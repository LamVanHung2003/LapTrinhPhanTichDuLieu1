# %%
# Import thư viện 
import pandas as pd
import seaborn as sb
import matplotlib as mp
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import skew
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.formula.api import ols
import scipy.stats as stats

# %%
df=pd.read_csv('de01-data.csv')
df
# Out:
#      TimeToPlay  TimeToStudy  ProfessionalScore InterviewScore Sexuality  \
# 0           0.1          4.4                2.5              F         T
# 1           4.1          5.7                3.7              D         L
# 2           7.3          0.9                2.7              D         T
# 3           6.2          8.8                2.7              D         T
# 4           5.0          3.1                0.2              D         Q
# ..          ...          ...                ...            ...       ...
# 995         2.9          6.3                1.2              C         Q
# 996         3.8          1.5                2.8              B         T
# 997         7.4          0.6                1.3              D         Q
# 998         8.5          5.7                3.3              C         L
# 999         0.9          4.3                0.3              B         L
#
#      ExpectedSalary SocialNetworkingTimeUse Result
# ...

# %%
mean_diem_phong_van = df['InterviewScore']
# Out:
# Giá trị trung bình của điểm phỏng vấn của sinh viên là: 1000

# %%
so_lan_A = mean_diem_phong_van.count('A')
so_lan_B = mean_diem_phong_van.count('B')
so_lan_C = mean_diem_phong_van.count('C')
so_lan_F = mean_diem_phong_van.count('F')
so_lan_D = mean_diem_phong_van.count('D')

# Tìm ký tự xuất hiện nhiều nhất (đa số)
da_so_diem_phong_van = max(so_lan_A, so_lan_F, so_lan_D)

if da_so_diem_phong_van == so_lan_A:
    print("Đa số điểm phỏng vấn của sinh viên là A")
elif da_so_diem_phong_van == so_lan_F:
    print("Đa số điểm phỏng vấn của sinh viên là F")
else:
    print("Đa số điểm phỏng vấn của sinh viên là D")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\hungl\LapTrinhPhanTichDuLieu\Ontap\GK1.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hungl/LapTrinhPhanTichDuLieu/Ontap/GK1.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> so_lan_A = mean_diem_phong_van.count('A')
#       <a href='vscode-notebook-cell:/c%3A/Users/hungl/LapTrinhPhanTichDuLieu/Ontap/GK1.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> so_lan_B = mean_diem_phong_van.count('B')
#       <a href='vscode-notebook-cell:/c%3A/Users/hungl/LapTrinhPhanTichDuLieu/Ontap/GK1.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> so_lan_C = mean_diem_phong_van.count('C')
#
# AttributeError: 'numpy.int64' object has no attribute 'count'

# %%
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
sns.lineplot(data=df, x='InterviewScore', y='ExpectedSalary', hue='Sexuality', marker='o')

# Đặt tiêu đề và nhãn
plt.title('Lương mong đợi trung bình theo điểm số phỏng vấn và xu hướng tính dục')
plt.xlabel('Điểm số phỏng vấn')
plt.ylabel('Lương mong đợi trung bình')

# Hiển thị biểu đồ
plt.legend(title='Xu Hướng Tính Dục')
