# %%
import pandas as pd

# %%
column_name=['ID','NAME','AGE','WEIGHT','M006','M0612','M1218','F0006','F0612','F1218']

# %%
df=pd.read_csv('patient_heart_rate.csv',names=column_name)

# %%
df.head(10)
# Out:
#     ID            NAME   AGE      WEIGHT M006 M0612 M1218 F0006 F0612 F1218
# 0  1.0    Mickéy Mousé  56.0       70kgs   72    69    71     -     -     -
# 1  2.0     Donald Duck  34.0   154.89lbs    -     -     -    85    84    76
# 2  3.0      Mini Mouse  16.0         NaN    -     -     -    65    69    72
# 3  4.0  Scrooge McDuck   NaN       78kgs   78    79    72     -     -     -
# 4  5.0    Pink Panther  54.0  198.658lbs    -     -     -    69   NaN    75
# 5  6.0     Huey McDuck  52.0      189lbs    -     -     -    68    75    72
# 6  7.0    Dewey McDuck  19.0       56kgs    -     -     -    71    78    75
# 7  8.0      Scööpy Doo  32.0       78kgs   78    76    75     -     -     -
# 8  NaN             NaN   NaN         NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 9  NaN             NaN   NaN         NaN  NaN   NaN   NaN   NaN   NaN   NaN

# %%
df[['Firstname','Lastname']]=df['NAME'].str.split(expand=True)

# %%
df=df.drop('NAME',axis=1)

# %%
df
# Out:
#       ID   AGE      WEIGHT M006 M0612 M1218 F0006 F0612 F1218 Firstname  \
# 0    1.0  56.0       70kgs   72    69    71     -     -     -    Mickéy
# 1    2.0  34.0   154.89lbs    -     -     -    85    84    76    Donald
# 2    3.0  16.0         NaN    -     -     -    65    69    72      Mini
# 3    4.0   NaN       78kgs   78    79    72     -     -     -   Scrooge
# 4    5.0  54.0  198.658lbs    -     -     -    69   NaN    75      Pink
# 5    6.0  52.0      189lbs    -     -     -    68    75    72      Huey
# 6    7.0  19.0       56kgs    -     -     -    71    78    75     Dewey
# 7    8.0  32.0       78kgs   78    76    75     -     -     -    Scööpy
# 8    NaN   NaN         NaN  NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 9    NaN   NaN         NaN  NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 10   9.0  52.0      189lbs    -     -     -    68    75    72      Huey
# 11  10.0  12.0       45kgs    -     -     -    92    95    87     Louie
# 12  11.0   NaN       60kgs   78    75    72     -     -     -     Henry
# 13  12.0  34.0         NaN   65    67    55     -     -     -    Michel
# 14  13.0   NaN         NaN    -     -     -    68    72    70      Tana
# 15  14.0   NaN         NaN  NaN   NaN   NaN   NaN   NaN   NaN  UniLever
# 16  15.0  52.0      180lbs    -     -     -    68    75    72       NaN
#
#    Lastname
# 0     Mousé
# 1      Duck
# 2     Mouse
# 3    McDuck
# 4   Panther
# 5    McDuck
# 6    McDuck
# 7       Doo
# 8       NaN
# 9       NaN
# 10   McDuck
# 11   McDuck
# 12      Nam
# 13     Long
# 14    Ricky
# 15     None
# 16      NaN

# %%
weight=df['WEIGHT']

# %%
weight
# Out:
# 0          70kgs
# 1      154.89lbs
# 2            NaN
# 3          78kgs
# 4     198.658lbs
# 5         189lbs
# 6          56kgs
# 7          78kgs
# 8            NaN
# 9            NaN
# 10        189lbs
# 11         45kgs
# 12         60kgs
# 13           NaN
# 14           NaN
# 15           NaN
# 16        180lbs
# Name: WEIGHT, dtype: object

# %%
for i in range(0, len(weight)):
  x=str(weight[i])
  if 'lbs' in x[-3:]:
    x=x[:-3:]
    floatx=float(x)
    y=int(floatx/2.2)
    weight[i]=y
  if'kgs'in x[-3:]:
    x=x[:-3:]
    floatx=float(x)
    weight[i]=floatx

# %%
df.rename(columns={'WEIGHT':'WEIGHT_KGS'},inplace=True)

# %%
df
# Out:
#       ID   AGE WEIGHT_KGS M006 M0612 M1218 F0006 F0612 F1218 Firstname  \
# 0    1.0  56.0       70.0   72    69    71     -     -     -    Mickéy
# 1    2.0  34.0         70    -     -     -    85    84    76    Donald
# 2    3.0  16.0        NaN    -     -     -    65    69    72      Mini
# 3    4.0   NaN       78.0   78    79    72     -     -     -   Scrooge
# 4    5.0  54.0         90    -     -     -    69   NaN    75      Pink
# 5    6.0  52.0         85    -     -     -    68    75    72      Huey
# 6    7.0  19.0       56.0    -     -     -    71    78    75     Dewey
# 7    8.0  32.0       78.0   78    76    75     -     -     -    Scööpy
# 8    NaN   NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 9    NaN   NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN       NaN
# 10   9.0  52.0         85    -     -     -    68    75    72      Huey
# 11  10.0  12.0       45.0    -     -     -    92    95    87     Louie
# 12  11.0   NaN       60.0   78    75    72     -     -     -     Henry
# 13  12.0  34.0        NaN   65    67    55     -     -     -    Michel
# 14  13.0   NaN        NaN    -     -     -    68    72    70      Tana
# 15  14.0   NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN  UniLever
# 16  15.0  52.0         81    -     -     -    68    75    72       NaN
#
#    Lastname
# 0     Mousé
# 1      Duck
# 2     Mouse
# 3    McDuck
# 4   Panther
# 5    McDuck
# 6    McDuck
# 7       Doo
# 8       NaN
# 9       NaN
# 10   McDuck
# 11   McDuck
# 12      Nam
# 13     Long
# 14    Ricky
# 15     None
# 16      NaN

# %%
df.dropna(how='all',inplace=True)

# %%
df=df.drop_duplicates(subset=['Firstname','Lastname','AGE','WEIGHT_KGS'])

# %%
df
# Out:
#       ID   AGE WEIGHT_KGS M006 M0612 M1218 F0006 F0612 F1218 Firstname  \
# 0    1.0  56.0       70.0   72    69    71     -     -     -    Mickéy
# 1    2.0  34.0         70    -     -     -    85    84    76    Donald
# 2    3.0  16.0        NaN    -     -     -    65    69    72      Mini
# 3    4.0   NaN       78.0   78    79    72     -     -     -   Scrooge
# 4    5.0  54.0         90    -     -     -    69   NaN    75      Pink
# 5    6.0  52.0         85    -     -     -    68    75    72      Huey
# 6    7.0  19.0       56.0    -     -     -    71    78    75     Dewey
# 7    8.0  32.0       78.0   78    76    75     -     -     -    Scööpy
# 11  10.0  12.0       45.0    -     -     -    92    95    87     Louie
# 12  11.0   NaN       60.0   78    75    72     -     -     -     Henry
# 13  12.0  34.0        NaN   65    67    55     -     -     -    Michel
# 14  13.0   NaN        NaN    -     -     -    68    72    70      Tana
# 15  14.0   NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN  UniLever
# 16  15.0  52.0         81    -     -     -    68    75    72       NaN
#
#    Lastname
# 0     Mousé
# 1      Duck
# 2     Mouse
# 3    McDuck
# 4   Panther
# 5    McDuck
# 6    McDuck
# 7       Doo
# 11   McDuck
# 12      Nam
# 13     Long
# 14    Ricky
# 15     None
# 16      NaN

# %%
df.Firstname.replace({r'[^\x00-\x7F]+':''},regex=True,inplace=True)

# %%
df.Lastname.replace({r'[^\x00-\x7F]+':''},regex=True,inplace=True)

# %%
df['AGE'].fillna(df['AGE'].mode()[0],inplace=True)

# %%
df=pd.melt(df,id_vars=['ID','AGE','WEIGHT_KGS','Firstname','Lastname'],value_name='PulseRate',var_name='Gender_time').sort_values(['ID','AGE','WEIGHT_KGS','Firstname','Lastname'])

# %%
df
# Out:
#       ID   AGE WEIGHT_KGS Firstname Lastname Gender_time PulseRate
# 0    1.0  56.0       70.0     Micky     Mous        M006        72
# 14   1.0  56.0       70.0     Micky     Mous       M0612        69
# 28   1.0  56.0       70.0     Micky     Mous       M1218        71
# 42   1.0  56.0       70.0     Micky     Mous       F0006         -
# 56   1.0  56.0       70.0     Micky     Mous       F0612         -
# ..   ...   ...        ...       ...      ...         ...       ...
# 27  15.0  52.0         81       NaN      NaN       M0612         -
# 41  15.0  52.0         81       NaN      NaN       M1218         -
# 55  15.0  52.0         81       NaN      NaN       F0006        68
# 69  15.0  52.0         81       NaN      NaN       F0612        75
# 83  15.0  52.0         81       NaN      NaN       F1218        72
#
# [84 rows x 7 columns]

# %%
df_temp=df['Gender_time'].str.extract('(\D)(\d+)(\d{2})',expand=True)

# %%
df_temp.columns=['Gender','Lower_hour','Upper_hour']

# %%
df_temp
# Out:
#    Gender Lower_hour Upper_hour
# 0       M          0         06
# 14      M         06         12
# 28      M         12         18
# 42      F         00         06
# 56      F         06         12
# ..    ...        ...        ...
# 27      M         06         12
# 41      M         12         18
# 55      F         00         06
# 69      F         06         12
# 83      F         12         18
#
# [84 rows x 3 columns]

# %%
df=pd.concat([df,df_temp],axis=1)
df
# Out:
#       ID   AGE WEIGHT_KGS Firstname Lastname Gender_time PulseRate Gender  \
# 0    1.0  56.0       70.0     Micky     Mous        M006        72      M
# 14   1.0  56.0       70.0     Micky     Mous       M0612        69      M
# 28   1.0  56.0       70.0     Micky     Mous       M1218        71      M
# 42   1.0  56.0       70.0     Micky     Mous       F0006         -      F
# 56   1.0  56.0       70.0     Micky     Mous       F0612         -      F
# ..   ...   ...        ...       ...      ...         ...       ...    ...
# 27  15.0  52.0         81       NaN      NaN       M0612         -      M
# 41  15.0  52.0         81       NaN      NaN       M1218         -      M
# 55  15.0  52.0         81       NaN      NaN       F0006        68      F
# 69  15.0  52.0         81       NaN      NaN       F0612        75      F
# 83  15.0  52.0         81       NaN      NaN       F1218        72      F
#
#    Lower_hour Upper_hour
# 0           0         06
# 14         06         12
# 28         12         18
# 42         00         06
# 56         06         12
# ..        ...        ...
# 27         06         12
# 41         12         18
# 55         00         06
# 69         06         12
# 83         12         18
#
# [84 rows x 10 columns]

# %%
df=df.drop(['Gender_time'],axis=1)

# %%
df
# Out:
#       ID   AGE WEIGHT_KGS Firstname Lastname PulseRate Gender Lower_hour  \
# 0    1.0  56.0       70.0     Micky     Mous        72      M          0
# 14   1.0  56.0       70.0     Micky     Mous        69      M         06
# 28   1.0  56.0       70.0     Micky     Mous        71      M         12
# 42   1.0  56.0       70.0     Micky     Mous         -      F         00
# 56   1.0  56.0       70.0     Micky     Mous         -      F         06
# ..   ...   ...        ...       ...      ...       ...    ...        ...
# 27  15.0  52.0         81       NaN      NaN         -      M         06
# 41  15.0  52.0         81       NaN      NaN         -      M         12
# 55  15.0  52.0         81       NaN      NaN        68      F         00
# 69  15.0  52.0         81       NaN      NaN        75      F         06
# 83  15.0  52.0         81       NaN      NaN        72      F         12
#
#    Upper_hour
# 0          06
# 14         12
# 28         18
# 42         06
# 56         12
# ..        ...
# 27         12
# 41         18
# 55         06
# 69         12
# 83         18
#
# [84 rows x 9 columns]

# %%
import numpy as np

# %%
df=df.replace('-',np.nan).dropna(subset=['PulseRate'])

# %%
df
# Out:
#       ID   AGE  WEIGHT_KGS Firstname Lastname PulseRate Gender Lower_hour  \
# 0    1.0  56.0        70.0     Micky     Mous        72      M          0
# 14   1.0  56.0        70.0     Micky     Mous        69      M         06
# 28   1.0  56.0        70.0     Micky     Mous        71      M         12
# 43   2.0  34.0        70.0    Donald     Duck        85      F         00
# 57   2.0  34.0        70.0    Donald     Duck        84      F         06
# 71   2.0  34.0        70.0    Donald     Duck        76      F         12
# 44   3.0  16.0         NaN      Mini    Mouse        65      F         00
# 58   3.0  16.0         NaN      Mini    Mouse        69      F         06
# 72   3.0  16.0         NaN      Mini    Mouse        72      F         12
# 3    4.0  34.0        78.0   Scrooge   McDuck        78      M          0
# 17   4.0  34.0        78.0   Scrooge   McDuck        79      M         06
# 31   4.0  34.0        78.0   Scrooge   McDuck        72      M         12
# 46   5.0  54.0        90.0      Pink  Panther        69      F         00
# 74   5.0  54.0        90.0      Pink  Panther        75      F         12
# 47   6.0  52.0        85.0      Huey   McDuck        68      F         00
# 61   6.0  52.0        85.0      Huey   McDuck        75      F         06
# 75   6.0  52.0        85.0      Huey   McDuck        72      F         12
# 48   7.0  19.0        56.0     Dewey   McDuck        71      F         00
# 62   7.0  19.0        56.0     Dewey   McDuck        78      F         06
# 76   7.0  19.0        56.0     Dewey   McDuck        75      F         12
# 7    8.0  32.0        78.0      Scpy      Doo        78      M          0
# 21   8.0  32.0        78.0      Scpy      Doo        76      M         06
# 35   8.0  32.0        78.0      Scpy      Doo        75      M         12
# 50  10.0  12.0        45.0     Louie   McDuck        92      F         00
# 64  10.0  12.0        45.0     Louie   McDuck        95      F         06
# 78  10.0  12.0        45.0     Louie   McDuck        87      F         12
# 9   11.0  34.0        60.0     Henry      Nam        78      M          0
# 23  11.0  34.0        60.0     Henry      Nam        75      M         06
# 37  11.0  34.0        60.0     Henry      Nam        72      M         12
# 10  12.0  34.0         NaN    Michel     Long        65      M          0
# 24  12.0  34.0         NaN    Michel     Long        67      M         06
# 38  12.0  34.0         NaN    Michel     Long        55      M         12
# 53  13.0  34.0         NaN      Tana    Ricky        68      F         00
# 67  13.0  34.0         NaN      Tana    Ricky        72      F         06
# 81  13.0  34.0         NaN      Tana    Ricky        70      F         12
# 55  15.0  52.0        81.0       NaN      NaN        68      F         00
# 69  15.0  52.0        81.0       NaN      NaN        75      F         06
# 83  15.0  52.0        81.0       NaN      NaN        72      F         12
#
#    Upper_hour
# 0          06
# 14         12
# 28         18
# 43         06
# 57         12
# 71         18
# 44         06
# 58         12
# 72         18
# 3          06
# 17         12
# 31         18
# 46         06
# 74         18
# 47         06
# 61         12
# 75         18
# 48         06
# 62         12
# 76         18
# 7          06
# 21         12
# 35         18
# 50         06
# 64         12
# 78         18
# 9          06
# 23         12
# 37         18
# 10         06
# 24         12
# 38         18
# 53         06
# 67         12
# 81         18
# 55         06
# 69         12
# 83         18

# %%
df['Firstname'].fillna('Unknown',inplace=True)

# %%
df['Lastname'].fillna('Unknown',inplace=True)

# %%
df=df.reset_index()

# %%
df
# Out:
#     index    ID   AGE  WEIGHT_KGS Firstname Lastname PulseRate Gender  \
# 0       0   1.0  56.0        70.0     Micky     Mous        72      M
# 1      14   1.0  56.0        70.0     Micky     Mous        69      M
# 2      28   1.0  56.0        70.0     Micky     Mous        71      M
# 3      43   2.0  34.0        70.0    Donald     Duck        85      F
# 4      57   2.0  34.0        70.0    Donald     Duck        84      F
# 5      71   2.0  34.0        70.0    Donald     Duck        76      F
# 6      44   3.0  16.0         NaN      Mini    Mouse        65      F
# 7      58   3.0  16.0         NaN      Mini    Mouse        69      F
# 8      72   3.0  16.0         NaN      Mini    Mouse        72      F
# 9       3   4.0  34.0        78.0   Scrooge   McDuck        78      M
# 10     17   4.0  34.0        78.0   Scrooge   McDuck        79      M
# 11     31   4.0  34.0        78.0   Scrooge   McDuck        72      M
# 12     46   5.0  54.0        90.0      Pink  Panther        69      F
# 13     74   5.0  54.0        90.0      Pink  Panther        75      F
# 14     47   6.0  52.0        85.0      Huey   McDuck        68      F
# 15     61   6.0  52.0        85.0      Huey   McDuck        75      F
# 16     75   6.0  52.0        85.0      Huey   McDuck        72      F
# 17     48   7.0  19.0        56.0     Dewey   McDuck        71      F
# 18     62   7.0  19.0        56.0     Dewey   McDuck        78      F
# 19     76   7.0  19.0        56.0     Dewey   McDuck        75      F
# 20      7   8.0  32.0        78.0      Scpy      Doo        78      M
# 21     21   8.0  32.0        78.0      Scpy      Doo        76      M
# 22     35   8.0  32.0        78.0      Scpy      Doo        75      M
# 23     50  10.0  12.0        45.0     Louie   McDuck        92      F
# 24     64  10.0  12.0        45.0     Louie   McDuck        95      F
# 25     78  10.0  12.0        45.0     Louie   McDuck        87      F
# 26      9  11.0  34.0        60.0     Henry      Nam        78      M
# 27     23  11.0  34.0        60.0     Henry      Nam        75      M
# 28     37  11.0  34.0        60.0     Henry      Nam        72      M
# 29     10  12.0  34.0         NaN    Michel     Long        65      M
# 30     24  12.0  34.0         NaN    Michel     Long        67      M
# 31     38  12.0  34.0         NaN    Michel     Long        55      M
# 32     53  13.0  34.0         NaN      Tana    Ricky        68      F
# 33     67  13.0  34.0         NaN      Tana    Ricky        72      F
# 34     81  13.0  34.0         NaN      Tana    Ricky        70      F
# 35     55  15.0  52.0        81.0   Unknown  Unknown        68      F
# 36     69  15.0  52.0        81.0   Unknown  Unknown        75      F
# 37     83  15.0  52.0        81.0   Unknown  Unknown        72      F
#
#    Lower_hour Upper_hour
# 0           0         06
# 1          06         12
# 2          12         18
# 3          00         06
# 4          06         12
# 5          12         18
# 6          00         06
# 7          06         12
# 8          12         18
# 9           0         06
# 10         06         12
# 11         12         18
# 12         00         06
# 13         12         18
# 14         00         06
# 15         06         12
# 16         12         18
# 17         00         06
# 18         06         12
# 19         12         18
# 20          0         06
# 21         06         12
# 22         12         18
# 23         00         06
# 24         06         12
# 25         12         18
# 26          0         06
# 27         06         12
# 28         12         18
# 29          0         06
# 30         06         12
# 31         12         18
# 32         00         06
# 33         06         12
# 34         12         18
# 35         00         06
# 36         06         12
# 37         12         18

# %%
df.to_csv('patient_heart_rate_clean.csv')
