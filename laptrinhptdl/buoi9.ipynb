# %%
pip install pycaret
# Out:
# Collecting pycaret
#   Using cached pycaret-3.0.4-py3-none-any.whl (484 kB)
# Collecting lightgbm>=3.0.0
#   Downloading lightgbm-4.0.0-py3-none-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 1.0 MB/s eta 0:00:00
# Collecting plotly-resampler>=0.8.3.1
#   Downloading plotly_resampler-0.9.1-py3-none-any.whl (73 kB)
#      -------------------------------------- 73.4/73.4 kB 809.3 kB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp310-cp310-win_amd64.whl (30 kB)
# Collecting schemdraw==0.15
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      -------------------------------------- 106.8/106.8 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (3.5.3)
# Collecting importlib-metadata>=4.12.0
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (8.0.1)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: numpy<1.24,>=1.21 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (1.23.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (1.2.0)
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0
#   Downloading pmdarima-2.0.3-cp310-cp310-win_amd64.whl (569 kB)
#      -------------------------------------- 569.7/569.7 kB 1.6 MB/s eta 0:00:00
# Collecting pyod>=1.0.8
#   Downloading pyod-1.1.0.tar.gz (153 kB)
#      -------------------------------------- 153.4/153.4 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy<2.0.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (1.9.3)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (1.1.3)
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting plotly>=5.0.0
#   Downloading plotly-5.15.0-py2.py3-none-any.whl (15.5 MB)
#      ---------------------------------------- 15.5/15.5 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.27.1 in c:\users\thanh duoc\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.31.0)
# Collecting scikit-plot>=0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting kaleido>=0.2.1
#   Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
#      ---------------------------------------- 65.9/65.9 MB 1.3 MB/s eta 0:00:00
# Collecting numba>=0.55.0
#   Downloading numba-0.57.1-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (5.4.0)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (1.4.4)
# Collecting tqdm>=4.62.0
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting yellowbrick>=1.4
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# Collecting tbats>=1.1.3
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.0/44.0 kB ? eta 0:00:00
# Collecting category-encoders>=2.4.0
#   Downloading category_encoders-2.6.1-py2.py3-none-any.whl (81 kB)
#      -------------------------------------- 81.9/81.9 kB 919.2 kB/s eta 0:00:00
# Requirement already satisfied: ipython>=5.5.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (8.4.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (5.9.1)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\thanh duoc\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: jinja2>=1.2 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pycaret) (3.1.2)
# Collecting imbalanced-learn>=0.8.1
#   Downloading imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
#      -------------------------------------- 235.6/235.6 kB 1.8 MB/s eta 0:00:00
# Collecting deprecation>=2.1.0
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1
#   Downloading sktime-0.20.0-py3-none-any.whl (17.0 MB)
#      ---------------------------------------- 17.0/17.0 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: patsy>=0.5.1 in c:\users\thanh duoc\appdata\local\programs\python\python310\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: packaging in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from imbalanced-learn>=0.8.1->pycaret) (3.1.0)
# Collecting zipp>=0.5
#   Downloading zipp-3.16.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: stack-data in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.5.0)
# Requirement already satisfied: pickleshare in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (3.0.31)
# Requirement already satisfied: colorama in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: traitlets>=5 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (5.3.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (2.13.0)
# Requirement already satisfied: decorator in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: backcall in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\thanh duoc\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (65.5.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->pycaret) (4.37.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: fastjsonschema in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from nbformat>=4.2.0->pycaret) (2.16.1)
# Requirement already satisfied: jupyter-core in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from nbformat>=4.2.0->pycaret) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from nbformat>=4.2.0->pycaret) (4.15.0)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.1-cp310-cp310-win_amd64.whl (27.7 MB)
#      ---------------------------------------- 27.7/27.7 MB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.2.1)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting orjson<4.0.0,>=3.8.0
#   Downloading orjson-3.9.2-cp310-none-win_amd64.whl (195 kB)
#      -------------------------------------- 195.7/195.7 kB 1.5 MB/s eta 0:00:00
# Collecting trace-updater>=0.0.8
#   Downloading trace_updater-0.0.9.1-py3-none-any.whl (185 kB)
#      -------------------------------------- 185.2/185.2 kB 2.8 MB/s eta 0:00:00
# Collecting tsdownsample==0.1.2
#   Downloading tsdownsample-0.1.2-cp310-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 1.4 MB/s eta 0:00:00
# Collecting dash<3.0.0,>=2.11.0
#   Downloading dash-2.11.1-py3-none-any.whl (10.4 MB)
#      ---------------------------------------- 10.4/10.4 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in c:\users\thanh duoc\appdata\local\programs\python\python310\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (2.0.3)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading Cython-0.29.36-py2.py3-none-any.whl (988 kB)
#      -------------------------------------- 988.3/988.3 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thanh duoc\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thanh duoc\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thanh duoc\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (3.1.0)
# Collecting scikit-base<0.6.0
#   Downloading scikit_base-0.5.0-py3-none-any.whl (118 kB)
#      -------------------------------------- 118.2/118.2 kB 7.2 MB/s eta 0:00:00
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting Werkzeug<2.3.0
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      -------------------------------------- 233.6/233.6 kB 2.4 MB/s eta 0:00:00
# Collecting typing-extensions>=4.1.1
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: nest-asyncio in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.5)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Collecting Flask<2.3.0,>=1.0.4
#   Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.8/101.8 kB 3.0 MB/s eta 0:00:00
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.15.0-cp310-cp310-win_amd64.whl (36 kB)
# Requirement already satisfied: pyzmq>=17 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: wcwidth in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (304)
# Requirement already satisfied: asttokens in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.8)
# Requirement already satisfied: executing in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=5.5.0->pycaret) (1.0.0)
# Requirement already satisfied: pure-eval in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.0
#   Downloading click-8.1.5-py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.1/98.1 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in c:\users\thanh duoc\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Installing collected packages: trace-updater, kaleido, dash-table, dash-html-components, dash-core-components, zipp, xxhash, wrapt, Werkzeug, typing-extensions, tsdownsample, tqdm, tenacity, scikit-base, schemdraw, retrying, orjson, llvmlite, itsdangerous, Cython, cloudpickle, click, ansi2html, plotly, numba, lightgbm, importlib-metadata, Flask, deprecation, deprecated, yellowbrick, sktime, scikit-plot, pyod, imbalanced-learn, dash, pmdarima, plotly-resampler, category-encoders, tbats, pycaret
#   Running setup.py install for pyod: started
#   Running setup.py install for pyod: finished with status 'done'
# Successfully installed Cython-0.29.36 Flask-2.2.5 Werkzeug-2.2.3 ansi2html-1.8.0 category-encoders-2.6.1 click-8.1.5 cloudpickle-2.2.1 dash-2.11.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecated-1.2.14 deprecation-2.1.0 imbalanced-learn-0.11.0 importlib-metadata-6.8.0 itsdangerous-2.1.2 kaleido-0.2.1 lightgbm-4.0.0 llvmlite-0.40.1 numba-0.57.1 orjson-3.9.2 plotly-5.15.0 plotly-resampler-0.9.1 pmdarima-2.0.3 pycaret-3.0.4 pyod-1.1.0 retrying-1.3.4 schemdraw-0.15 scikit-base-0.5.0 scikit-plot-0.3.7 sktime-0.20.0 tbats-1.1.3 tenacity-8.2.2 tqdm-4.65.0 trace-updater-0.0.9.1 tsdownsample-0.1.2 typing-extensions-4.7.1 wrapt-1.15.0 xxhash-3.2.0 yellowbrick-1.5 zipp-3.16.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\THANH DUOC\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts cygdb.exe, cython.exe and cythonize.exe are installed in 'c:\Users\THANH DUOC\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script ansi2html.exe is installed in 'c:\Users\THANH DUOC\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script flask.exe is installed in 'c:\Users\THANH DUOC\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   DEPRECATION: pyod is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   WARNING: The scripts dash-generate-components.exe, dash-update-components.exe and renderer.exe are installed in 'c:\Users\THANH DUOC\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# load sample data

from pycaret.datasets import get_data

data = get_data('france')
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#       InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/2010 8:45       3.75     12583.0  France
# 1  12/1/2010 8:45       3.75     12583.0  France
# 2  12/1/2010 8:45       3.75     12583.0  France
# 3  12/1/2010 8:45       0.85     12583.0  France
# 4  12/1/2010 8:45       0.65     12583.0  France

# %%
# init setup

from pycaret.arules import *

s = setup(data = data, transaction_id = 'InvoiceNo', item_id = 'Description')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# e:\laptrinhptdl\buoi9.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # init setup
# ----> <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> from pycaret.arules import *
#       <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> s = setup(data = data, transaction_id = 'InvoiceNo', item_id = 'Description')
#
# ModuleNotFoundError: No module named 'pycaret.arules'

# %%
import pycaret
print(pycaret.__version__)
# Out:
# 3.0.4

# %%
# train model

arules = create_model(metric='confidence', threshold=0.5, min_support=0.05)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\laptrinhptdl\buoi9.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # train model
# ----> <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> arules = create_model(metric='confidence', threshold=0.5, min_support=0.05)
#
# NameError: name 'create_model' is not defined

# %%
# 2d plot
plot_model(arules, plot = '2d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\laptrinhptdl\buoi9.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # 2d plot
# ----> <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> plot_model(arules, plot = '2d')
#
# NameError: name 'plot_model' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# e:\laptrinhptdl\buoi9.ipynb Cell 8 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/buoi9.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> from mlxtend.frequent_patterns import apriori, association_rules
#
# ModuleNotFoundError: No module named 'mlxtend'
