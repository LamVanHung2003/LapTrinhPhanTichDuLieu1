# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier

# %%
data=pd.read_csv('Boston.csv')

# %%
x = pd.DataFrame(dataset.iloc[:,:-1])
y = pd.DataFrame(dataset .iloc[:,-1])

# %%
x
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat
# 0    296     15.3  396.90   4.98
# 1    242     17.8  396.90   9.14
# 2    242     17.8  392.83   4.03
# 3    222     18.7  394.63   2.94
# 4    222     18.7  396.90   5.33
# ..   ...      ...     ...    ...
# 501  273     21.0  391.99   9.67
# 502  273     21.0  396.90   9.08
# 503  273     21.0  396.90   5.64
# 504  273     21.0  393.45   6.48
# 505  273     21.0  396.90   7.88
#
# [506 rows x 14 columns]

# %%
y
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# split training and testing data
xtrain,xtest,ytrain,ytest= train_test_split(
                                            x,y,
                                            test_size=0.2,
                                            random_state=1
                                           )
# creating object
stand= StandardScaler()
# fit data
Fit= stand.fit(xtrain)
# transform data
x_scaled = Fit.transform(xtrain)

# %%
regressor = LinearRegression()
regressor.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
v = pd.DataFrame(regressor.coef_,index=['Co-efficient']).transpose()
w = pd.DataFrame (x.columns, columns=['Attribute'])

# %%
coeff_df=pd.concat([w,v],axis=1,join='inner')
coeff_df
# Out:
#      Attribute  Co-efficient
# 0   Unnamed: 0     -0.002717
# 1         crim     -0.113467
# 2           zn      0.060670
# 3        indus      0.019462
# 4         chas      2.155218
# 5          nox    -19.441797
# 6           rm      3.106845
# 7          age      0.002296
# 8          dis     -1.523417
# 9          rad      0.333528
# 10         tax     -0.010737
# 11     ptratio     -0.988933
# 12       black      0.007304
# 13       lstat     -0.547095

# %%
ytrain
# Out:
#      medv
# 42   25.3
# 58   23.3
# 385   7.2
# 78   21.2
# 424  11.7
# ..    ...
# 255  20.9
# 72   22.8
# 396  12.5
# 235  24.0
# 37   21.0
#
# [404 rows x 1 columns]

# %%
ft=regressor.predict(xtrain)
ft
# Out:
# array([[25.44228423],
#        [22.38858062],
#        [ 8.4204682 ],
#        [21.61766821],
#        [15.93573009],
#        [32.61857586],
#        [24.55072385],
#        [25.48209352],
#        [38.63805182],
#        [29.05784392],
#        [14.69730149],
#        [34.90194595],
#        [35.83938471],
#        [33.16729259],
#        [20.64863943],
#        [17.05898681],
#        [35.07190191],
#        [39.54140638],
#        [21.17370056],
#        [15.44667312],
#        [27.85089852],
#        [19.03742084],
#        [27.14103141],
#        [20.52416727],
#        [25.54081107],
#        [21.25752547],
#        [23.43872793],
#        [28.65179436],
#        [20.77881594],
#        [23.66318772],
#        [29.69010993],
#        [10.52674321],
#        [27.33269411],
#        [32.58626734],
#        [14.13493481],
#        [13.37528258],
#        [33.54586956],
#        [13.50410845],
#        [17.19927868],
#        [16.38736849],
#        [17.54422261],
#        [28.60594158],
#        [33.80924732],
#        [20.15200692],
#        [24.26438631],
#        [17.12131175],
#        [28.66636989],
#        [15.87058594],
#        [23.38650966],
#        [24.75703888],
#        [37.84282528],
#        [28.39917824],
#        [20.20071935],
#        [17.63572121],
#        [ 8.16642493],
#        [ 6.09206516],
#        [15.59712048],
#        [11.80577605],
#        [22.34043643],
#        [18.91210297],
#        [21.01596021],
#        [20.16460947],
#        [26.04804536],
#        [35.23201641],
#        [16.66207374],
#        [17.1575038 ],
#        [ 4.47859945],
#        [25.20449413],
#        [25.11067303],
#        [15.92446959],
#        [18.0289866 ],
#        [20.79285215],
#        [20.00180668],
#        [19.67118193],
#        [ 4.36995031],
#        [22.33862021],
#        [17.41556019],
#        [24.08677611],
#        [23.09752757],
#        [24.30910793],
#        [18.22961861],
#        [21.85752577],
#        [ 6.65193723],
#        [12.89176371],
#        [14.57946209],
#        [24.49166574],
#        [20.15646924],
#        [17.09563912],
#        [18.10323885],
#        [22.13028591],
#        [24.88287981],
#        [34.64979008],
#        [31.12344773],
#        [33.87422065],
#        [17.59139629],
#        [31.95632056],
#        [22.15843155],
#        [18.78440805],
#        [14.36363191],
#        [ 9.08888599],
#        [17.3323215 ],
#        [19.95713469],
#        [15.9961467 ],
#        [42.28751864],
#        [20.29512294],
#        [22.681711  ],
#        [24.95154658],
#        [19.14452136],
#        [25.30107906],
#        [23.63070437]])

# %%
y_pred = regressor.predict (xtest)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred
# Out:
#      Predicted
# 0    32.417338
# 1    27.790194
# 2    18.177707
# 3    21.813096
# 4    19.003303
# ..         ...
# 97   29.389236
# 98   37.104539
# 99   20.786951
# 100  17.416306
# 101  17.646926
#
# [102 rows x 1 columns]

# %%
ytest.sort_index()
# Out:
#      medv
# 4    36.2
# 5    28.7
# 6    22.9
# 11   18.9
# 17   17.5
# ..    ...
# 491  13.6
# 494  24.5
# 497  18.3
# 501  22.4
# 503  23.9
#
# [102 rows x 1 columns]

# %%
from sklearn.metrics import r2_score

# %%
from sklearn import metrics

print('Mean Absolute Error: ',metrics.mean_absolute_error(ytest,y_pred))
print('Mean Square Error: ',metrics.mean_squared_error(ytest,y_pred))
print('Root Mean Square Error: ',np.sqrt(metrics.mean_squared_error(ytest,y_pred)))
print('',r2_score(ytest,y_pred))
# Out:
# Mean Absolute Error:  3.7357095670940104
# Mean Square Error:  23.369625899561175
# Root Mean Square Error:  4.834214093269058
#  0.7635308791830625

# %%
#############3

# %%
data_=data.loc[:,['age','lstat','medv']]
data_.head(10)
# Out:
#      age  lstat  medv
# 0   65.2   4.98  24.0
# 1   78.9   9.14  21.6
# 2   61.1   4.03  34.7
# 3   45.8   2.94  33.4
# 4   54.2   5.33  36.2
# 5   58.7   5.21  28.7
# 6   66.6  12.43  22.9
# 7   96.1  19.15  27.1
# 8  100.0  29.93  16.5
# 9   85.9  17.10  18.9

# %%
X = pd.DataFrame (data[['age','lstat']])
y = pd.DataFrame (data['medv'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split (X, y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print (regressor.intercept_)
# Out:
# [33.26495503]

# %%
print (regressor.coef_)
# Out:
# [[ 0.02984524 -0.99935   ]]

# %%
sh=X_train.shape
sh
# Out:
# (404, 2)

# %%
import numpy as np
from sklearn import metrics
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([[27.83797009],
#        [27.77289372],
#        [17.02894325],
#        [25.8089082 ],
#        [25.95269088],
#        [25.07403229],
#        [29.2663887 ],
#        [23.21795529],
#        [18.15608677],
#        [26.43345207],
#        [27.76539471],
#        [29.49660285],
#        [21.60971133],
#        [23.95979805],
#        [24.25058296],
#        [24.1273638 ],
#        [12.82462213],
#        [31.11511969],
#        [26.98584184],
#        [ 6.61033919],
#        [24.09140538],
#        [19.61030178],
#        [26.59647672],
#        [28.34572726],
#        [29.12923584],
#        [11.73804463],
#        [15.83018001],
#        [24.18929378],
#        [28.67783874],
#        [15.380202  ],
#        [28.84996774],
#        [16.91209003],
#        [31.33889028],
#        [19.71869145],
#        [25.14188033],
#        [20.95519584],
#        [18.3635999 ],
#        [29.55603169],
#        [12.92465025],
#        [20.67634237],
#        [26.44306419],
#        [27.66838437],
#        [28.08139064],
#        [12.08754662],
#        [18.13270947],
#        [12.82289704],
#        [34.2770059 ],
#        [19.75192699],
#        [26.2369391 ],
#        [25.19064825],
#        [23.63007242],
#        [23.63106135],
#        [29.81025728],
#        [25.04029785],
#        [ 6.52908075],
#        [28.56283699],
#        [ 5.63639533],
#        [28.86467084],
#        [21.04284684],
#        [31.41862763],
#        [21.23924229],
#        [28.41351764],
#        [16.3095975 ],
#        [18.2060964 ],
#        [ 4.02664581],
#        [29.97119321],
#        [32.98421684],
#        [26.40233851],
#        [24.13416878],
#        [24.3723143 ],
#        [27.98148003],
#        [ 7.98786124],
#        [22.0019102 ],
#        [23.89823171],
#        [21.72692819],
#        [24.05449129],
#        [33.21679022],
#        [25.99236776],
#        [28.86428281],
#        [30.53398225],
#        [20.83366849],
#        [25.43686707],
#        [29.03943847],
#        [12.83344044],
#        [28.6139708 ],
#        [28.8980749 ],
#        [16.90129386],
#        [28.62698209],
#        [21.28119414],
#        [19.24678184],
#        [30.34453813],
#        [30.74183464],
#        [18.15541048],
#        [22.83072768],
#        [21.10321361],
#        [22.47775113],
#        [25.66354679],
#        [26.70996403],
#        [31.46452855],
#        [21.89698621],
#        [19.36691449],
#        [17.41173177]])

# %%
y_test
# Out:
#      medv
# 307  28.2
# 343  23.9
# 47   16.6
# 67   22.0
# 362  20.8
# ..    ...
# 92   22.9
# 224  44.8
# 110  21.7
# 426  10.2
# 443  15.4
#
# [102 rows x 1 columns]

# %%
import numpy as np
from sklearn.metrics import r2_score
print('Mean Absolute Error: ',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Square Error: ',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Square Error: ',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print('',r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error:  5.115471184760084
# Mean Square Error:  45.768411039762675
# Root Mean Square Error:  6.76523547555905
#  0.5368853585301029

# %%
xx=np.array([[37.5,4.65]])
yso=regressor.predict(xx)
# Out:
# C:\Users\THANH DUOC\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
yso
# Out:
# array([[29.73717413]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# split training and testing data
xtrain,xtest,ytrain,ytest= train_test_split(
                                            X,y,
                                            test_size=0.2,
                                            random_state=1
                                           )
# creating object
stand= StandardScaler()
# fit data
Fit= stand.fit(xtrain)
# transform data
x_scaled = Fit.transform(xtrain)

# %%
x_scaled
# Out:
# array([[-2.15002959e+00, -9.66850164e-01],
#        [-1.35782026e+00, -8.21167893e-01],
#        [ 1.05736657e+00,  2.50177533e+00],
#        [-4.99009272e-01, -6.08451860e-02],
#        [ 9.33950447e-02,  6.07905809e-01],
#        [ 8.64572262e-01, -1.00986112e+00],
#        [ 3.02987269e-02,  5.15382799e-02],
#        [ 1.17932502e-01, -7.08784428e-01],
#        [-5.37568133e-01, -1.33452447e+00],
#        [ 5.66617428e-01, -5.18703751e-01],
#        [ 3.56296369e-01,  1.21283409e+00],
#        [ 1.38964608e-01, -8.75278451e-01],
#        [ 1.12396824e+00, -6.92135025e-01],
#        [-1.45947544e+00, -1.37476052e+00],
#        [-7.89953404e-01, -4.21582237e-01],
#        [-1.09842429e+00, -1.51029449e-01],
#        [-1.82753730e+00, -1.49824359e+00],
#        [-3.27975909e-02, -7.40695782e-01],
#        [-1.47700220e+00, -3.89670882e-01],
#        [ 9.17152527e-01,  8.22960589e-01],
#        [-2.27972757e+00, -1.10143283e+00],
#        [ 8.11991997e-01,  1.95833100e-01],
#        [-1.57865738e+00, -4.53493591e-01],
#        [-9.23885577e-02,  1.96269254e-02],
#        [-1.73639817e+00, -5.82526460e-01],
#        [ 3.07221455e-01, -5.13153950e-01],
#        [ 7.20852872e-01,  2.65205610e-01],
#        [-1.20709017e+00, -1.03899757e+00],
#        [-1.21410087e+00,  1.90283300e-01],
#        [-2.57868890e-02, -3.35560325e-01],
#        [-1.36833632e+00, -9.11352156e-01],
#        [ 1.01880771e+00,  1.79001338e+00],
#        [ 8.63843427e-02, -7.71219686e-01],
#        [-9.40683497e-01, -8.11455742e-01],
#        [ 1.12396824e+00,  1.94818270e+00],
#        [ 6.99820766e-01,  8.64584095e-01],
#        [ 5.38574620e-01, -7.24046380e-01],
#        [ 8.40034805e-01,  6.14843060e-01],
#        [-1.69783931e+00, -1.00014897e+00],
#        [ 1.05035586e+00,  7.88274334e-01],
#        [ 8.40034805e-01,  8.16023338e-01],
#        [-1.73289282e+00, -8.90540403e-01],
#        [-1.40338983e+00, -1.31093781e+00],
#        [-1.15801526e+00, -5.02054348e-01],
#        [-5.48084186e-01, -7.73994587e-01],
#        [ 9.31173931e-01,  1.18508509e+00],
#        [-3.55289882e-01, -8.50304348e-01],
#        [ 8.75088315e-01,  7.14739474e-01],
#        [ 4.85994355e-01, -4.42393990e-01],
#        [ 1.12396824e+00,  9.85292262e-01],
#        [-2.15075842e-01, -6.26924866e-01],
#        [ 8.92615070e-01,  2.30519355e-01],
#        [ 1.08190402e+00,  1.17398549e+00],
#        [ 5.21047865e-01, -6.76873073e-01],
#        [ 8.33024103e-01,  8.24348039e-01],
#        [ 1.31953906e-01,  4.38636885e-01],
#        [-3.20236372e-01, -6.73462830e-03],
#        [ 9.87259547e-01,  8.84008398e-01],
#        [ 4.12381985e-01,  2.15257403e-01],
#        [ 1.12396824e+00,  3.00125740e+00],
#        [-8.00469457e-01,  1.13022242e-02],
#        [-1.73289282e+00, -6.92135025e-01],
#        [-9.93992597e-02, -5.25204848e-02],
#        [ 7.97970593e-01,  1.26896744e-02],
#        [-8.95113934e-01, -4.59043392e-01],
#        [-1.09141359e+00,  4.32135788e-02],
#        [-7.79437351e-01,  9.31617858e-02],
#        [ 1.12396824e+00,  2.47125142e+00],
#        [ 1.12396824e+00,  1.01304127e+00],
#        [ 9.13647176e-01,  4.66385889e-01],
#        [-2.14301889e+00, -1.28318881e+00],
#        [ 1.08190402e+00,  6.02356008e-01],
#        [ 1.07416449e-01,  7.42488478e-01],
#        [ 1.12396824e+00,  1.04495262e+00],
#        [ 8.08486646e-01,  6.81876823e-02],
#        [-1.25967044e+00, -8.61403949e-01],
#        [-6.63760769e-01, -9.33551359e-01],
#        [ 2.26598382e-01, -8.12843192e-01],
#        [-1.07739219e+00, -1.13611909e+00],
#        [ 1.01880771e+00,  6.00968558e-01],
#        [ 1.28448555e-01, -1.11669479e+00],
#        [-1.76794633e+00, -4.02157934e-01],
#        [ 7.73433136e-01,  5.05234494e-01],
#        [ 9.38184633e-01,  7.71624932e-01],
#        [ 1.04685051e+00,  2.29088290e+00],
#        [ 1.07839867e+00,  7.42488478e-01],
#        [-1.17203666e+00, -6.61611121e-01],
#        [ 9.62722090e-01,  3.12378917e-01],
#        [-1.21760623e+00, -1.24434020e+00],
#        [ 8.64572262e-01,  3.31803220e-01],
#        [-1.71186071e+00, -4.89567297e-01],
#        [-2.10796538e+00, -1.00708622e+00],
#        [ 9.83754196e-01,  9.14532302e-01],
#        [-2.25591895e-01, -2.63412915e-01],
#        [-9.26662093e-01, -5.56164906e-01]])

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred)
mape
# Out:
# 0.2382909630228522

# %%
intercept = regressor.intercept_
intercept
# Out:
# array([33.26495503])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# Đường dẫn tới file "boston.csv"
file_path = "boston.csv"

# Đọc file CSV bằng pandas
data = pd.read_csv(file_path)

# Chuẩn bị dữ liệu đầu vào và đầu ra
X = data[['age', 'lstat']]
y = data['medv']

# Khởi tạo StandardScaler
scaler = StandardScaler()

# Chuẩn hóa dữ liệu đầu vào
X_scaled = scaler.fit_transform(X)

# Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.1, random_state=10)

# Xây dựng mô hình hồi quy tuyến tính
model = LinearRegression()

# Huấn luyện mô hình trên tập huấn luyện
model.fit(X_train, y_train)

# Dự báo giá trị medv
X_input = [[37.5, 4.65]]
X_input_scaled = scaler.transform(X_input)
prediction = model.predict(X_input_scaled)

# In giá trị dự báo medv
print("Giá trị dự báo medv:", prediction[0])
# Out:
# Giá trị dự báo medv: 29.454798629362067
# C:\Users\THANH DUOC\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
