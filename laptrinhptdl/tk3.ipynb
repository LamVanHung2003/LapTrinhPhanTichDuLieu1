# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from apyori import apriori
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

# %%
df=pd.read_csv('data-quizth03.csv')
df
# Out:
#      CartCode  Total  Discount  CustomerSalary  CustomerAge  \
# 0          C0    100      0.09            1472           29
# 1          C1     75      0.17            2113           24
# 2          C2    162      0.06            1015           39
# 3          C3     94      0.03            2123           56
# 4          C4    114      0.25            1631           33
# ...       ...    ...       ...             ...          ...
# 7496    C7496    122      0.25            1191           52
# 7497    C7497    206      0.09            1087           42
# 7498    C7498    199      0.12            1420           59
# 7499    C7499     82      0.23            1586           56
# 7500    C7500    114      0.22            1276           31
#
#                                           ListOfProduct
# 0     shrimp>almonds>avocado>vegetables mix>green gr...
# 1                                burgers>meatballs>eggs
# 2                                               chutney
# 3                                        turkey>avocado
# 4     mineral water>milk>energy bar>whole wheat rice...
# ...                                                 ...
# 7496                      butter>light mayo>fresh bread
# 7497  burgers>frozen vegetables>eggs>french fries>ma...
# 7498                                            chicken
# 7499                                 escalope>green tea
# 7500    eggs>frozen smoothie>yogurt cake>low fat yogurt
#
# [7501 rows x 6 columns]

# %%
records = []
for i in range(0, 7501):
    records.append([str(df.values[i,j]) for j in range(0, 6)])

# %%
records
# Out:
# [['C0',
#   '100',
#   '0.09',
#   '1472',
#   '29',
#   'shrimp>almonds>avocado>vegetables mix>green grapes>whole weat flour>yams>cottage cheese>energy drink>tomato juice>low fat yogurt>green tea>honey>salad>mineral water>salmon>antioxydant juice>frozen smoothie>spinach>olive oil'],
#  ['C1', '75', '0.17', '2113', '24', 'burgers>meatballs>eggs'],
#  ['C2', '162', '0.06', '1015', '39', 'chutney'],
#  ['C3', '94', '0.03', '2123', '56', 'turkey>avocado'],
#  ['C4',
#   '114',
#   '0.25',
#   '1631',
#   '33',
#   'mineral water>milk>energy bar>whole wheat rice>green tea'],
#  ['C5', '161', '0.09', '2109', '58', 'low fat yogurt'],
#  ['C6', '102', '0.11', '619', '25', 'whole wheat pasta>french fries'],
#  ['C7', '132', '0.11', '2409', '59', 'soup>light cream>shallot'],
#  ['C8', '201', '0.18', '613', '32', 'frozen vegetables>spaghetti>green tea'],
#  ['C9', '74', '0.13', '2195', '55', 'french fries'],
#  ['C10', '140', '0.22', '1541', '51', 'eggs>pet food'],
#  ['C11', '64', '0.17', '714', '27', 'cookies'],
#  ['C12',
#   '175',
#   '0.24',
#   '2267',
#   '33',
#   'turkey>burgers>mineral water>eggs>cooking oil'],
#  ['C13', '103', '0.2', '938', '51', 'spaghetti>champagne>cookies'],
#  ['C14', '216', '0.05', '1117', '21', 'mineral water>salmon'],
#  ['C15', '238', '0.2', '1213', '42', 'mineral water'],
#  ['C16',
#   '57',
#   '0.25',
#   '1961',
#   '25',
#   'shrimp>chocolate>chicken>honey>oil>cooking oil>low fat yogurt'],
#  ['C17', '211', '0.19', '987', '54', 'turkey>eggs'],
#  ['C18',
#   '129',
#   '0.15',
#   '1939',
#   '34',
#   'turkey>fresh tuna>tomatoes>spaghetti>mineral water>black tea>salmon>eggs>chicken>extra dark chocolate'],
#  ['C19',
#   '160',
#   '0.1',
#   '1412',
#   '49',
#   'meatballs>milk>honey>french fries>protein bar'],
#  ['C20',
#   '142',
#   '0.16',
#   '709',
#   '46',
#   'red wine>shrimp>pasta>pepper>eggs>chocolate>shampoo'],
#  ['C21', '227', '0.02', '655', '42', 'rice>sparkling water'],
#  ['C22',
#   '148',
#   '0.15',
#   '1105',
#   '31',
#   'spaghetti>mineral water>ham>body spray>pancakes>green tea'],
#  ['C23',
#   '86',
#   '0.1',
#   '1892',
#   '49',
#   'burgers>grated cheese>shrimp>pasta>avocado>honey>white wine>toothpaste'],
#  ['C24', '74', '0.21', '2430', '54', 'eggs'],
#  ['C25',
#   '73',
#   '0.1',
#   '660',
#   '50',
#   'parmesan cheese>spaghetti>soup>avocado>milk>fresh bread'],
#  ['C26',
#   '215',
#   '0.06',
#   '1704',
#   '49',
#   'ground beef>spaghetti>mineral water>milk>energy bar>black tea>salmon>frozen smoothie>escalope'],
#  ['C27', '75', '0.15', '2155', '58', 'sparkling water'],
#  ['C28',
#   '210',
#   '0.01',
#   '961',
#   '59',
#   'mineral water>eggs>chicken>chocolate>french fries'],
#  ['C29',
#   '250',
#   '0.0',
#   '1641',
#   '54',
#   'frozen vegetables>spaghetti>yams>mineral water'],
#  ['C30',
#   '61',
#   '0.01',
#   '1143',
#   '47',
#   'herb & pepper>tomato sauce>light cream>magazines'],
#  ['C31', '64', '0.03', '1693', '41', 'mineral water>chocolate>avocado>eggs'],
#  ['C32', '207', '0.02', '1534', '27', 'turkey>french fries>strawberries'],
#  ['C33',
#   '51',
#   '0.04',
#   '2409',
#   '32',
#   'frozen vegetables>strong cheese>chocolate'],
#  ['C34', '131', '0.0', '2236', '36', 'cookies'],
#  ['C35', '98', '0.21', '1286', '21', 'pickles>spaghetti>salmon>escalope'],
#  ['C36', '215', '0.07', '986', '45', 'energy bar>french fries'],
#  ['C37', '74', '0.08', '2377', '44', 'red wine>ground beef>mineral water'],
#  ['C38', '141', '0.07', '1779', '44', 'mineral water>cake>cottage cheese'],
#  ['C39', '154', '0.23', '572', '38', 'pickles>champagne>green tea'],
#  ['C40', '58', '0.09', '1186', '59', 'spaghetti'],
#  ['C41',
#   '199',
#   '0.09',
#   '1561',
#   '43',
#   'fresh tuna>frozen vegetables>spaghetti>mineral water>honey>whole wheat rice>frozen smoothie>escalope'],
#  ['C42', '167', '0.06', '1461', '50', 'spaghetti'],
#  ['C43',
#   '96',
#   '0.14',
#   '1464',
#   '48',
#   'soup>meatballs>hot dogs>sparkling water'],
#  ['C44', '201', '0.19', '937', '44', 'escalope'],
#  ['C45',
#   '144',
#   '0.14',
#   '701',
#   '55',
#   'soup>avocado>french fries>hot dogs>brownies>body spray>pancakes>green tea'],
#  ['C46',
#   '192',
#   '0.21',
#   '1091',
#   '51',
#   'mineral water>chicken>cereals>clothes accessories'],
#  ['C47', '221', '0.15', '1546', '22', 'mineral water>bug spray'],
#  ['C48', '208', '0.05', '693', '45', 'avocado>muffins'],
#  ['C49', '181', '0.11', '1424', '34', 'burgers>black tea>green tea'],
#  ['C50',
#   '235',
#   '0.1',
#   '2223',
#   '57',
#   'spaghetti>chocolate>brownies>white wine>green tea'],
#  ['C51', '210', '0.07', '1242', '49', 'fresh tuna>mineral water>eggs'],
#  ['C52', '70', '0.01', '2397', '27', 'spaghetti>muffins'],
#  ['C53', '171', '0.22', '1105', '23', 'spaghetti>chocolate'],
#  ['C54', '117', '0.09', '1280', '28', 'french fries>escalope>champagne'],
#  ['C55', '226', '0.19', '1340', '30', 'tomato sauce>light mayo'],
#  ['C56',
#   '117',
#   '0.04',
#   '1558',
#   '32',
#   'turkey>fresh tuna>frozen vegetables>tomatoes>ground beef>spaghetti>mineral water>chocolate>soup>milk>olive oil'],
#  ['C57', '118', '0.14', '1616', '32', 'eggs>cookies'],
#  ['C58',
#   '143',
#   '0.02',
#   '2268',
#   '54',
#   'soup>chicken>gums>soda>body spray>energy drink>green tea'],
#  ['C59',
#   '102',
#   '0.23',
#   '1797',
#   '39',
#   'turkey>frozen vegetables>mineral water>cider>cooking oil>green tea'],
#  ['C60', '98', '0.07', '644', '31', 'spaghetti'],
#  ['C61', '63', '0.21', '1187', '41', 'clothes accessories'],
#  ['C62', '239', '0.14', '649', '20', 'energy drink'],
#  ['C63',
#   '241',
#   '0.07',
#   '2188',
#   '31',
#   'soup>bug spray>shallot>protein bar>green tea'],
#  ['C64', '186', '0.14', '1002', '53', 'turkey>eggs'],
#  ['C65', '158', '0.11', '1553', '26', 'french fries'],
#  ['C66', '105', '0.17', '1371', '53', 'chocolate>milk'],
#  ['C67',
#   '179',
#   '0.19',
#   '1853',
#   '30',
#   'herb & pepper>whole wheat pasta>ground beef>mineral water>avocado>cider>whole wheat rice'],
#  ['C68', '170', '0.14', '2181', '25', 'cookies'],
#  ['C69', '160', '0.13', '2137', '32', 'shrimp>pasta'],
#  ['C70',
#   '156',
#   '0.22',
#   '1221',
#   '33',
#   'grated cheese>herb & pepper>tomatoes>tomato sauce>corn'],
#  ['C71', '170', '0.08', '2191', '51', 'burgers>escalope>shallot'],
#  ['C72', '170', '0.11', '608', '57', 'cookies'],
#  ['C73', '149', '0.19', '1386', '23', 'yogurt cake'],
#  ['C74', '212', '0.03', '945', '55', 'soup>eggs'],
#  ['C75', '221', '0.12', '2266', '50', 'cookies'],
#  ['C76',
#   '141',
#   '0.02',
#   '1234',
#   '23',
#   'mineral water>chocolate>low fat yogurt'],
#  ['C77', '169', '0.22', '1432', '39', 'eggs>strawberries'],
#  ['C78',
#   '92',
#   '0.01',
#   '1449',
#   '57',
#   'grated cheese>ground beef>spaghetti>mineral water>white wine'],
#  ['C79', '190', '0.04', '1513', '53', 'mint'],
#  ['C80', '91', '0.1', '778', '34', 'eggs>cake>french fries'],
#  ['C81',
#   '226',
#   '0.09',
#   '2489',
#   '36',
#   'burgers>spaghetti>milk>french fries>green tea'],
#  ['C82',
#   '65',
#   '0.01',
#   '2218',
#   '51',
#   'mineral water>energy bar>butter>french fries'],
#  ['C83',
#   '205',
#   '0.1',
#   '1090',
#   '30',
#   'burgers>grated cheese>herb & pepper>mineral water>eggs>cooking oil'],
#  ['C84', '150', '0.08', '2309', '39', 'energy bar'],
#  ['C85', '201', '0.23', '831', '56', 'energy bar>energy drink'],
#  ['C86', '181', '0.1', '818', '25', 'chocolate>frozen smoothie'],
#  ['C87', '168', '0.05', '807', '59', 'low fat yogurt'],
#  ['C88', '98', '0.24', '2020', '24', 'asparagus>salad'],
#  ['C89',
#   '170',
#   '0.17',
#   '1882',
#   '53',
#   'burgers>french fries>low fat yogurt>green tea'],
#  ['C90', '239', '0.04', '2483', '51', 'low fat yogurt'],
#  ['C91',
#   '193',
#   '0.16',
#   '735',
#   '25',
#   'burgers>herb & pepper>shrimp>pasta>spaghetti>mineral water>meatballs>olive oil>energy bar>french wine>eggs>salt'],
#  ['C92', '249', '0.03', '2090', '36', 'champagne>low fat yogurt'],
#  ['C93', '87', '0.05', '541', '32', 'champagne'],
#  ['C94',
#   '91',
#   '0.24',
#   '2209',
#   '33',
#   'burgers>almonds>eggs>french fries>cookies>green tea'],
#  ['C95', '105', '0.1', '1955', '33', 'ham>soup>escalope>body spray'],
#  ['C96',
#   '69',
#   '0.13',
#   '1108',
#   '52',
#   'turkey>ham>frozen vegetables>pepper>oil>extra dark chocolate>tea>magazines'],
#  ['C97', '63', '0.15', '770', '42', 'muffins>eggs>cookies'],
#  ['C98', '186', '0.18', '608', '42', 'cookies'],
#  ['C99',
#   '127',
#   '0.08',
#   '1881',
#   '27',
#   'frozen vegetables>whole wheat pasta>ground beef>spaghetti>chocolate>green tea'],
#  ['C100',
#   '119',
#   '0.14',
#   '2205',
#   '25',
#   'mineral water>barbecue sauce>chocolate'],
#  ['C101',
#   '216',
#   '0.07',
#   '2247',
#   '31',
#   'burgers>herb & pepper>energy bar>almonds>eggs>corn>mayonnaise>zucchini'],
#  ['C102',
#   '231',
#   '0.22',
#   '1557',
#   '28',
#   'turkey>burgers>ground beef>chocolate>soup>almonds>eggs>hot dogs>cottage cheese'],
#  ['C103', '104', '0.02', '2244', '58', 'ham>spaghetti>chocolate>eggs'],
#  ['C104',
#   '151',
#   '0.11',
#   '592',
#   '58',
#   'ground beef>energy bar>pet food>carrots>protein bar'],
#  ['C105',
#   '178',
#   '0.25',
#   '2174',
#   '38',
#   'ground beef>tomato sauce>spaghetti>mineral water>almonds>eggs'],
#  ['C106',
#   '110',
#   '0.04',
#   '806',
#   '39',
#   'mineral water>olive oil>gums>cooking oil'],
#  ['C107',
#   '67',
#   '0.04',
#   '1587',
#   '58',
#   'shrimp>pasta>mineral water>soup>avocado>milk>olive oil>green grapes>eggs>bug spray'],
#  ['C108',
#   '106',
#   '0.06',
#   '2154',
#   '57',
#   'shrimp>pasta>soup>cake>cooking oil>chicken>light mayo>low fat yogurt'],
#  ['C109',
#   '192',
#   '0.09',
#   '1840',
#   '23',
#   'spaghetti>mineral water>chocolate>french fries>champagne>escalope>mushroom cream sauce>fresh bread'],
#  ['C110', '155', '0.0', '1619', '48', 'shrimp>pasta>mineral water>eggs'],
#  ['C111', '172', '0.04', '796', '51', 'burgers>oil>tomato juice>fresh bread'],
#  ['C112',
#   '198',
#   '0.02',
#   '654',
#   '57',
#   'french wine>eggs>chocolate>low fat yogurt'],
#  ['C113', '233', '0.11', '1144', '59', 'chicken>eggs>french fries>pancakes'],
#  ['C114',
#   '56',
#   '0.05',
#   '981',
#   '21',
#   'turkey>herb & pepper>salmon>white wine>candy bars'],
#  ['C115',
#   '67',
#   '0.12',
#   '881',
#   '22',
#   'grated cheese>spaghetti>olive oil>eggs>french fries>green tea'],
#  ['C116', '213', '0.14', '1599', '29', 'mineral water>energy bar'],
#  ['C117', '204', '0.03', '1258', '52', 'eggs>french fries'],
#  ['C118',
#   '55',
#   '0.22',
#   '1859',
#   '20',
#   'burgers>tomatoes>mineral water>soup>milk>almonds>eggs>chocolate>tomato juice'],
#  ['C119', '198', '0.2', '1237', '34', 'muffins'],
#  ['C120', '172', '0.02', '1062', '58', 'pasta'],
#  ['C121', '223', '0.08', '1027', '33', 'tomatoes>spaghetti>frozen smoothie'],
#  ['C122', '135', '0.21', '940', '46', 'ground beef>spaghetti>milk'],
#  ['C123', '53', '0.02', '1296', '21', 'french fries'],
#  ['C124', '209', '0.17', '1645', '28', 'chocolate>milk'],
#  ['C125',
#   '136',
#   '0.19',
#   '1154',
#   '25',
#   'burgers>shrimp>pasta>frozen vegetables>spaghetti>mineral water>milk>eggs>chocolate>french fries>pancakes>low fat yogurt'],
#  ['C126',
#   '91',
#   '0.16',
#   '1562',
#   '55',
#   'ground beef>mineral water>antioxydant juice>protein bar'],
#  ['C127',
#   '176',
#   '0.2',
#   '651',
#   '33',
#   'grated cheese>whole wheat pasta>ground beef>spaghetti>cake>energy drink'],
#  ['C128', '239', '0.03', '1431', '58', 'grated cheese'],
#  ['C129', '99', '0.22', '554', '59', 'pancakes'],
#  ['C130', '166', '0.23', '1044', '49', 'frozen smoothie'],
#  ['C131', '86', '0.19', '1528', '26', 'carrots>green tea'],
#  ['C132', '178', '0.17', '596', '27', 'chocolate'],
#  ['C133',
#   '186',
#   '0.11',
#   '1760',
#   '32',
#   'turkey>burgers>chocolate>olive oil>eggs>cooking oil>corn'],
#  ['C134',
#   '190',
#   '0.05',
#   '2288',
#   '51',
#   'frozen vegetables>tomatoes>pepper>spaghetti>mineral water>pancakes>chicken>chili>tea>french fries>tomato juice>fresh bread'],
#  ['C135', '163', '0.18', '632', '50', 'cookies'],
#  ['C136', '111', '0.2', '2292', '51', 'ground beef'],
#  ['C137',
#   '171',
#   '0.16',
#   '761',
#   '31',
#   'turkey>eggs>chocolate>frozen smoothie>tomato juice'],
#  ['C138',
#   '96',
#   '0.1',
#   '602',
#   '36',
#   'frozen vegetables>cooking oil>mashed potato'],
#  ['C139',
#   '223',
#   '0.0',
#   '1131',
#   '58',
#   'frozen vegetables>ground beef>tomato sauce>mineral water>meatballs>olive oil>light cream>tomato juice'],
#  ['C140',
#   '112',
#   '0.12',
#   '517',
#   '56',
#   'red wine>spaghetti>mineral water>soup>milk>eggs>cake>gums>cooking oil>chocolate>frozen smoothie'],
#  ['C141',
#   '229',
#   '0.04',
#   '530',
#   '57',
#   'chocolate>tomatoes>spaghetti>mineral water>avocado>milk>olive oil>eggs>rice>french fries>brownies'],
#  ['C142',
#   '236',
#   '0.24',
#   '833',
#   '60',
#   'chocolate>shrimp>pasta>frozen vegetables>ground beef>mineral water>nonfat milk>eggs'],
#  ['C143',
#   '212',
#   '0.19',
#   '1582',
#   '52',
#   'turkey>shrimp>pasta>pepper>spaghetti>mineral water>eggs>chicken>french fries'],
#  ['C144', '182', '0.18', '1977', '37', 'cookies'],
#  ['C145', '85', '0.0', '582', '54', 'turkey>tomatoes>cake'],
#  ['C146',
#   '175',
#   '0.07',
#   '604',
#   '22',
#   'yams>mineral water>soup>milk>pancakes>whole wheat rice>barbecue sauce>carrots>chocolate>champagne'],
#  ['C147', '223', '0.15', '1732', '38', 'rice'],
#  ['C148', '217', '0.16', '1658', '55', 'chocolate>milk'],
#  ['C149',
#   '174',
#   '0.18',
#   '909',
#   '54',
#   'shrimp>pasta>frozen vegetables>water spray'],
#  ['C150',
#   '153',
#   '0.1',
#   '1048',
#   '45',
#   'burgers>mineral water>milk>eggs>whole wheat rice>mint'],
#  ['C151',
#   '72',
#   '0.17',
#   '2403',
#   '46',
#   'mineral water>vegetables mix>cake>frozen smoothie>brownies'],
#  ['C152', '164', '0.18', '1630', '36', 'cookies'],
#  ['C153', '141', '0.15', '2159', '58', 'shrimp>pasta>chicken>chocolate bread'],
#  ['C154', '205', '0.25', '2396', '22', 'shallot'],
#  ['C155',
#   '248',
#   '0.02',
#   '890',
#   '46',
#   'shrimp>pasta>spaghetti>eggs>hot dogs>green tea'],
#  ['C156', '61', '0.06', '513', '31', 'burgers'],
#  ['C157',
#   '128',
#   '0.03',
#   '2196',
#   '30',
#   'red wine>ground beef>spaghetti>mineral water>milk>olive oil>strong cheese>light cream>cooking oil'],
#  ['C158',
#   '101',
#   '0.04',
#   '920',
#   '53',
#   'burgers>grated cheese>spaghetti>avocado>milk>oil>french fries'],
#  ['C159',
#   '155',
#   '0.14',
#   '2222',
#   '42',
#   'herb & pepper>whole wheat pasta>ground beef>mineral water>olive oil'],
#  ['C160', '248', '0.11', '806', '27', 'shrimp>pasta>yams>milk>chocolate'],
#  ['C161', '67', '0.01', '2108', '56', 'butter>green tea'],
#  ['C162', '70', '0.23', '1938', '48', 'light mayo'],
#  ['C163', '162', '0.1', '863', '45', 'low fat yogurt'],
#  ['C164',
#   '216',
#   '0.2',
#   '1691',
#   '43',
#   'herb & pepper>shrimp>pasta>spaghetti>milk'],
#  ['C165', '126', '0.18', '1022', '59', 'burgers>eggs'],
#  ['C166',
#   '63',
#   '0.17',
#   '1664',
#   '48',
#   'turkey>herb & pepper>ground beef>soup>avocado>milk>black tea>eggs>barbecue sauce>carrots>cookies>tomato juice>fresh bread'],
#  ['C167', '200', '0.13', '520', '50', 'cookies'],
#  ['C168', '83', '0.22', '1870', '32', 'escalope'],
#  ['C169',
#   '149',
#   '0.19',
#   '650',
#   '20',
#   'pepper>french fries>strawberries>pancakes>low fat yogurt'],
#  ['C170',
#   '174',
#   '0.22',
#   '2064',
#   '28',
#   'frozen vegetables>yams>chicken>honey>light mayo'],
#  ['C171', '177', '0.09', '1823', '24', 'chocolate>champagne'],
#  ['C172',
#   '163',
#   '0.23',
#   '1340',
#   '57',
#   'herb & pepper>honey>cake>rice>protein bar'],
#  ['C173',
#   '67',
#   '0.23',
#   '1840',
#   '60',
#   'burgers>chocolate>frozen vegetables>ground beef>mineral water>milk>light mayo>asparagus'],
#  ['C174',
#   '228',
#   '0.11',
#   '1083',
#   '58',
#   'chocolate>mineral water>corn>cottage cheese>green tea'],
#  ['C175', '70', '0.1', '1171', '39', 'muffins'],
#  ['C176', '63', '0.0', '1677', '34', 'ham>french wine>escalope'],
#  ['C177',
#   '205',
#   '0.05',
#   '846',
#   '20',
#   'spaghetti>milk>whole wheat rice>mint green tea'],
#  ['C178', '139', '0.11', '1238', '31', 'chocolate>body spray'],
#  ['C179',
#   '224',
#   '0.02',
#   '1897',
#   '57',
#   'frozen vegetables>french fries>hot dogs'],
#  ['C180', '178', '0.12', '1616', '45', 'candy bars'],
#  ['C181',
#   '75',
#   '0.12',
#   '1214',
#   '26',
#   'burgers>shrimp>pasta>milk>green tea>french fries>cookies>white wine'],
#  ['C182', '225', '0.02', '2204', '58', 'parmesan cheese>ground beef'],
#  ['C183', '231', '0.16', '1463', '31', 'pancakes>whole wheat rice>candy bars'],
#  ['C184', '133', '0.05', '1859', '58', 'eggs>eggplant>cookies'],
#  ['C185', '242', '0.15', '1129', '57', 'frozen vegetables>mineral water'],
#  ['C186', '97', '0.14', '992', '38', 'chocolate'],
#  ['C187',
#   '224',
#   '0.1',
#   '1295',
#   '31',
#   'turkey>spaghetti>milk>whole wheat rice>chocolate'],
#  ['C188',
#   '243',
#   '0.12',
#   '1564',
#   '31',
#   'whole wheat pasta>ground beef>spaghetti>soup>meatballs>chicken>blueberries>cooking oil>champagne>yogurt cake>protein bar'],
#  ['C189', '170', '0.18', '1563', '39', 'cooking oil>tomato juice'],
#  ['C190',
#   '206',
#   '0.12',
#   '1460',
#   '25',
#   'frozen vegetables>milk>eggs>french fries>green tea'],
#  ['C191',
#   '234',
#   '0.12',
#   '987',
#   '46',
#   'fresh tuna>spaghetti>olive oil>french wine>eggs>french fries>champagne>pancakes>light mayo'],
#  ['C192', '157', '0.04', '1709', '24', 'red wine>honey>hot dogs'],
#  ['C193',
#   '149',
#   '0.23',
#   '672',
#   '38',
#   'milk>bacon>eggs>french fries>fresh bread'],
#  ['C194', '81', '0.05', '946', '36', 'french fries>yogurt cake'],
#  ['C195', '169', '0.09', '2493', '60', 'milk'],
#  ['C196', '226', '0.02', '677', '42', 'french fries'],
#  ['C197', '217', '0.08', '1500', '49', 'chocolate'],
#  ['C198', '110', '0.18', '524', '39', 'burgers>ham>red wine'],
#  ['C199',
#   '241',
#   '0.2',
#   '1925',
#   '24',
#   'shrimp>pasta>tomatoes>energy bar>french wine>antioxydant juice>french fries>frozen smoothie>brownies'],
#  ['C200', '216', '0.08', '1509', '52', 'green tea'],
#  ['C201', '197', '0.19', '2469', '54', 'low fat yogurt'],
#  ['C202',
#   '227',
#   '0.1',
#   '2113',
#   '51',
#   'turkey>spaghetti>mineral water>soup>spinach>soda>energy drink>salt'],
#  ['C203', '163', '0.18', '500', '55', 'turkey>eggs'],
#  ['C204', '95', '0.14', '1124', '33', 'bug spray>hot dogs'],
#  ['C205', '100', '0.18', '2392', '55', 'oil'],
#  ['C206',
#   '84',
#   '0.2',
#   '1926',
#   '46',
#   'soup>energy bar>chicken>eggs>cake>french fries>body spray>strawberries'],
#  ['C207', '132', '0.07', '2370', '46', 'spaghetti>chocolate>yogurt cake'],
#  ['C208', '141', '0.07', '2109', '32', 'turkey>mineral water>meatballs'],
#  ['C209',
#   '163',
#   '0.11',
#   '597',
#   '35',
#   'ground beef>mineral water>chocolate>fromage blanc>bacon>hot dogs'],
#  ['C210',
#   '132',
#   '0.24',
#   '670',
#   '33',
#   'frozen vegetables>mineral water>vegetables mix>escalope'],
#  ['C211', '108', '0.0', '1683', '53', 'herb & pepper>red wine>tomatoes'],
#  ['C212',
#   '102',
#   '0.08',
#   '1767',
#   '43',
#   'whole wheat pasta>olive oil>cereals>brownies>green tea'],
#  ['C213', '146', '0.03', '1711', '42', 'cookies'],
#  ['C214',
#   '140',
#   '0.19',
#   '1809',
#   '43',
#   'olive oil>cookies>mushroom cream sauce'],
#  ['C215',
#   '115',
#   '0.03',
#   '1304',
#   '33',
#   'ground beef>pancakes>cooking oil>gluten free bar>light mayo'],
#  ['C216', '185', '0.04', '1198', '54', 'mineral water>french fries'],
#  ['C217', '238', '0.03', '1098', '41', 'herb & pepper'],
#  ['C218', '67', '0.16', '909', '43', 'salmon'],
#  ['C219', '108', '0.17', '1644', '51', 'eggs>escalope'],
#  ['C220', '249', '0.1', '1138', '29', 'mineral water>tomato juice'],
#  ['C221', '158', '0.01', '635', '52', 'mineral water'],
#  ['C222', '137', '0.13', '1232', '41', 'shrimp>mineral water>soup>black tea'],
#  ['C223', '50', '0.24', '747', '32', 'cake>frozen smoothie'],
#  ['C224',
#   '173',
#   '0.04',
#   '1002',
#   '34',
#   'turkey>burgers>grated cheese>tomatoes>chocolate>fromage blanc>honey>whole wheat rice'],
#  ['C225',
#   '204',
#   '0.21',
#   '2284',
#   '49',
#   'frozen vegetables>ground beef>mineral water>olive oil>pancakes'],
#  ['C226',
#   '138',
#   '0.14',
#   '1086',
#   '44',
#   'turkey>burgers>ground beef>milk>olive oil>cake>fresh bread'],
#  ['C227',
#   '61',
#   '0.01',
#   '536',
#   '27',
#   'whole wheat pasta>ground beef>spaghetti>yams>mineral water>soup>chutney>cereals>energy drink>protein bar'],
#  ['C228',
#   '136',
#   '0.03',
#   '2274',
#   '27',
#   'eggs>whole wheat rice>cake>green tea>escalope'],
#  ['C229',
#   '65',
#   '0.16',
#   '1763',
#   '39',
#   'ground beef>yams>soup>avocado>salmon>green tea'],
#  ['C230', '144', '0.11', '1176', '22', 'milk'],
#  ['C231', '196', '0.06', '707', '20', 'spaghetti>chocolate'],
#  ['C232', '176', '0.09', '1716', '48', 'whole wheat pasta>honey'],
#  ['C233', '190', '0.19', '1275', '51', 'whole wheat pasta>green tea'],
#  ['C234',
#   '153',
#   '0.0',
#   '695',
#   '32',
#   'spaghetti>meatballs>vegetables mix>chocolate'],
#  ['C235', '167', '0.03', '1746', '21', 'eggs>low fat yogurt'],
#  ['C236',
#   '109',
#   '0.16',
#   '2225',
#   '56',
#   'fresh tuna>shrimp>pasta>mineral water>olive oil>eggs>cake>brownies>tomato juice'],
#  ['C237',
#   '215',
#   '0.0',
#   '2158',
#   '29',
#   'mineral water>green grapes>hot dogs>fresh bread'],
#  ['C238',
#   '56',
#   '0.12',
#   '1308',
#   '34',
#   'frozen vegetables>meatballs>eggs>chocolate'],
#  ['C239', '236', '0.01', '1081', '32', 'chocolate'],
#  ['C240', '112', '0.02', '1304', '43', 'meatballs>milk'],
#  ['C241', '203', '0.22', '1426', '35', 'low fat yogurt'],
#  ['C242', '115', '0.15', '2070', '25', 'green tea'],
#  ['C243', '165', '0.23', '1227', '32', 'escalope>pasta'],
#  ['C244',
#   '191',
#   '0.24',
#   '717',
#   '49',
#   'pepper>chocolate>olive oil>french wine>salmon>rice>light mayo>fresh bread>magazines'],
#  ['C245',
#   '68',
#   '0.04',
#   '2162',
#   '29',
#   'red wine>french wine>vegetables mix>rice>clothes accessories>hot dogs>green tea'],
#  ['C246',
#   '175',
#   '0.2',
#   '2055',
#   '42',
#   'burgers>dessert wine>spaghetti>chicken>cake>protein bar>green tea'],
#  ['C247', '186', '0.25', '1398', '38', 'french wine>cake>fresh bread'],
#  ['C248',
#   '55',
#   '0.11',
#   '833',
#   '49',
#   'burgers>frozen vegetables>flax seed>eggs'],
#  ['C249', '149', '0.01', '1376', '23', 'red wine'],
#  ['C250',
#   '125',
#   '0.06',
#   '1141',
#   '58',
#   'pepper>mineral water>energy bar>green grapes'],
#  ['C251',
#   '249',
#   '0.13',
#   '563',
#   '31',
#   'milk>eggs>cake>chocolate>french fries>green tea'],
#  ['C252', '201', '0.13', '2027', '45', 'french fries'],
#  ['C253', '209', '0.05', '562', '58', 'almonds'],
#  ['C254', '53', '0.08', '1604', '21', 'burgers>mineral water>green tea'],
#  ['C255', '124', '0.04', '2098', '46', 'milk>pancakes'],
#  ['C256', '138', '0.13', '503', '44', 'pancakes>eggs>salt>tomato juice'],
#  ['C257', '139', '0.08', '757', '49', 'mineral water'],
#  ['C258',
#   '182',
#   '0.05',
#   '2477',
#   '36',
#   'ham>spaghetti>mineral water>olive oil'],
#  ['C259', '108', '0.01', '1463', '25', 'salt>tomato juice>fresh bread'],
#  ['C260', '201', '0.02', '843', '36', 'spaghetti>mushroom cream sauce'],
#  ['C261', '97', '0.24', '782', '31', 'spaghetti>mineral water>eggs>pet food'],
#  ['C262', '205', '0.07', '1047', '43', 'frozen vegetables>spaghetti'],
#  ['C263', '121', '0.05', '983', '34', 'energy drink'],
#  ['C264', '102', '0.13', '1925', '25', 'muffins'],
#  ['C265', '244', '0.11', '1293', '48', 'turkey>milk'],
#  ['C266', '132', '0.04', '904', '28', 'cookies'],
#  ['C267', '83', '0.1', '1308', '47', 'chocolate'],
#  ['C268',
#   '179',
#   '0.21',
#   '2035',
#   '30',
#   'spaghetti>mineral water>eggs>cooking oil>chocolate>escalope'],
#  ['C269',
#   '96',
#   '0.07',
#   '915',
#   '49',
#   'shrimp>frozen vegetables>pepper>spaghetti>green tea'],
#  ['C270',
#   '239',
#   '0.16',
#   '1350',
#   '35',
#   'burgers>fresh tuna>red wine>mineral water>french fries>hand protein bar>low fat yogurt'],
#  ['C271',
#   '198',
#   '0.12',
#   '1628',
#   '23',
#   'pancakes>eggs>energy drink>fresh bread'],
#  ['C272',
#   '183',
#   '0.22',
#   '827',
#   '51',
#   'strong cheese>salmon>green tea>french fries>frozen smoothie>hot dogs'],
#  ['C273',
#   '183',
#   '0.01',
#   '1519',
#   '24',
#   'grated cheese>shrimp>pasta>tomatoes>milk>frozen smoothie>sandwich'],
#  ['C274',
#   '72',
#   '0.16',
#   '1297',
#   '38',
#   'herb & pepper>whole wheat pasta>olive oil>pancakes>eggs'],
#  ['C275', '111', '0.16', '1678', '38', 'spaghetti>antioxydant juice'],
#  ['C276',
#   '65',
#   '0.05',
#   '1955',
#   '39',
#   'chocolate>milk>almonds>eggs>strawberries>white wine'],
#  ['C277', '111', '0.02', '1933', '51', 'french fries>strawberries'],
#  ['C278', '67', '0.0', '1414', '28', 'mineral water'],
#  ['C279', '99', '0.12', '1697', '21', 'eggs'],
#  ['C280', '148', '0.16', '1104', '57', 'escalope'],
#  ['C281', '249', '0.08', '2053', '45', 'cake'],
#  ['C282',
#   '198',
#   '0.21',
#   '2275',
#   '60',
#   'whole wheat pasta>antioxydant juice>body spray>green tea'],
#  ['C283', '238', '0.09', '1380', '25', 'mineral water>oil>frozen smoothie'],
#  ['C284', '216', '0.18', '2381', '39', 'french fries>champagne'],
#  ['C285', '235', '0.22', '2298', '46', 'chocolate>french fries'],
#  ['C286', '110', '0.07', '1739', '51', 'frozen vegetables>spaghetti>eggs'],
#  ['C287', '235', '0.25', '756', '35', 'hot dogs'],
#  ['C288', '174', '0.11', '1504', '56', 'chocolate>cookies'],
#  ['C289', '122', '0.03', '1383', '23', 'pancakes'],
#  ['C290', '193', '0.17', '1599', '32', 'shrimp>butter>chicken>salmon'],
#  ['C291', '180', '0.08', '1315', '33', 'chocolate>cookies>babies food'],
#  ['C292',
#   '157',
#   '0.0',
#   '1973',
#   '22',
#   'pepper>spaghetti>cake>chocolate>french fries>fresh bread'],
#  ['C293', '113', '0.02', '594', '25', 'avocado>oil>cereals>french fries'],
#  ['C294',
#   '223',
#   '0.11',
#   '1224',
#   '48',
#   'herb & pepper>spaghetti>mineral water>spinach>eggs>oil>cooking oil>green tea>shampoo>tomato juice>low fat yogurt'],
#  ['C295',
#   '194',
#   '0.03',
#   '2246',
#   '29',
#   'herb & pepper>frozen vegetables>ground beef>pepper>spaghetti>mint green tea>french fries'],
#  ['C296', '120', '0.02', '2053', '27', 'french fries'],
#  ['C297', '89', '0.23', '1798', '42', 'green tea>tomato juice'],
#  ['C298', '185', '0.02', '534', '42', 'eggs>whole wheat rice>chocolate'],
#  ['C299',
#   '219',
#   '0.23',
#   '1414',
#   '23',
#   'grated cheese>herb & pepper>red wine>spaghetti>mineral water>salmon>eggs>cooking oil>green tea'],
#  ['C300',
#   '75',
#   '0.15',
#   '1027',
#   '29',
#   'french fries>cookies>shallot>tomato juice>fresh bread>low fat yogurt'],
#  ['C301',
#   '105',
#   '0.08',
#   '1411',
#   '40',
#   'burgers>fresh tuna>spaghetti>muffins>honey'],
#  ['C302',
#   '210',
#   '0.22',
#   '1162',
#   '40',
#   'herb & pepper>ground beef>spaghetti>eggs>chicken'],
#  ['C303',
#   '174',
#   '0.2',
#   '2382',
#   '59',
#   'grated cheese>muffins>tomato juice>mayonnaise'],
#  ['C304',
#   '117',
#   '0.17',
#   '2097',
#   '42',
#   'whole wheat pasta>yams>mineral water>muffins>frozen smoothie>hot dogs>energy drink'],
#  ['C305',
#   '173',
#   '0.14',
#   '598',
#   '25',
#   'burgers>spaghetti>soup>milk>olive oil>salmon>eggs>blueberries'],
#  ['C306', '224', '0.21', '1594', '31', 'chocolate>champagne>magazines'],
#  ['C307',
#   '111',
#   '0.24',
#   '1072',
#   '60',
#   'frozen vegetables>spaghetti>yams>mineral water>french wine>green grapes>rice>chocolate'],
#  ['C308', '224', '0.04', '1966', '51', 'tomato sauce>chocolate'],
#  ['C309', '189', '0.05', '2072', '56', 'milk>eggs'],
#  ['C310', '182', '0.21', '1916', '34', 'pet food'],
#  ['C311', '155', '0.23', '818', '59', 'yogurt cake'],
#  ['C312', '111', '0.2', '2201', '45', 'green tea'],
#  ['C313', '208', '0.14', '1450', '55', 'escalope>pasta'],
#  ['C314', '153', '0.22', '1655', '27', 'herb & pepper>ground beef'],
#  ['C315', '248', '0.16', '1364', '29', 'mineral water>honey>brownies'],
#  ['C316', '137', '0.11', '558', '46', 'turkey>eggs>cake>energy drink'],
#  ['C317',
#   '219',
#   '0.12',
#   '2149',
#   '56',
#   'turkey>burgers>dessert wine>ground beef>soup>salmon>eggs>gums>tomato juice>candy bars'],
#  ['C318', '96', '0.02', '2057', '32', 'spaghetti>mineral water>chicken'],
#  ['C319',
#   '248',
#   '0.0',
#   '1953',
#   '48',
#   'turkey>ground beef>carrots>french fries>melons'],
#  ['C320', '76', '0.09', '1788', '37', 'mineral water>eggs>low fat yogurt'],
#  ['C321', '230', '0.04', '939', '27', 'turkey>cooking oil>shampoo'],
#  ['C322', '187', '0.18', '2388', '43', 'spaghetti>hot dogs'],
#  ['C323', '164', '0.15', '1354', '56', 'chocolate>green tea'],
#  ['C324',
#   '221',
#   '0.22',
#   '1146',
#   '56',
#   'grated cheese>pepper>mineral water>chocolate>eggs>cake>mashed potato>tomato juice'],
#  ['C325', '170', '0.11', '1407', '44', 'chocolate'],
#  ['C326',
#   '121',
#   '0.03',
#   '564',
#   '33',
#   'spaghetti>olive oil>strong cheese>pancakes'],
#  ['C327',
#   '110',
#   '0.21',
#   '2496',
#   '57',
#   'red wine>mineral water>soup>rice>cookies'],
#  ['C328', '64', '0.01', '2051', '57', 'red wine>shrimp>spaghetti'],
#  ['C329', '110', '0.17', '617', '33', 'green tea'],
#  ['C330',
#   '111',
#   '0.24',
#   '1749',
#   '38',
#   'mineral water>chicken>french fries>frozen smoothie'],
#  ['C331', '50', '0.21', '1536', '44', 'muffins'],
#  ['C332', '244', '0.11', '2195', '41', 'cake>chocolate'],
#  ['C333',
#   '207',
#   '0.08',
#   '963',
#   '36',
#   'fresh tuna>tomatoes>mineral water>soup>avocado>meatballs>olive oil'],
#  ['C334', '175', '0.25', '2301', '20', 'turkey>french fries'],
#  ['C335',
#   '192',
#   '0.11',
#   '1218',
#   '33',
#   'burgers>turkey>herb & pepper>ground beef>pancakes>eggs>light cream>rice>champagne>fresh bread'],
#  ['C336', '108', '0.17', '504', '41', 'escalope'],
#  ['C337', '137', '0.24', '901', '50', 'chocolate>escalope>fresh bread'],
#  ['C338',
#   '67',
#   '0.06',
#   '1925',
#   '36',
#   'ham>spaghetti>french wine>vegetables mix>chocolate>french fries'],
#  ['C339', '200', '0.05', '865', '53', 'avocado>light mayo'],
#  ['C340', '172', '0.03', '891', '44', 'spaghetti>yams>butter>chocolate'],
#  ['C341', '246', '0.12', '589', '54', 'energy bar>eggs>french fries'],
#  ['C342', '170', '0.16', '2444', '31', 'fresh tuna>barbecue sauce>eggplant'],
#  ['C343', '177', '0.01', '568', '21', 'energy drink'],
#  ['C344',
#   '115',
#   '0.22',
#   '1633',
#   '28',
#   'whole wheat rice>french fries>hot dogs>green tea'],
#  ['C345', '167', '0.18', '872', '26', 'mineral water>chicken>green tea'],
#  ['C346', '50', '0.1', '1088', '54', 'eggs>cake>mushroom cream sauce'],
#  ['C347', '68', '0.12', '2087', '45', 'escalope'],
#  ['C348', '115', '0.1', '2322', '33', 'antioxydant juice>escalope'],
#  ['C349', '116', '0.17', '2394', '26', 'shrimp>spaghetti>french fries'],
#  ['C350',
#   '226',
#   '0.16',
#   '2125',
#   '41',
#   'grated cheese>spaghetti>salmon>tomato juice'],
#  ['C351', '182', '0.1', '2498', '55', 'spaghetti>green tea'],
#  ['C352', '174', '0.12', '940', '60', 'champagne>protein bar'],
#  ['C353', '188', '0.15', '1167', '33', 'mineral water>avocado>chocolate'],
#  ['C354', '182', '0.22', '1970', '49', 'tomatoes>champagne>green tea'],
#  ['C355', '105', '0.19', '2139', '42', 'chicken>french fries>escalope'],
#  ['C356',
#   '62',
#   '0.01',
#   '1017',
#   '43',
#   'frozen vegetables>tomatoes>eggs>green tea>frozen smoothie>light mayo'],
#  ['C357',
#   '95',
#   '0.1',
#   '2425',
#   '57',
#   'ground beef>chicken>cider>green grapes>honey>chocolate>french fries>champagne>frozen smoothie>escalope'],
#  ['C358', '80', '0.08', '1697', '60', 'french fries>champagne'],
#  ['C359', '127', '0.18', '514', '52', 'mineral water>soup'],
#  ['C360',
#   '128',
#   '0.1',
#   '715',
#   '51',
#   'frozen vegetables>spaghetti>milk>chocolate>babies food'],
#  ['C361', '230', '0.06', '1918', '44', 'honey>whole wheat rice'],
#  ['C362', '149', '0.2', '1896', '60', 'whole wheat rice>chicken>tomato juice'],
#  ['C363', '247', '0.01', '1621', '35', 'pancakes'],
#  ['C364',
#   '229',
#   '0.2',
#   '938',
#   '48',
#   'green tea>protein bar>tomato juice>candy bars'],
#  ['C365', '55', '0.2', '2249', '46', 'french fries'],
#  ['C366', '168', '0.19', '1140', '20', 'mineral water'],
#  ['C367', '170', '0.1', '2016', '35', 'escalope'],
#  ['C368',
#   '152',
#   '0.1',
#   '2280',
#   '39',
#   'grated cheese>herb & pepper>whole wheat pasta>yams>mineral water>bacon>nonfat milk>spinach'],
#  ['C369', '236', '0.05', '2418', '46', 'spaghetti>milk'],
#  ['C370', '166', '0.23', '613', '20', 'milk>chocolate>white wine'],
#  ['C371', '89', '0.03', '1434', '26', 'sandwich'],
#  ['C372', '206', '0.18', '2350', '23', 'chocolate>light mayo'],
#  ['C373',
#   '80',
#   '0.11',
#   '1661',
#   '23',
#   'shrimp>whole wheat pasta>spaghetti>meatballs>chicken>frozen smoothie>tomato juice'],
#  ['C374',
#   '192',
#   '0.23',
#   '2375',
#   '33',
#   'red wine>ground beef>spaghetti>mineral water>eggs'],
#  ['C375', '199', '0.06', '1350', '42', 'yams>melons'],
#  ['C376', '71', '0.01', '1063', '35', 'spaghetti>cooking oil'],
#  ['C377', '244', '0.17', '688', '33', 'french fries'],
#  ['C378',
#   '228',
#   '0.19',
#   '1543',
#   '54',
#   'mineral water>milk>spinach>cooking oil>chocolate>frozen smoothie>hot dogs'],
#  ['C379', '57', '0.09', '2158', '33', 'tomato sauce>milk'],
#  ['C380', '126', '0.05', '1403', '48', 'shrimp>cider>eggs>french fries'],
#  ['C381', '56', '0.14', '521', '54', 'champagne'],
#  ['C382', '63', '0.15', '874', '36', 'salad'],
#  ['C383', '181', '0.1', '1976', '31', 'french fries'],
#  ['C384',
#   '223',
#   '0.1',
#   '1255',
#   '49',
#   'frozen vegetables>mineral water>energy bar>honey>rice>green tea'],
#  ['C385', '164', '0.07', '656', '48', 'french fries>salad'],
#  ['C386',
#   '200',
#   '0.16',
#   '1315',
#   '39',
#   'honey>chocolate>french fries>brownies'],
#  ['C387',
#   '94',
#   '0.11',
#   '1754',
#   '21',
#   'green tea>strawberries>gluten free bar'],
#  ['C388',
#   '63',
#   '0.18',
#   '1824',
#   '57',
#   'frozen vegetables>ground beef>mineral water>salmon>honey>extra dark chocolate>green tea>mushroom cream sauce>gluten free bar'],
#  ['C389',
#   '69',
#   '0.08',
#   '2204',
#   '30',
#   'grated cheese>tomatoes>mineral water>meatballs'],
#  ['C390', '243', '0.2', '1743', '59', 'shrimp>chocolate>water spray'],
#  ['C391', '123', '0.2', '1920', '31', 'turkey'],
#  ['C392', '109', '0.02', '2181', '58', 'turkey>eggs'],
#  ['C393',
#   '126',
#   '0.04',
#   '2312',
#   '50',
#   'turkey>frozen vegetables>tomatoes>soup>butter>french wine>pancakes>eggs>tomato juice>fresh bread>green tea'],
#  ['C394', '80', '0.23', '800', '55', 'spaghetti'],
#  ['C395', '121', '0.08', '1449', '37', 'milk>frozen smoothie>low fat yogurt'],
#  ['C396',
#   '229',
#   '0.23',
#   '1317',
#   '33',
#   'burgers>mineral water>milk>whole wheat rice>cereals>chocolate>french fries'],
#  ['C397', '58', '0.05', '1116', '52', 'mineral water'],
#  ['C398',
#   '78',
#   '0.04',
#   '2036',
#   '24',
#   'tomatoes>mineral water>soup>cake>chocolate'],
#  ['C399', '167', '0.03', '1213', '45', 'mineral water'],
#  ['C400', '189', '0.24', '1288', '23', 'ground beef>spaghetti'],
#  ['C401', '145', '0.12', '1162', '25', 'pepper>frozen smoothie'],
#  ['C402', '249', '0.24', '950', '52', 'yogurt cake'],
#  ['C403', '249', '0.08', '2272', '47', 'red wine>pancakes'],
#  ['C404', '112', '0.06', '1835', '26', 'candy bars'],
#  ['C405', '185', '0.14', '995', '47', 'eggs>french fries>low fat yogurt'],
#  ['C406', '134', '0.22', '744', '42', 'cookies'],
#  ['C407', '203', '0.23', '1558', '54', 'cookies'],
#  ['C408',
#   '217',
#   '0.22',
#   '2062',
#   '34',
#   'spaghetti>soup>vegetables mix>spinach>french fries>escalope>cauliflower>toothpaste'],
#  ['C409', '123', '0.21', '1170', '35', 'cookies'],
#  ['C410', '124', '0.11', '741', '26', 'soup>olive oil>eggs>soda>corn'],
#  ['C411',
#   '99',
#   '0.08',
#   '1130',
#   '54',
#   'chocolate>frozen smoothie>low fat yogurt'],
#  ['C412',
#   '79',
#   '0.21',
#   '508',
#   '27',
#   'spaghetti>mineral water>milk>pancakes>chocolate>french fries'],
#  ['C413', '129', '0.05', '1413', '45', 'mineral water'],
#  ['C414',
#   '205',
#   '0.18',
#   '1531',
#   '22',
#   'herb & pepper>frozen vegetables>tomato sauce>mineral water>soup>milk>olive oil>almonds'],
#  ['C415', '212', '0.04', '1596', '39', 'burgers>eggs'],
#  ['C416', '248', '0.22', '1860', '40', 'french fries'],
#  ['C417', '183', '0.02', '684', '32', 'frozen smoothie>cottage cheese'],
#  ['C418',
#   '170',
#   '0.15',
#   '829',
#   '52',
#   'tomatoes>mineral water>chocolate>light mayo'],
#  ['C419',
#   '73',
#   '0.02',
#   '1856',
#   '35',
#   'salmon>escalope>shallot>strawberries>fresh bread>low fat yogurt'],
#  ['C420', '235', '0.06', '746', '42', 'energy bar'],
#  ['C421',
#   '189',
#   '0.04',
#   '850',
#   '57',
#   'red wine>ground beef>spaghetti>pancakes>blueberries>oil>cooking oil>tomato juice'],
#  ['C422',
#   '76',
#   '0.13',
#   '1610',
#   '53',
#   'ground beef>spaghetti>mineral water>milk>frozen smoothie>champagne'],
#  ['C423', '162', '0.03', '2227', '44', 'cookies'],
#  ['C424', '90', '0.2', '2306', '58', 'salmon>escalope'],
#  ['C425', '173', '0.11', '1855', '23', 'cookies'],
#  ['C426', '189', '0.14', '1156', '52', 'low fat yogurt'],
#  ['C427', '177', '0.1', '1638', '41', 'eggs'],
#  ['C428', '220', '0.12', '1592', '46', 'red wine>butter>hot dogs'],
#  ['C429',
#   '176',
#   '0.18',
#   '2034',
#   '57',
#   'tomatoes>mineral water>soup>mashed potato'],
#  ['C430', '134', '0.15', '1590', '35', 'cookies'],
#  ['C431',
#   '64',
#   '0.11',
#   '1119',
#   '29',
#   'parmesan cheese>ground beef>salmon>pancakes>champagne'],
#  ['C432',
#   '94',
#   '0.22',
#   '2107',
#   '38',
#   'ground beef>yams>chocolate>olive oil>eggs'],
#  ['C433', '199', '0.14', '1228', '39', 'shrimp>salmon>eggs>cookies>hot dogs'],
#  ['C434', '134', '0.09', '2062', '42', 'magazines>mint'],
#  ['C435',
#   '247',
#   '0.07',
#   '2312',
#   '53',
#   'turkey>mineral water>eggs>cooking oil>extra dark chocolate>escalope'],
#  ['C436', '113', '0.18', '1154', '35', 'mineral water>mushroom cream sauce'],
#  ['C437',
#   '222',
#   '0.23',
#   '2109',
#   '43',
#   'grated cheese>frozen vegetables>mineral water>soup>milk>french wine'],
#  ['C438', '144', '0.07', '2059', '34', 'chocolate>cake'],
#  ['C439', '193', '0.1', '2315', '46', 'burgers>salt>white wine'],
#  ['C440', '66', '0.23', '1545', '31', 'energy drink'],
#  ['C441', '71', '0.21', '1016', '40', 'olive oil>cake>energy drink'],
#  ['C442', '108', '0.14', '592', '53', 'ground beef>whole wheat rice'],
#  ['C443', '126', '0.12', '1952', '42', 'eggs>french fries'],
#  ['C444',
#   '75',
#   '0.05',
#   '1742',
#   '45',
#   'spaghetti>escalope>mushroom cream sauce'],
#  ['C445',
#   '207',
#   '0.08',
#   '808',
#   '45',
#   'mineral water>fromage blanc>whole wheat rice>cake>french fries'],
#  ['C446',
#   '93',
#   '0.19',
#   '2472',
#   '55',
#   'turkey>burgers>frozen vegetables>ground beef>mineral water>milk>eggs>cake>light mayo'],
#  ['C447', '134', '0.19', '1084', '48', 'green tea>cottage cheese'],
#  ['C448', '188', '0.07', '1752', '49', 'fresh tuna>eggs>champagne'],
#  ['C449', '179', '0.23', '1777', '35', 'cookies'],
#  ['C450', '249', '0.23', '1630', '36', 'cookies'],
#  ['C451', '61', '0.0', '1693', '21', 'cookies'],
#  ['C452', '229', '0.01', '1829', '31', 'tomatoes>mineral water>eggplant'],
#  ['C453',
#   '165',
#   '0.22',
#   '1105',
#   '48',
#   'grated cheese>tomatoes>spaghetti>mineral water>soup>honey>chicken>chocolate>french fries'],
#  ['C454', '242', '0.16', '1921', '49', 'protein bar'],
#  ['C455',
#   '164',
#   '0.01',
#   '1251',
#   '60',
#   'herb & pepper>red wine>shrimp>mineral water>barbecue sauce>protein bar'],
#  ['C456',
#   '117',
#   '0.02',
#   '553',
#   '31',
#   'burgers>ham>spaghetti>mineral water>milk>eggs>french fries>escalope>pancakes>low fat yogurt'],
#  ['C457', '113', '0.02', '1494', '20', 'french fries'],
#  ['C458',
#   '53',
#   '0.21',
#   '736',
#   '50',
#   'frozen vegetables>soup>milk>eggs>whole wheat rice>chocolate>escalope>melons'],
#  ['C459', '240', '0.24', '1025', '32', 'spaghetti'],
#  ['C460',
#   '58',
#   '0.05',
#   '2269',
#   '59',
#   'herb & pepper>shrimp>soup>eggs>oil>cooking oil>energy drink>protein bar>low fat yogurt'],
#  ['C461',
#   '247',
#   '0.07',
#   '652',
#   '49',
#   'ham>grated cheese>herb & pepper>shrimp>ground beef>spaghetti>mineral water>carrots'],
#  ['C462',
#   '60',
#   '0.05',
#   '1185',
#   '45',
#   'ham>red wine>ground beef>yams>mineral water>chocolate>low fat yogurt'],
#  ['C463',
#   '167',
#   '0.13',
#   '2330',
#   '50',
#   'chocolate>french fries>mushroom cream sauce>cottage cheese>low fat yogurt'],
#  ['C464', '228', '0.01', '617', '32', 'eggs'],
#  ['C465', '232', '0.13', '1285', '29', 'cake>cookies'],
#  ['C466',
#   '188',
#   '0.18',
#   '784',
#   '36',
#   'grated cheese>mineral water>cake>chocolate bread'],
#  ['C467',
#   '229',
#   '0.03',
#   '1760',
#   '20',
#   'tomatoes>almonds>cake>champagne>low fat yogurt'],
#  ['C468',
#   '130',
#   '0.21',
#   '1121',
#   '32',
#   'herb & pepper>shrimp>frozen vegetables>milk>butter>salmon>eggs>chocolate'],
#  ['C469',
#   '241',
#   '0.13',
#   '1161',
#   '27',
#   'herb & pepper>shrimp>whole wheat pasta>whole wheat rice>chicken>green tea>cauliflower'],
#  ['C470', '193', '0.23', '1103', '23', 'eggs>corn'],
#  ['C471',
#   '222',
#   '0.11',
#   '1717',
#   '46',
#   'shrimp>frozen vegetables>tomato sauce>mineral water>chocolate>soup>olive oil>salmon>green beans>champagne'],
#  ['C472',
#   '60',
#   '0.23',
#   '1653',
#   '45',
#   'ham>herb & pepper>tomato sauce>mineral water>green grapes>eggs>gums>light cream>oil>green tea>mint'],
#  ['C473', '174', '0.24', '589', '58', 'energy bar>cake>chocolate'],
#  ['C474', '50', '0.04', '1228', '50', 'herb & pepper>shrimp>spaghetti>eggs'],
#  ['C475',
#   '142',
#   '0.24',
#   '1537',
#   '56',
#   'fresh tuna>mineral water>honey>cooking oil'],
#  ['C476',
#   '141',
#   '0.19',
#   '2320',
#   '57',
#   'red wine>mineral water>oil>ketchup>chili>pet food>eggplant>green tea>escalope>tomato juice>low fat yogurt'],
#  ['C477',
#   '107',
#   '0.07',
#   '1856',
#   '50',
#   'herb & pepper>shrimp>mineral water>pancakes>eggs>cake>blueberries>tea>frozen smoothie'],
#  ['C478',
#   '214',
#   '0.08',
#   '1318',
#   '33',
#   'ground beef>mineral water>protein bar'],
#  ['C479',
#   '116',
#   '0.12',
#   '1841',
#   '53',
#   'shrimp>frozen vegetables>parmesan cheese>spaghetti>salmon>carrots>frozen smoothie>pasta>mashed potato>shallot>light mayo>magazines'],
#  ['C480', '185', '0.16', '2397', '48', 'milk>chocolate'],
#  ['C481',
#   '71',
#   '0.08',
#   '1299',
#   '20',
#   'frozen vegetables>ground beef>spaghetti>olive oil>whole wheat rice>eggplant>cottage cheese'],
#  ['C482', '74', '0.19', '749', '58', 'turkey>ground beef>low fat yogurt'],
#  ['C483',
#   '216',
#   '0.15',
#   '761',
#   '20',
#   'herb & pepper>spaghetti>mineral water>whole wheat rice>cake>hot dogs>green tea'],
#  ['C484', '232', '0.24', '1109', '46', 'green tea'],
#  ['C485', '126', '0.15', '1179', '27', 'cookies'],
#  ['C486', '69', '0.18', '588', '44', 'eggs>cookies'],
#  ['C487',
#   '167',
#   '0.22',
#   '2265',
#   '60',
#   'spaghetti>eggs>ham>chocolate>french fries>champagne>brownies>pancakes>light mayo'],
#  ['C488',
#   '52',
#   '0.23',
#   '1558',
#   '44',
#   'red wine>spaghetti>milk>eggs>chocolate'],
#  ['C489',
#   '56',
#   '0.08',
#   '1457',
#   '50',
#   'turkey>burgers>pancakes>french fries>strawberries>green tea'],
#  ['C490', '222', '0.1', '2367', '60', 'escalope'],
#  ['C491', '197', '0.09', '1012', '48', 'frozen vegetables>pancakes>eggs>cake'],
#  ['C492', '237', '0.21', '591', '41', 'french fries'],
#  ['C493',
#   '218',
#   '0.06',
#   '2445',
#   '46',
#   'turkey>ground beef>pepper>spaghetti>honey>cookies'],
#  ['C494',
#   '212',
#   '0.19',
#   '2123',
#   '54',
#   'chocolate>red wine>tomato sauce>olive oil>chili>french fries>cookies>salt>fresh bread>magazines'],
#  ['C495', '122', '0.01', '1339', '20', 'green tea>french fries'],
#  ['C496', '232', '0.06', '1589', '29', 'mineral water'],
#  ['C497', '89', '0.03', '555', '46', 'cooking oil'],
#  ['C498', '87', '0.01', '1875', '31', 'frozen vegetables>spaghetti'],
#  ['C499', '189', '0.02', '1019', '47', 'ham>spaghetti'],
#  ['C500', '146', '0.18', '2011', '36', 'chicken>chocolate>cookies'],
#  ['C501', '81', '0.12', '1897', '34', 'low fat yogurt'],
#  ['C502', '125', '0.01', '1846', '51', 'eggs>cake>low fat yogurt'],
#  ['C503',
#   '181',
#   '0.23',
#   '849',
#   '49',
#   'shrimp>spaghetti>mineral water>soup>milk>bramble>frozen smoothie>cottage cheese'],
#  ['C504', '193', '0.14', '994', '56', 'mineral water>eggs>protein bar'],
#  ['C505',
#   '198',
#   '0.13',
#   '1418',
#   '49',
#   'turkey>shrimp>meatballs>butter>eggs>salad>green tea'],
#  ['C506',
#   '148',
#   '0.2',
#   '601',
#   '24',
#   'fresh tuna>spaghetti>chocolate>olive oil>chicken>french fries'],
#  ['C507', '94', '0.01', '1076', '52', 'turkey>shrimp>escalope>hot dogs'],
#  ['C508',
#   '148',
#   '0.19',
#   '1334',
#   '22',
#   'burgers>pepper>soup>milk>pancakes>green tea'],
#  ['C509', '100', '0.11', '1439', '31', 'pancakes'],
#  ['C510',
#   '81',
#   '0.02',
#   '1816',
#   '49',
#   'mineral water>pancakes>eggs>french fries'],
#  ['C511', '213', '0.12', '532', '51', 'eggs>escalope>low fat yogurt'],
#  ['C512',
#   '109',
#   '0.2',
#   '869',
#   '28',
#   'mineral water>french wine>gluten free bar'],
#  ['C513',
#   '144',
#   '0.25',
#   '1263',
#   '50',
#   'burgers>ground beef>spaghetti>eggs>french fries'],
#  ['C514', '168', '0.15', '757', '59', 'soup>meatballs>milk>energy bar'],
#  ['C515', '79', '0.23', '1632', '60', 'chocolate'],
#  ['C516', '131', '0.06', '1310', '22', 'herb & pepper'],
#  ['C517',
#   '141',
#   '0.12',
#   '1740',
#   '44',
#   'turkey>red wine>mineral water>eggs>bramble'],
#  ['C518',
#   '181',
#   '0.23',
#   '747',
#   '32',
#   'burgers>ham>frozen vegetables>tomatoes>cake>chicken>green tea>toothpaste>mint'],
#  ['C519',
#   '156',
#   '0.17',
#   '1631',
#   '40',
#   'grated cheese>mineral water>olive oil>energy bar'],
#  ['C520', '121', '0.19', '2140', '35', 'milk>cake>green tea'],
#  ['C521',
#   '232',
#   '0.08',
#   '536',
#   '42',
#   'mineral water>almonds>cooking oil>cereals>protein bar>white wine>green tea'],
#  ['C522',
#   '100',
#   '0.14',
#   '2240',
#   '36',
#   'turkey>fresh tuna>mineral water>milk>eggs>cake>burger sauce>chicken>french fries>frozen smoothie>fresh bread'],
#  ['C523',
#   '149',
#   '0.13',
#   '656',
#   '29',
#   'herb & pepper>mineral water>whole wheat rice>yogurt cake>low fat yogurt'],
#  ['C524',
#   '143',
#   '0.03',
#   '935',
#   '25',
#   'tomatoes>spaghetti>meatballs>chicken>eggs'],
#  ['C525',
#   '67',
#   '0.15',
#   '1365',
#   '57',
#   'burgers>mineral water>eggs>green tea>pancakes'],
#  ['C526', '184', '0.06', '2361', '44', 'cake>green tea'],
#  ['C527', '153', '0.11', '1394', '57', 'chocolate>herb & pepper>yogurt cake'],
#  ['C528',
#   '234',
#   '0.19',
#   '2189',
#   '25',
#   'ground beef>spaghetti>mineral water>almonds>salmon>nonfat milk>green grapes>pancakes'],
#  ['C529', '123', '0.04', '1950', '58', 'mineral water>vegetables mix>eggs'],
#  ['C530', '89', '0.15', '1685', '60', 'protein bar'],
#  ['C531', '61', '0.19', '2047', '41', 'eggs>eggplant'],
#  ['C532', '59', '0.24', '1798', '42', 'mayonnaise'],
#  ['C533',
#   '97',
#   '0.24',
#   '2105',
#   '54',
#   'milk>bug spray>oatmeal>sandwich>asparagus'],
#  ['C534',
#   '200',
#   '0.19',
#   '1389',
#   '56',
#   'frozen vegetables>soup>almonds>eggs>french fries'],
#  ['C535', '98', '0.03', '1156', '51', 'frozen vegetables'],
#  ['C536', '248', '0.11', '607', '24', 'soup>butter>shampoo'],
#  ['C537',
#   '184',
#   '0.19',
#   '1352',
#   '58',
#   'herb & pepper>whole wheat pasta>pepper>eggs'],
#  ['C538',
#   '109',
#   '0.23',
#   '1010',
#   '24',
#   'mineral water>whole wheat rice>rice>cooking oil>chocolate>fresh bread>low fat yogurt'],
#  ['C539',
#   '66',
#   '0.23',
#   '1779',
#   '44',
#   'grated cheese>butter>chocolate>french fries>cookies'],
#  ['C540',
#   '112',
#   '0.0',
#   '1735',
#   '36',
#   'spaghetti>soup>milk>chutney>cooking oil>asparagus>tomato juice'],
#  ['C541',
#   '244',
#   '0.19',
#   '1101',
#   '25',
#   'eggs>french fries>frozen smoothie>cookies>champagne>cottage cheese>green tea'],
#  ['C542',
#   '127',
#   '0.1',
#   '1480',
#   '24',
#   'turkey>tomatoes>mineral water>eggs>blueberries'],
#  ['C543',
#   '72',
#   '0.07',
#   '1593',
#   '26',
#   'milk>tomato juice>low fat yogurt>green tea'],
#  ['C544',
#   '223',
#   '0.09',
#   '1511',
#   '57',
#   'mineral water>soup>almonds>cereals>green tea'],
#  ['C545', '128', '0.24', '509', '50', 'chocolate>light mayo'],
#  ['C546', '185', '0.17', '1333', '46', 'turkey>herb & pepper>chocolate'],
#  ['C547', '75', '0.03', '1200', '29', 'eggs>french fries>green tea'],
#  ['C548',
#   '209',
#   '0.01',
#   '2463',
#   '58',
#   'mineral water>cake>chocolate>tomato juice'],
#  ['C549', '151', '0.18', '2062', '43', 'eggs'],
#  ['C550',
#   '122',
#   '0.14',
#   '1497',
#   '52',
#   'chocolate>pepper>spaghetti>mineral water>whole wheat rice>champagne>mushroom cream sauce'],
#  ['C551',
#   '240',
#   '0.16',
#   '655',
#   '35',
#   'frozen vegetables>pepper>mineral water>chocolate>white wine'],
#  ['C552',
#   '110',
#   '0.07',
#   '1023',
#   '23',
#   'burgers>turkey>spaghetti>milk>whole wheat rice>oil>tomato juice>green tea'],
#  ['C553',
#   '90',
#   '0.11',
#   '1953',
#   '38',
#   'burgers>spaghetti>mineral water>soup>french wine>french fries>light mayo>low fat yogurt'],
#  ['C554',
#   '236',
#   '0.16',
#   '536',
#   '42',
#   'butter>green grapes>frozen smoothie>low fat yogurt'],
#  ['C555', '50', '0.04', '604', '26', 'eggs>low fat yogurt'],
#  ['C556', '53', '0.22', '762', '37', 'cookies'],
#  ['C557', '156', '0.06', '2365', '24', 'milk>energy drink'],
#  ['C558', '59', '0.14', '1461', '58', 'olive oil>energy drink'],
#  ['C559', '146', '0.0', '1697', '20', 'eggs>cookies'],
#  ['C560', '155', '0.09', '1582', '56', 'eggs'],
#  ['C561', '77', '0.02', '589', '30', 'energy bar>eggs'],
#  ['C562', '83', '0.23', '2061', '57', 'eggs'],
#  ['C563', '112', '0.16', '2222', '43', 'eggs>green tea'],
#  ['C564', '135', '0.05', '1488', '22', 'escalope'],
#  ['C565',
#   '248',
#   '0.14',
#   '1558',
#   '43',
#   'shrimp>soup>milk>almonds>eggs>oil>chocolate'],
#  ['C566', '176', '0.05', '689', '55', 'chocolate>french fries'],
#  ['C567', '60', '0.12', '2403', '40', 'cake'],
#  ['C568',
#   '101',
#   '0.01',
#   '2143',
#   '45',
#   'pancakes>eggs>cake>green tea>toothpaste'],
# ...
#  ['C829', '78', '0.12', '1175', '39', 'pancakes'],
#  ['C830', '152', '0.01', '872', '59', 'mineral water>honey'],
#  ['C831', '190', '0.07', '1772', '25', 'burgers>ground beef>pancakes>salt'],
#  ['C832',
#   '175',
#   '0.23',
#   '1064',
#   '55',
#   'parmesan cheese>soda>french fries>brownies'],
#  ['C833', '238', '0.18', '1481', '24', 'whole wheat rice'],
#  ['C834',
#   '230',
#   '0.11',
#   '1445',
#   '23',
#   'ground beef>spaghetti>chicken>rice>oil>cooking oil>hot dogs>mint'],
#  ['C835', '135', '0.08', '2395', '25', 'butter>chocolate'],
#  ['C836', '94', '0.14', '1720', '35', 'pepper'],
#  ['C837',
#   '180',
#   '0.12',
#   '1656',
#   '49',
#   'herb & pepper>chocolate>champagne>yogurt cake>green tea'],
#  ['C838',
#   '107',
#   '0.05',
#   '642',
#   '23',
#   'grated cheese>mineral water>eggs>escalope'],
#  ['C839',
#   '202',
#   '0.22',
#   '609',
#   '31',
#   'cookies>yogurt cake>light mayo>green tea'],
#  ['C840', '84', '0.16', '1096', '32', 'milk>cooking oil'],
#  ['C841',
#   '99',
#   '0.02',
#   '709',
#   '33',
#   'milk>olive oil>light cream>cooking oil>chicken>extra dark chocolate>cereals>french fries>frozen smoothie>pancakes>tomato juice>fresh bread>low fat yogurt'],
#  ['C842',
#   '242',
#   '0.06',
#   '2213',
#   '56',
#   'tomatoes>soup>avocado>milk>yogurt cake>energy drink>low fat yogurt>green tea'],
#  ['C843',
#   '117',
#   '0.03',
#   '2403',
#   '21',
#   'ham>chocolate>ground beef>mineral water>oil'],
#  ['C844', '198', '0.01', '1314', '38', 'green tea>champagne>escalope'],
#  ['C845', '157', '0.22', '2401', '37', 'chocolate'],
#  ['C846', '55', '0.16', '2396', '38', 'escalope>pasta'],
#  ['C847',
#   '109',
#   '0.08',
#   '1601',
#   '58',
#   'burgers>mineral water>olive oil>rice>antioxydant juice>frozen smoothie'],
#  ['C848', '186', '0.04', '2314', '43', 'green tea'],
#  ['C849',
#   '62',
#   '0.1',
#   '1750',
#   '23',
#   'grated cheese>tomato sauce>spaghetti>milk>pancakes>energy drink>white wine'],
#  ['C850',
#   '54',
#   '0.03',
#   '2198',
#   '43',
#   'turkey>spaghetti>strong cheese>strawberries'],
#  ['C851', '113', '0.12', '953', '37', 'muffins'],
#  ['C852',
#   '207',
#   '0.17',
#   '1618',
#   '38',
#   'ground beef>spaghetti>cider>cooking oil>cookies'],
#  ['C853',
#   '207',
#   '0.15',
#   '644',
#   '38',
#   'burgers>frozen vegetables>parmesan cheese>spaghetti>fromage blanc>vegetables mix>pancakes>honey>hot dogs>low fat yogurt'],
#  ['C854', '74', '0.0', '1602', '34', 'ground beef'],
#  ['C855', '51', '0.15', '2074', '53', 'green beans'],
#  ['C856',
#   '236',
#   '0.03',
#   '1452',
#   '38',
#   'frozen vegetables>mineral water>honey>whole wheat rice>champagne>escalope'],
#  ['C857',
#   '122',
#   '0.04',
#   '1350',
#   '50',
#   'parmesan cheese>milk>butter>black tea>eggs>frozen smoothie>light mayo>shampoo>low fat yogurt>green tea'],
#  ['C858', '156', '0.19', '2154', '24', 'mineral water>cake'],
#  ['C859',
#   '193',
#   '0.11',
#   '1645',
#   '49',
#   'turkey>mineral water>milk>pancakes>whole wheat rice>cooking oil>frozen smoothie>cookies>green tea'],
#  ['C860', '154', '0.14', '2110', '46', 'avocado>chocolate>french fries'],
#  ['C861', '103', '0.04', '1010', '47', 'green tea'],
#  ['C862', '67', '0.04', '2162', '39', 'chocolate>eggs>bug spray'],
#  ['C863',
#   '191',
#   '0.24',
#   '1415',
#   '33',
#   'grated cheese>muffins>french fries>body spray'],
#  ['C864',
#   '197',
#   '0.03',
#   '2025',
#   '46',
#   'mineral water>eggs>blueberries>soda>escalope'],
#  ['C865', '230', '0.09', '1452', '58', 'whole wheat rice'],
#  ['C866',
#   '80',
#   '0.19',
#   '868',
#   '46',
#   'nonfat milk>cookies>mushroom cream sauce'],
#  ['C867', '141', '0.12', '1072', '34', 'french fries>champagne'],
#  ['C868', '109', '0.24', '1853', '29', 'mineral water>salmon'],
#  ['C869', '204', '0.08', '1962', '43', 'olive oil'],
#  ['C870',
#   '72',
#   '0.19',
#   '1112',
#   '55',
#   'turkey>tomatoes>ground beef>soup>milk>butter>honey>cake>mint green tea>brownies>salt'],
#  ['C871',
#   '191',
#   '0.21',
#   '1930',
#   '48',
#   'parmesan cheese>spaghetti>mineral water>chocolate>napkins>low fat yogurt'],
#  ['C872',
#   '77',
#   '0.09',
#   '1118',
#   '26',
#   'burgers>parmesan cheese>chocolate>soup>milk>olive oil>energy bar>butter>almonds>fromage blanc>eggs>cake>pancakes'],
#  ['C873',
#   '110',
#   '0.24',
#   '527',
#   '58',
#   'shrimp>honey>pasta>energy drink>green tea'],
#  ['C874',
#   '174',
#   '0.2',
#   '768',
#   '56',
#   'fresh tuna>chocolate>milk>french wine>muffins>pancakes>champagne>frozen smoothie'],
#  ['C875', '123', '0.16', '2306', '57', 'strawberries'],
#  ['C876', '65', '0.01', '2003', '24', 'herb & pepper'],
#  ['C877',
#   '138',
#   '0.14',
#   '2449',
#   '23',
#   'herb & pepper>frozen vegetables>tomatoes>parmesan cheese>ground beef>fromage blanc>eggs>honey>cake>rice>cereals>french fries>champagne'],
#  ['C878',
#   '100',
#   '0.24',
#   '2419',
#   '51',
#   'spaghetti>mineral water>milk>strong cheese>cereals>escalope>cottage cheese'],
#  ['C879',
#   '61',
#   '0.03',
#   '2087',
#   '22',
#   'turkey>burgers>fresh tuna>spaghetti>pancakes>eggs>cake>cottage cheese>energy drink>gluten free bar'],
#  ['C880', '81', '0.05', '2376', '35', 'eggplant'],
#  ['C881',
#   '238',
#   '0.17',
#   '1222',
#   '23',
#   'burgers>spaghetti>mineral water>almonds>honey>extra dark chocolate>carrots>mashed potato'],
#  ['C882',
#   '98',
#   '0.08',
#   '1692',
#   '56',
#   'chocolate>french fries>frozen smoothie>cottage cheese>strawberries>light mayo'],
#  ['C883', '122', '0.02', '1896', '56', 'strong cheese'],
#  ['C884', '104', '0.21', '1373', '24', 'chocolate>french fries'],
#  ['C885', '76', '0.22', '801', '37', 'chocolate>french fries>strawberries'],
#  ['C886',
#   '70',
#   '0.12',
#   '692',
#   '25',
#   'turkey>frozen vegetables>avocado>cake>light cream>cooking oil>chicken>chocolate bread>mashed potato'],
#  ['C887', '54', '0.1', '935', '57', 'olive oil>energy bar>shallot'],
#  ['C888', '85', '0.07', '1805', '30', 'turkey>shrimp'],
#  ['C889',
#   '219',
#   '0.04',
#   '1857',
#   '55',
#   'chocolate>spaghetti>champagne>yogurt cake'],
#  ['C890',
#   '101',
#   '0.25',
#   '1365',
#   '49',
#   'shrimp>mineral water>chocolate>avocado>butter>zucchini>green tea'],
#  ['C891', '164', '0.14', '1597', '55', 'muffins>green tea>brownies'],
#  ['C892', '163', '0.24', '500', '29', 'yogurt cake'],
#  ['C893',
#   '248',
#   '0.25',
#   '1205',
#   '34',
#   'turkey>tomato sauce>milk>butter>bacon>salmon>cooking oil>chocolate>french fries>hot dogs>melons>protein bar>mint'],
#  ['C894', '66', '0.2', '2361', '20', 'grated cheese'],
#  ['C895',
#   '207',
#   '0.05',
#   '1224',
#   '22',
#   'butter>burger sauce>brownies>pancakes'],
#  ['C896',
#   '104',
#   '0.22',
#   '2168',
#   '40',
#   'butter>pancakes>whole wheat rice>green tea>french fries>cookies>shallot>low fat yogurt'],
#  ['C897',
#   '143',
#   '0.05',
#   '1065',
#   '31',
#   'shrimp>chocolate>butter>cooking oil>escalope'],
#  ['C898',
#   '71',
#   '0.1',
#   '1362',
#   '41',
#   'burgers>red wine>frozen vegetables>pepper>spaghetti>chocolate>milk>honey>whole wheat rice>cooking oil>cereals'],
#  ['C899',
#   '180',
#   '0.01',
#   '2127',
#   '40',
#   'turkey>ground beef>spaghetti>pancakes>eggs>cake>chili>pet food>chocolate'],
#  ['C900',
#   '101',
#   '0.1',
#   '2056',
#   '59',
#   'shrimp>milk>butter>chicken>salt>mayonnaise>green tea'],
#  ['C901',
#   '183',
#   '0.11',
#   '1002',
#   '52',
#   'fresh tuna>mineral water>fromage blanc>honey>gums>chocolate>french fries>frozen smoothie>sparkling water>strawberries>green tea'],
#  ['C902', '237', '0.18', '800', '31', 'chocolate>cookies'],
#  ['C903', '62', '0.11', '1449', '60', 'sparkling water>light mayo'],
#  ['C904',
#   '155',
#   '0.12',
#   '556',
#   '48',
#   'frozen vegetables>tomatoes>spaghetti>chicken>french fries>escalope'],
#  ['C905',
#   '242',
#   '0.22',
#   '2060',
#   '40',
#   'turkey>burgers>butter>vegetables mix>green grapes>pancakes>eggs>cake>barbecue sauce>green tea'],
#  ['C906',
#   '53',
#   '0.22',
#   '881',
#   '51',
#   'red wine>shrimp>yams>eggs>burger sauce>yogurt cake'],
#  ['C907', '186', '0.19', '1371', '36', 'french fries>light mayo'],
#  ['C908',
#   '176',
#   '0.09',
#   '1357',
#   '34',
#   'burgers>ground beef>eggs>chocolate>champagne>zucchini'],
#  ['C909', '190', '0.06', '2243', '32', 'mushroom cream sauce'],
#  ['C910', '245', '0.02', '1571', '24', 'butter>mint green tea'],
#  ['C911', '86', '0.14', '1604', '45', 'whole wheat rice'],
#  ['C912', '86', '0.14', '942', '21', 'gums'],
#  ['C913',
#   '91',
#   '0.23',
#   '2387',
#   '28',
#   'mineral water>french fries>champagne>green tea'],
#  ['C914', '94', '0.2', '1975', '20', 'cereals>salt>green tea'],
#  ['C915',
#   '213',
#   '0.19',
#   '2067',
#   '21',
#   'shrimp>spaghetti>chocolate>french fries>escalope>cookies>brownies>pancakes>melons'],
#  ['C916',
#   '137',
#   '0.17',
#   '2158',
#   '49',
#   'ham>spaghetti>yams>chicken>cooking oil>chocolate>hot dogs'],
#  ['C917', '126', '0.23', '2381', '20', 'eggs'],
#  ['C918',
#   '178',
#   '0.02',
#   '1525',
#   '27',
#   'ground beef>olive oil>bug spray>frozen smoothie>hot dogs'],
#  ['C919',
#   '181',
#   '0.22',
#   '1427',
#   '49',
#   'frozen vegetables>spaghetti>mineral water>soup>olive oil>escalope'],
#  ['C920',
#   '243',
#   '0.19',
#   '2475',
#   '30',
#   'whole wheat rice>oil>chicken>french fries>escalope'],
#  ['C921', '184', '0.15', '959', '52', 'green tea'],
#  ['C922',
#   '135',
#   '0.01',
#   '787',
#   '40',
#   'parmesan cheese>whole wheat rice>escalope>champagne'],
#  ['C923',
#   '192',
#   '0.13',
#   '1100',
#   '54',
#   'fresh tuna>frozen vegetables>chicken>fromage blanc>honey>light mayo'],
#  ['C924', '102', '0.16', '1808', '34', 'ground beef'],
#  ['C925',
#   '73',
#   '0.08',
#   '834',
#   '49',
#   'muffins>champagne>cookies>fresh bread>green tea'],
#  ['C926',
#   '149',
#   '0.09',
#   '2367',
#   '60',
#   'frozen vegetables>spaghetti>chocolate>escalope>fresh bread'],
#  ['C927',
#   '89',
#   '0.06',
#   '1122',
#   '35',
#   'pickles>spaghetti>french fries>frozen smoothie'],
#  ['C928', '158', '0.15', '2152', '53', 'avocado'],
#  ['C929', '153', '0.12', '1869', '52', 'sandwich'],
#  ['C930', '130', '0.14', '1210', '38', 'spaghetti>milk>oil>shampoo'],
#  ['C931', '212', '0.07', '1894', '23', 'champagne'],
#  ['C932', '114', '0.1', '2212', '21', 'spaghetti'],
#  ['C933', '169', '0.03', '1513', '27', 'champagne'],
#  ['C934',
#   '85',
#   '0.04',
#   '724',
#   '22',
#   'avocado>milk>butter>french fries>cookies'],
#  ['C935',
#   '134',
#   '0.01',
#   '1539',
#   '50',
#   'turkey>frozen vegetables>chicken>eggs>frozen smoothie>cauliflower>low fat yogurt'],
#  ['C936',
#   '166',
#   '0.2',
#   '921',
#   '38',
#   'burgers>shrimp>tomatoes>milk>energy bar>almonds>chicken>chocolate>french fries>body spray'],
#  ['C937',
#   '235',
#   '0.23',
#   '1347',
#   '40',
#   'burgers>milk>cake>cooking oil>french fries>escalope>zucchini'],
#  ['C938',
#   '175',
#   '0.2',
#   '939',
#   '59',
#   'tomatoes>spaghetti>chocolate>milk>olive oil>whole wheat rice>cake>frozen smoothie>protein bar'],
#  ['C939',
#   '114',
#   '0.02',
#   '2481',
#   '32',
#   'fresh tuna>red wine>pepper>spaghetti>fromage blanc>salmon>pancakes>eggs>honey>green tea'],
#  ['C940', '182', '0.13', '942', '55', 'milk>low fat yogurt'],
#  ['C941',
#   '67',
#   '0.15',
#   '2482',
#   '43',
#   'shrimp>parmesan cheese>soup>chocolate>brownies'],
#  ['C942', '54', '0.12', '2189', '57', 'spaghetti>chicken'],
#  ['C943',
#   '85',
#   '0.12',
#   '2262',
#   '41',
#   'grated cheese>vegetables mix>nonfat milk>green tea'],
#  ['C944',
#   '121',
#   '0.1',
#   '508',
#   '43',
#   'fresh tuna>parmesan cheese>cider>muffins>spinach>honey>oil'],
#  ['C945', '159', '0.25', '1792', '54', 'cake'],
#  ['C946',
#   '160',
#   '0.15',
#   '2284',
#   '39',
#   'shrimp>chocolate>mushroom cream sauce>candy bars'],
#  ['C947', '195', '0.19', '1196', '35', 'candy bars'],
#  ['C948', '118', '0.17', '1638', '40', 'avocado>honey'],
#  ['C949',
#   '158',
#   '0.24',
#   '1829',
#   '45',
#   'shrimp>frozen vegetables>tomatoes>cottage cheese'],
#  ['C950', '156', '0.02', '1831', '28', 'french fries'],
#  ['C951', '160', '0.05', '1822', '47', 'strawberries'],
#  ['C952',
#   '248',
#   '0.21',
#   '1260',
#   '23',
#   'ground beef>almonds>french fries>escalope'],
#  ['C953', '137', '0.09', '1464', '44', 'grated cheese>spaghetti'],
#  ['C954',
#   '84',
#   '0.03',
#   '563',
#   '34',
#   'turkey>mineral water>butter>frozen smoothie'],
#  ['C955',
#   '178',
#   '0.13',
#   '549',
#   '39',
#   'frozen vegetables>spaghetti>french fries>light mayo>green tea'],
#  ['C956',
#   '166',
#   '0.05',
#   '1876',
#   '41',
#   'burgers>ham>spaghetti>whole wheat rice>eggplant>chocolate>cookies>shallot>green tea'],
#  ['C957',
#   '161',
#   '0.08',
#   '985',
#   '55',
#   'grated cheese>frozen vegetables>spaghetti>avocado>milk>blueberries>light cream>rice>green tea>chocolate>french fries>frozen smoothie>cookies>hot dogs'],
#  ['C958',
#   '175',
#   '0.23',
#   '1750',
#   '21',
#   'burgers>shrimp>tomatoes>bacon>whole wheat rice>green tea'],
#  ['C959', '250', '0.23', '2281', '58', 'parmesan cheese>pancakes'],
#  ['C960',
#   '207',
#   '0.24',
#   '1126',
#   '50',
#   'parmesan cheese>cake>hot dogs>green tea'],
#  ['C961',
#   '195',
#   '0.05',
#   '764',
#   '48',
#   'spaghetti>milk>fromage blanc>ketchup>chocolate>babies food'],
#  ['C962', '130', '0.04', '1659', '44', 'mint'],
#  ['C963', '139', '0.08', '956', '54', 'chocolate>mint'],
#  ['C964', '132', '0.21', '1620', '58', 'butter>french fries>salt>fresh bread'],
#  ['C965',
#   '238',
#   '0.18',
#   '1997',
#   '35',
#   'chocolate>french fries>strawberries>yogurt cake>light mayo'],
#  ['C966', '216', '0.23', '2159', '35', 'eggs>eggplant>cookies'],
#  ['C967', '163', '0.16', '956', '57', 'yogurt cake'],
#  ['C968',
#   '58',
#   '0.24',
#   '783',
#   '60',
#   'herb & pepper>spaghetti>meatballs>milk>olive oil>chicken>honey>frozen smoothie>escalope>pancakes'],
#  ['C969', '213', '0.09', '993', '53', 'frozen vegetables>rice>chocolate'],
#  ['C970',
#   '132',
#   '0.16',
#   '641',
#   '52',
#   'herb & pepper>ground beef>spaghetti>chocolate>milk>eggs>light cream'],
#  ['C971', '126', '0.15', '575', '50', 'eggs>champagne'],
#  ['C972',
#   '108',
#   '0.17',
#   '1261',
#   '28',
#   'whole wheat pasta>ground beef>olive oil>blueberries>escalope'],
#  ['C973',
#   '82',
#   '0.1',
#   '2010',
#   '48',
#   'burgers>red wine>mineral water>eggs>oil>carrots>hand protein bar>tomato juice'],
#  ['C974',
#   '117',
#   '0.09',
#   '2059',
#   '22',
#   'chocolate>grated cheese>herb & pepper>mineral water>soup>olive oil'],
#  ['C975',
#   '101',
#   '0.0',
#   '1196',
#   '45',
#   'burgers>shrimp>mineral water>chicken>fromage blanc>salmon>eggs>cake>frozen smoothie>strawberries'],
#  ['C976', '238', '0.15', '1035', '22', 'green tea'],
#  ['C977', '165', '0.21', '1708', '24', 'cookies'],
#  ['C978', '184', '0.1', '623', '27', 'french fries>cookies'],
#  ['C979', '116', '0.13', '1866', '55', 'milk>butter>eggs'],
#  ['C980',
#   '84',
#   '0.05',
#   '1654',
#   '46',
#   'eggs>mushroom cream sauce>low fat yogurt'],
#  ['C981', '104', '0.22', '1314', '23', 'eggs>green tea'],
#  ['C982', '112', '0.0', '1542', '44', 'mineral water>whole wheat rice'],
#  ['C983',
#   '66',
#   '0.21',
#   '1050',
#   '24',
#   'shrimp>frozen vegetables>parmesan cheese>mineral water>whole wheat rice>cake'],
#  ['C984', '117', '0.16', '1804', '21', 'whole wheat rice>pancakes'],
#  ['C985',
#   '58',
#   '0.12',
#   '565',
#   '22',
#   'frozen vegetables>spaghetti>olive oil>butter>salmon>oil>cooking oil>frozen smoothie>cauliflower'],
#  ['C986', '168', '0.13', '1836', '49', 'green tea'],
#  ['C987', '91', '0.03', '2052', '43', 'fresh tuna>eggs>escalope>strawberries'],
#  ['C988',
#   '240',
#   '0.06',
#   '1825',
#   '20',
#   'spaghetti>soup>milk>carrots>chocolate'],
#  ['C989',
#   '228',
#   '0.05',
#   '1389',
#   '55',
#   'burgers>mineral water>soup>meatballs>olive oil'],
#  ['C990',
#   '221',
#   '0.15',
#   '1087',
#   '49',
#   'grated cheese>mineral water>cooking oil>french fries>cookies>low fat yogurt'],
#  ['C991', '66', '0.21', '2283', '28', 'shrimp>milk>olive oil>french fries'],
#  ['C992',
#   '82',
#   '0.06',
#   '1957',
#   '39',
#   'frozen vegetables>mineral water>pancakes>cake>tomato juice'],
#  ['C993', '161', '0.19', '788', '34', 'spaghetti>milk>chicken'],
#  ['C994',
#   '244',
#   '0.05',
#   '2446',
#   '40',
#   'grated cheese>mineral water>chicken>french fries>cottage cheese>pancakes'],
#  ['C995',
#   '195',
#   '0.14',
#   '1581',
#   '36',
#   'ground beef>mineral water>milk>eggs>mint'],
#  ['C996', '136', '0.1', '1559', '37', 'shrimp>body spray>green tea'],
#  ['C997', '152', '0.18', '1993', '39', 'frozen smoothie'],
#  ['C998',
#   '198',
#   '0.07',
#   '1393',
#   '38',
#   'herb & pepper>frozen vegetables>mineral water>muffins>cereals'],
#  ['C999',
#   '223',
#   '0.08',
#   '1030',
#   '46',
#   'turkey>tomatoes>spaghetti>milk>cider>eggs>honey>cake>green tea>french fries>brownies>tomato juice'],
#  ...]

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\laptrinhptdl\tk3.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/tk3.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
#       <a href='vscode-notebook-cell:/e%3A/laptrinhptdl/tk3.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> association_results = list(association_rules)
#
# TypeError: apriori() got an unexpected keyword argument 'min_confidence'

# %%
association_results
# Out:
# []

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
