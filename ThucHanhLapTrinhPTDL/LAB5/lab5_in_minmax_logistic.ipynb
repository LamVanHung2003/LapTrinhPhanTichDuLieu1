# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
# đọc file 
df= pd.read_excel('D:\HK1 năm 3\Lập trình phân tích dữ liệu 1\LAB5\P1-SuperStoreUS-2015.xlsx',index_col=0)
df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\H'
# <>:2: SyntaxWarning: invalid escape sequence '\H'
# C:\Users\phi16\AppData\Local\Temp\ipykernel_15708\656639632.py:2: SyntaxWarning: invalid escape sequence '\H'
#   df= pd.read_excel('D:\HK1 năm 3\Lập trình phân tích dữ liệu 1\LAB5\P1-SuperStoreUS-2015.xlsx',index_col=0)
#        Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# Row ID
# 20847            High      0.01        2.84           0.93            3
# 20228   Not Specified      0.02      500.98          26.00            5
# 21776        Critical      0.06        9.48           7.29           11
# 24844          Medium      0.09       78.69          19.99           14
# 24846          Medium      0.08        3.28           2.31           14
# ...               ...       ...         ...            ...          ...
# 19842            High      0.01       10.90           7.46         3397
# 19843            High      0.10        7.99           5.03         3397
# 26208   Not Specified      0.08       11.97           5.81         3399
# 24911          Medium      0.10        9.38           4.93         3400
# 25914            High      0.10      105.98          13.99         3403
#
#             Customer Name       Ship Mode Customer Segment Product Category  \
# Row ID
# 20847       Bonnie Potter     Express Air        Corporate  Office Supplies
# 20228      Ronnie Proctor  Delivery Truck      Home Office        Furniture
# 21776       Marcus Dunlap     Regular Air      Home Office        Furniture
# 24844   Gwendolyn F Tyson     Regular Air   Small Business        Furniture
# 24846   Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies
# ...                   ...             ...              ...              ...
# 19842         Andrea Shaw     Regular Air   Small Business  Office Supplies
# 19843         Andrea Shaw     Regular Air   Small Business       Technology
# 26208         Marvin Reid     Regular Air   Small Business  Office Supplies
# 24911       Florence Gold     Express Air   Small Business        Furniture
# 25914       Tammy Buckley     Express Air         Consumer        Furniture
#
#                 Product Sub-Category  ...   Region State or Province  \
# Row ID                                ...
# 20847            Pens & Art Supplies  ...     West        Washington
# 20228             Chairs & Chairmats  ...     West        California
# 21776             Office Furnishings  ...     East        New Jersey
# 24844             Office Furnishings  ...  Central         Minnesota
# 24846            Pens & Art Supplies  ...  Central         Minnesota
# ...                              ...  ...      ...               ...
# 19842         Storage & Organization  ...  Central          Illinois
# 19843   Telephones and Communication  ...  Central          Illinois
# 26208            Pens & Art Supplies  ...  Central          Illinois
# 24911             Office Furnishings  ...     East     West Virginia
# 25914             Office Furnishings  ...     West           Wyoming
#
#                City Postal Code Order Date  Ship Date     Profit  \
# Row ID
# 20847     Anacortes       98221 2015-01-07 2015-01-08     4.5600
# 20228   San Gabriel       91776 2015-06-13 2015-06-15  4390.3665
# 21776       Roselle        7203 2015-02-15 2015-02-17   -53.8096
# 24844    Prior Lake       55372 2015-05-12 2015-05-14   803.4705
# 24846    Prior Lake       55372 2015-05-12 2015-05-13   -24.0300
# ...             ...         ...        ...        ...        ...
# 19842      Danville       61832 2015-03-11 2015-03-12  -116.7600
# 19843      Danville       61832 2015-03-11 2015-03-12  -160.9520
# 26208   Des Plaines       60016 2015-03-29 2015-03-31   -41.8700
# 24911      Fairmont       26554 2015-04-04 2015-04-04   -24.7104
# 25914      Cheyenne       82001 2015-02-08 2015-02-11   349.4850
#
#         Quantity ordered new    Sales Order ID
# Row ID
# 20847                      4    13.01    88522
# 20228                     12  6362.85    90193
# 21776                     22   211.15    90192
# 24844                     16  1164.45    86838
# 24846                      7    22.23    86838
# ...                      ...      ...      ...
# 19842                     18   207.31    87536
# 19843                     22   143.12    87536
# 26208                      5    59.98    87534
# 24911                     15   135.78    87537
# 25914                      5   506.50    87530
#
# [1952 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1952 entries, 20847 to 25914
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Order Priority        1952 non-null   object
#  1   Discount              1952 non-null   float64
#  2   Unit Price            1952 non-null   float64
#  3   Shipping Cost         1952 non-null   float64
#  4   Customer ID           1952 non-null   int64
#  5   Customer Name         1952 non-null   object
#  6   Ship Mode             1952 non-null   object
#  7   Customer Segment      1952 non-null   object
#  8   Product Category      1952 non-null   object
#  9   Product Sub-Category  1952 non-null   object
#  10  Product Container     1952 non-null   object
#  11  Product Name          1952 non-null   object
#  12  Product Base Margin   1936 non-null   float64
#  13  Country               1952 non-null   object
#  14  Region                1952 non-null   object
#  15  State or Province     1952 non-null   object
#  16  City                  1952 non-null   object
#  17  Postal Code           1952 non-null   int64
#  18  Order Date            1952 non-null   datetime64[ns]
#  19  Ship Date             1952 non-null   datetime64[ns]
#  20  Profit                1952 non-null   float64
#  21  Quantity ordered new  1952 non-null   int64
#  22  Sales                 1952 non-null   float64
#  23  Order ID              1952 non-null   int64
# dtypes: datetime64[ns](2), float64(6), int64(4), object(12)
# memory usage: 381.2+ KB

# %%
df=df.iloc[99:1600]

# %% [markdown]
# # đổi cột

# %%
df.rename(columns={'Unit Price' : 'unitprice','Shipping Cost': 'shipcost', 
                         'Ship Mode':'shipmode','Customer Segment':'customerseg',
                         'Product Category':'PCate','Product Container':'PCon',
                         'Quantity ordered new':'Quantity'},inplace=True)
df
# Out:
# C:\Users\phi16\AppData\Local\Temp\ipykernel_15708\2089671222.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Unit Price' : 'unitprice','Shipping Cost': 'shipcost',
#        Order Priority  Discount  unitprice  shipcost  Customer ID  \
# Row ID
# 5361         Critical      0.02      49.99     19.99          181
# 522              High      0.07       1.68      1.57          181
# 23361        Critical      0.02      49.99     19.99          184
# 18521            High      0.07      10.06      2.06          188
# 18522            High      0.07       1.68      1.57          188
# ...               ...       ...        ...       ...          ...
# 18419          Medium      0.05      15.68      3.73         2840
# 18420          Medium      0.00      14.98      8.99         2840
# 18421          Medium      0.02      38.76     13.26         2840
# 21855   Not Specified      0.04      90.48     19.99         2847
# 21856   Not Specified      0.02       9.77      6.02         2847
#
#          Customer Name     shipmode     customerseg            PCate  \
# Row ID
# 5361     Wesley Waller  Regular Air  Small Business       Technology
# 522      Wesley Waller  Regular Air       Corporate  Office Supplies
# 23361   Phillip Holmes  Regular Air  Small Business       Technology
# 18521     Alex Harrell  Regular Air       Corporate  Office Supplies
# 18522     Alex Harrell  Regular Air       Corporate  Office Supplies
# ...                ...          ...             ...              ...
# 18419         Bob Berg  Regular Air       Corporate        Furniture
# 18420         Bob Berg  Regular Air       Corporate        Furniture
# 18421         Bob Berg  Regular Air       Corporate  Office Supplies
# 21855      Vanessa Day  Regular Air       Corporate  Office Supplies
# 21856      Vanessa Day  Regular Air       Corporate        Furniture
#
#         Product Sub-Category  ...   Region State or Province           City  \
# Row ID                        ...
# 5361    Computer Peripherals  ...     West        California  San Francisco
# 522      Pens & Art Supplies  ...     West        California  San Francisco
# 23361   Computer Peripherals  ...     East     Massachusetts      Arlington
# 18521                  Paper  ...  Central             Texas    Gainesville
# 18522    Pens & Art Supplies  ...  Central             Texas    Gainesville
# ...                      ...  ...      ...               ...            ...
# 18419     Office Furnishings  ...    South           Florida    North Miami
# 18420     Office Furnishings  ...    South           Florida    North Miami
# 18421                  Paper  ...    South           Florida    North Miami
# 21855              Envelopes  ...    South         Tennessee   Collierville
# 21856     Office Furnishings  ...    South         Tennessee   Collierville
#
#        Postal Code Order Date  Ship Date     Profit  Quantity   Sales Order ID
# Row ID
# 5361         94122 2015-02-21 2015-02-21   -76.8900        18  901.81    38087
# 522          94122 2015-05-22 2015-05-23   -35.7500       116  186.59     3585
# 23361         2474 2015-02-21 2015-02-21   -76.8900         5  250.50    88360
# 18521        76240 2015-05-22 2015-05-22   152.6556        23  221.24    88361
# 18522        76240 2015-05-22 2015-05-23     7.1500        29   46.65    88361
# ...            ...        ...        ...        ...       ...     ...      ...
# 18419        33161 2015-06-11 2015-06-13  1166.6280        17  260.01    87885
# 18420        33161 2015-06-11 2015-06-12   -40.6042        18  273.79    87885
# 18421        33161 2015-06-11 2015-06-12  -294.0840         1   44.62    87885
# 21855        38017 2015-04-09 2015-04-11    55.5552         3  268.64    85928
# 21856        38017 2015-04-09 2015-04-10  -535.3320         9   87.68    85928
#
# [1501 rows x 24 columns]

# %% [markdown]
# # Tạo cột IsProfit biết rằng nếu Profit lớn hơn 0 thì là YES , ngược lại là NO

# %%
df['IsProfit'] = df['Profit'].apply(lambda x: 'YES' if x > 0 else 'NO')
# Out:
# C:\Users\phi16\AppData\Local\Temp\ipykernel_15708\1644961232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IsProfit'] = df['Profit'].apply(lambda x: 'YES' if x > 0 else 'NO')

# %%
df
# Out:
#        Order Priority  Discount  unitprice  shipcost  Customer ID  \
# Row ID
# 5361         Critical      0.02      49.99     19.99          181
# 522              High      0.07       1.68      1.57          181
# 23361        Critical      0.02      49.99     19.99          184
# 18521            High      0.07      10.06      2.06          188
# 18522            High      0.07       1.68      1.57          188
# ...               ...       ...        ...       ...          ...
# 18419          Medium      0.05      15.68      3.73         2840
# 18420          Medium      0.00      14.98      8.99         2840
# 18421          Medium      0.02      38.76     13.26         2840
# 21855   Not Specified      0.04      90.48     19.99         2847
# 21856   Not Specified      0.02       9.77      6.02         2847
#
#          Customer Name     shipmode     customerseg            PCate  \
# Row ID
# 5361     Wesley Waller  Regular Air  Small Business       Technology
# 522      Wesley Waller  Regular Air       Corporate  Office Supplies
# 23361   Phillip Holmes  Regular Air  Small Business       Technology
# 18521     Alex Harrell  Regular Air       Corporate  Office Supplies
# 18522     Alex Harrell  Regular Air       Corporate  Office Supplies
# ...                ...          ...             ...              ...
# 18419         Bob Berg  Regular Air       Corporate        Furniture
# 18420         Bob Berg  Regular Air       Corporate        Furniture
# 18421         Bob Berg  Regular Air       Corporate  Office Supplies
# 21855      Vanessa Day  Regular Air       Corporate  Office Supplies
# 21856      Vanessa Day  Regular Air       Corporate        Furniture
#
#         Product Sub-Category  ... State or Province           City  \
# Row ID                        ...
# 5361    Computer Peripherals  ...        California  San Francisco
# 522      Pens & Art Supplies  ...        California  San Francisco
# 23361   Computer Peripherals  ...     Massachusetts      Arlington
# 18521                  Paper  ...             Texas    Gainesville
# 18522    Pens & Art Supplies  ...             Texas    Gainesville
# ...                      ...  ...               ...            ...
# 18419     Office Furnishings  ...           Florida    North Miami
# 18420     Office Furnishings  ...           Florida    North Miami
# 18421                  Paper  ...           Florida    North Miami
# 21855              Envelopes  ...         Tennessee   Collierville
# 21856     Office Furnishings  ...         Tennessee   Collierville
#
#         Postal Code Order Date  Ship Date     Profit Quantity   Sales  \
# Row ID
# 5361          94122 2015-02-21 2015-02-21   -76.8900       18  901.81
# 522           94122 2015-05-22 2015-05-23   -35.7500      116  186.59
# 23361          2474 2015-02-21 2015-02-21   -76.8900        5  250.50
# 18521         76240 2015-05-22 2015-05-22   152.6556       23  221.24
# 18522         76240 2015-05-22 2015-05-23     7.1500       29   46.65
# ...             ...        ...        ...        ...      ...     ...
# 18419         33161 2015-06-11 2015-06-13  1166.6280       17  260.01
# 18420         33161 2015-06-11 2015-06-12   -40.6042       18  273.79
# 18421         33161 2015-06-11 2015-06-12  -294.0840        1   44.62
# 21855         38017 2015-04-09 2015-04-11    55.5552        3  268.64
# 21856         38017 2015-04-09 2015-04-10  -535.3320        9   87.68
#
#        Order ID IsProfit
# Row ID
# 5361      38087       NO
# 522        3585       NO
# 23361     88360       NO
# 18521     88361      YES
# 18522     88361      YES
# ...         ...      ...
# 18419     87885      YES
# 18420     87885       NO
# 18421     87885       NO
# 21855     85928      YES
# 21856     85928       NO
#
# [1501 rows x 25 columns]

# %%
df = df[['Discount', 'unitprice', 'shipcost', 'shipmode', 'customerseg', 'PCate', 
         'PCon', 'Region', 'Quantity', 'Sales', 'IsProfit']]
df
# Out:
#         Discount  unitprice  shipcost     shipmode     customerseg  \
# Row ID
# 5361        0.02      49.99     19.99  Regular Air  Small Business
# 522         0.07       1.68      1.57  Regular Air       Corporate
# 23361       0.02      49.99     19.99  Regular Air  Small Business
# 18521       0.07      10.06      2.06  Regular Air       Corporate
# 18522       0.07       1.68      1.57  Regular Air       Corporate
# ...          ...        ...       ...          ...             ...
# 18419       0.05      15.68      3.73  Regular Air       Corporate
# 18420       0.00      14.98      8.99  Regular Air       Corporate
# 18421       0.02      38.76     13.26  Regular Air       Corporate
# 21855       0.04      90.48     19.99  Regular Air       Corporate
# 21856       0.02       9.77      6.02  Regular Air       Corporate
#
#                   PCate        PCon   Region  Quantity   Sales IsProfit
# Row ID
# 5361         Technology   Small Box     West        18  901.81       NO
# 522     Office Supplies    Wrap Bag     West       116  186.59       NO
# 23361        Technology   Small Box     East         5  250.50       NO
# 18521   Office Supplies    Wrap Bag  Central        23  221.24      YES
# 18522   Office Supplies    Wrap Bag  Central        29   46.65      YES
# ...                 ...         ...      ...       ...     ...      ...
# 18419         Furniture  Small Pack    South        17  260.01      YES
# 18420         Furniture  Small Pack    South        18  273.79       NO
# 18421   Office Supplies   Small Box    South         1   44.62       NO
# 21855   Office Supplies   Small Box    South         3  268.64      YES
# 21856         Furniture  Medium Box    South         9   87.68       NO
#
# [1501 rows x 11 columns]

# %% [markdown]
# # 4.Mã hóa categorical data dùng One-Hot-Endcoding

# %%
dinhhuong = pd.get_dummies(df['shipmode']).astype(int)
df.drop('shipmode',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
# C:\Users\phi16\AppData\Local\Temp\ipykernel_15708\490238402.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('shipmode',axis=1,inplace=True)
#         Discount  unitprice  shipcost     customerseg            PCate  \
# Row ID
# 5361        0.02      49.99     19.99  Small Business       Technology
# 522         0.07       1.68      1.57       Corporate  Office Supplies
# 23361       0.02      49.99     19.99  Small Business       Technology
# 18521       0.07      10.06      2.06       Corporate  Office Supplies
# 18522       0.07       1.68      1.57       Corporate  Office Supplies
#
#              PCon   Region  Quantity   Sales IsProfit  Delivery Truck  \
# Row ID
# 5361    Small Box     West        18  901.81       NO               0
# 522      Wrap Bag     West       116  186.59       NO               0
# 23361   Small Box     East         5  250.50       NO               0
# 18521    Wrap Bag  Central        23  221.24      YES               0
# 18522    Wrap Bag  Central        29   46.65      YES               0
#
#         Express Air  Regular Air
# Row ID
# 5361              0            1
# 522               0            1
# 23361             0            1
# 18521             0            1
# 18522             0            1

# %%
dinhhuong = pd.get_dummies(df['customerseg']).astype(int)
df.drop('customerseg',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost            PCate       PCon   Region  \
# Row ID
# 5361        0.02      49.99     19.99       Technology  Small Box     West
# 522         0.07       1.68      1.57  Office Supplies   Wrap Bag     West
# 23361       0.02      49.99     19.99       Technology  Small Box     East
# 18521       0.07      10.06      2.06  Office Supplies   Wrap Bag  Central
# 18522       0.07       1.68      1.57  Office Supplies   Wrap Bag  Central
#
#         Quantity   Sales IsProfit  Delivery Truck  Express Air  Regular Air  \
# Row ID
# 5361          18  901.81       NO               0            0            1
# 522          116  186.59       NO               0            0            1
# 23361          5  250.50       NO               0            0            1
# 18521         23  221.24      YES               0            0            1
# 18522         29   46.65      YES               0            0            1
#
#         Consumer  Corporate  Home Office  Small Business
# Row ID
# 5361           0          0            0               1
# 522            0          1            0               0
# 23361          0          0            0               1
# 18521          0          1            0               0
# 18522          0          1            0               0

# %%
dinhhuong = pd.get_dummies(df['PCate']).astype(int)
df.drop('PCate',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost       PCon   Region  Quantity   Sales  \
# Row ID
# 5361        0.02      49.99     19.99  Small Box     West        18  901.81
# 522         0.07       1.68      1.57   Wrap Bag     West       116  186.59
# 23361       0.02      49.99     19.99  Small Box     East         5  250.50
# 18521       0.07      10.06      2.06   Wrap Bag  Central        23  221.24
# 18522       0.07       1.68      1.57   Wrap Bag  Central        29   46.65
#
#        IsProfit  Delivery Truck  Express Air  Regular Air  Consumer  \
# Row ID
# 5361         NO               0            0            1         0
# 522          NO               0            0            1         0
# 23361        NO               0            0            1         0
# 18521       YES               0            0            1         0
# 18522       YES               0            0            1         0
#
#         Corporate  Home Office  Small Business  Furniture  Office Supplies  \
# Row ID
# 5361            0            0               1          0                0
# 522             1            0               0          0                1
# 23361           0            0               1          0                0
# 18521           1            0               0          0                1
# 18522           1            0               0          0                1
#
#         Technology
# Row ID
# 5361             1
# 522              0
# 23361            1
# 18521            0
# 18522            0

# %%
dinhhuong = pd.get_dummies(df['PCon']).astype(int)
df.drop('PCon',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost   Region  Quantity   Sales IsProfit  \
# Row ID
# 5361        0.02      49.99     19.99     West        18  901.81       NO
# 522         0.07       1.68      1.57     West       116  186.59       NO
# 23361       0.02      49.99     19.99     East         5  250.50       NO
# 18521       0.07      10.06      2.06  Central        23  221.24      YES
# 18522       0.07       1.68      1.57  Central        29   46.65      YES
#
#         Delivery Truck  Express Air  Regular Air  ...  Furniture  \
# Row ID                                            ...
# 5361                 0            0            1  ...          0
# 522                  0            0            1  ...          0
# 23361                0            0            1  ...          0
# 18521                0            0            1  ...          0
# 18522                0            0            1  ...          0
#
#         Office Supplies  Technology  Jumbo Box  Jumbo Drum  Large Box  \
# Row ID
# 5361                  0           1          0           0          0
# 522                   1           0          0           0          0
# 23361                 0           1          0           0          0
# 18521                 1           0          0           0          0
# 18522                 1           0          0           0          0
#
#         Medium Box  Small Box  Small Pack  Wrap Bag
# Row ID
# 5361             0          1           0         0
# 522              0          0           0         1
# 23361            0          1           0         0
# 18521            0          0           0         1
# 18522            0          0           0         1
#
# [5 rows x 24 columns]

# %%
dinhhuong = pd.get_dummies(df['Region']).astype(int)
df.drop('Region',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost  Quantity   Sales IsProfit  \
# Row ID
# 5361        0.02      49.99     19.99        18  901.81       NO
# 522         0.07       1.68      1.57       116  186.59       NO
# 23361       0.02      49.99     19.99         5  250.50       NO
# 18521       0.07      10.06      2.06        23  221.24      YES
# 18522       0.07       1.68      1.57        29   46.65      YES
#
#         Delivery Truck  Express Air  Regular Air  Consumer  ...  Jumbo Drum  \
# Row ID                                                      ...
# 5361                 0            0            1         0  ...           0
# 522                  0            0            1         0  ...           0
# 23361                0            0            1         0  ...           0
# 18521                0            0            1         0  ...           0
# 18522                0            0            1         0  ...           0
#
#         Large Box  Medium Box  Small Box  Small Pack  Wrap Bag  Central  East  \
# Row ID
# 5361            0           0          1           0         0        0     0
# 522             0           0          0           0         1        0     0
# 23361           0           0          1           0         0        0     1
# 18521           0           0          0           0         1        1     0
# 18522           0           0          0           0         1        1     0
#
#         South  West
# Row ID
# 5361        0     1
# 522         0     1
# 23361       0     0
# 18521       0     0
# 18522       0     0
#
# [5 rows x 27 columns]

# %%
dinhhuong = pd.get_dummies(df['IsProfit'],drop_first=True)
dinhhuong=dinhhuong.astype(int)
df.drop('IsProfit',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost  Quantity   Sales  Delivery Truck  \
# Row ID
# 5361        0.02      49.99     19.99        18  901.81               0
# 522         0.07       1.68      1.57       116  186.59               0
# 23361       0.02      49.99     19.99         5  250.50               0
# 18521       0.07      10.06      2.06        23  221.24               0
# 18522       0.07       1.68      1.57        29   46.65               0
#
#         Express Air  Regular Air  Consumer  Corporate  ...  Large Box  \
# Row ID                                                 ...
# 5361              0            1         0          0  ...          0
# 522               0            1         0          1  ...          0
# 23361             0            1         0          0  ...          0
# 18521             0            1         0          1  ...          0
# 18522             0            1         0          1  ...          0
#
#         Medium Box  Small Box  Small Pack  Wrap Bag  Central  East  South  \
# Row ID
# 5361             0          1           0         0        0     0      0
# 522              0          0           0         1        0     0      0
# 23361            0          1           0         0        0     1      0
# 18521            0          0           0         1        1     0      0
# 18522            0          0           0         1        1     0      0
#
#         West  YES
# Row ID
# 5361       1    0
# 522        1    0
# 23361      0    0
# 18521      0    1
# 18522      0    1
#
# [5 rows x 27 columns]

# %%
df.rename(columns={'YES':'IsProfit'}, inplace=True)
df.head(5)
# Out:
#         Discount  unitprice  shipcost  Quantity   Sales  Delivery Truck  \
# Row ID
# 5361        0.02      49.99     19.99        18  901.81               0
# 522         0.07       1.68      1.57       116  186.59               0
# 23361       0.02      49.99     19.99         5  250.50               0
# 18521       0.07      10.06      2.06        23  221.24               0
# 18522       0.07       1.68      1.57        29   46.65               0
#
#         Express Air  Regular Air  Consumer  Corporate  ...  Large Box  \
# Row ID                                                 ...
# 5361              0            1         0          0  ...          0
# 522               0            1         0          1  ...          0
# 23361             0            1         0          0  ...          0
# 18521             0            1         0          1  ...          0
# 18522             0            1         0          1  ...          0
#
#         Medium Box  Small Box  Small Pack  Wrap Bag  Central  East  South  \
# Row ID
# 5361             0          1           0         0        0     0      0
# 522              0          0           0         1        0     0      0
# 23361            0          1           0         0        0     1      0
# 18521            0          0           0         1        1     0      0
# 18522            0          0           0         1        1     0      0
#
#         West  IsProfit
# Row ID
# 5361       1         0
# 522        1         0
# 23361      0         0
# 18521      0         1
# 18522      0         1
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1501 entries, 5361 to 21856
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Discount         1501 non-null   float64
#  1   unitprice        1501 non-null   float64
#  2   shipcost         1501 non-null   float64
#  3   Quantity         1501 non-null   int64
#  4   Sales            1501 non-null   float64
#  5   Delivery Truck   1501 non-null   int32
#  6   Express Air      1501 non-null   int32
#  7   Regular Air      1501 non-null   int32
#  8   Consumer         1501 non-null   int32
#  9   Corporate        1501 non-null   int32
#  10  Home Office      1501 non-null   int32
#  11  Small Business   1501 non-null   int32
#  12  Furniture        1501 non-null   int32
#  13  Office Supplies  1501 non-null   int32
#  14  Technology       1501 non-null   int32
#  15  Jumbo Box        1501 non-null   int32
#  16  Jumbo Drum       1501 non-null   int32
#  17  Large Box        1501 non-null   int32
#  18  Medium Box       1501 non-null   int32
#  19  Small Box        1501 non-null   int32
#  20  Small Pack       1501 non-null   int32
#  21  Wrap Bag         1501 non-null   int32
#  22  Central          1501 non-null   int32
#  23  East             1501 non-null   int32
#  24  South            1501 non-null   int32
#  25  West             1501 non-null   int32
#  26  IsProfit         1501 non-null   int32
# dtypes: float64(4), int32(22), int64(1)
# memory usage: 199.4 KB

# %% [markdown]
# # Xây dựng mô hình dự báo IsProfit dựa trên Discount, unitprice, shipcost, shipmode, customerseg, PCate, PCon, Region, Quantity, Sales với Cross validation là train 80%, test 20% và random_state = 16

# %%
X = df.drop('IsProfit',axis=1).values
Y = df[['IsProfit']].values

# %%
# Chia tách ra trainning (huấn luyện) và testing (kiểm thử) 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=16)

# %% [markdown]
# # MinMax --> Logictis

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
steps = [('minmaxnormalize',MinMaxScaler()),('Logistic',LogisticRegression())]
model = Pipeline(steps)
model.fit(X_train,y_train.flatten())
# Out:
# Pipeline(steps=[('minmaxnormalize', MinMaxScaler()),
#                 ('Logistic', LogisticRegression())])

# %% [markdown]
# # liblinear

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
# Chọn solver và tạo mô hình hồi quy logistic
  # L2 regularization, có thể thay đổi thành 'l1' nếu bạn muốn L1 regularization
steps = [
    ('minmaxnormalize', MinMaxScaler()),
    ('Logistic', LogisticRegression(solver='liblinear', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)

# Huấn luyện mô hình
model.fit(X_train, y_train)
# Out:
# c:\Users\phi16\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(steps=[('minmaxnormalize', MinMaxScaler()),
#                 ('Logistic',
#                  LogisticRegression(max_iter=10000, solver='liblinear'))])

# %% [markdown]
# # Test liblinear

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.654485049833887
# AUC: 0.6560559006211181

# %% [markdown]
# # Train liblinear

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.625
# AUC: 0.6230812013348165

# %% [markdown]
# # ROC và AUE Plot

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# # TEST

# %% [markdown]
# # Đường cong càng ôm góc trên bên trái của biểu đồ thì mô hình càng phân loại dữ liệu thành các danh mục tốt hơn.

# %%
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(libinear)')
plt.xlabel('False Positive Rate(libinear)')
plt.show()

# %% [markdown]
# Để định lượng điều này, chúng ta có thể tính toán AUC – diện tích dưới đường cong – cho chúng ta biết phần nằm dưới đường cong là bao nhiêu.
#
# AUC càng gần 1 thì mô hình càng tốt. Một mô hình có AUC bằng 0,5 không tốt hơn mô hình phân loại ngẫu nhiên.

# %%
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
auc
# Out:
# 0.6792369121561667

# %% [markdown]
# # ROC

# %%
#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(libinear)')
plt.xlabel('False Positive Rate(libinear)')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # TRAIN

# %%
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(libinear)')
plt.xlabel('False Positive Rate(libinear)')
plt.show()

# %%
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
auc
# Out:
# 0.6614265850945495

# %%
#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(libinear)')
plt.xlabel('False Positive Rate(libinear)')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # lbfgs

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
# Chọn solver và tạo mô hình hồi quy logistic
  # L2 regularization, có thể thay đổi thành 'l1' nếu bạn muốn L1 regularization
steps = [
    ('minmaxnormalize', MinMaxScaler()),
    ('Logistic', LogisticRegression(solver='lbfgs', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)

# Huấn luyện mô hình
model.fit(X_train, y_train)
# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(lbfgs)')
plt.xlabel('False Positive Rate(lbfgs)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(lbfgs)')
plt.xlabel('False Positive Rate(lbfgs)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST(lbfgs)')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(lbfgs)')
plt.xlabel('False Positive Rate(lbfgs)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(lbfgs)')
plt.xlabel('False Positive Rate(lbfgs)')
plt.legend(loc=4)
plt.show()
# Out:
# c:\Users\phi16\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# TẬP TRAIN
# AUC test 0.6614098998887653
# TẬP TEST(lbfgs)
# AUC test 0.6790150842945873

# %% [markdown]
# # tập test voi lbfgs

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6777408637873754
# AUC: 0.6782608695652174

# %% [markdown]
# # tập train lbfgs

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6683333333333333
# AUC: 0.6666852057842046

# %% [markdown]
# # AUE and ROC plot

# %% [markdown]
# # Newton-cg

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
# Chọn solver và tạo mô hình hồi quy logistic
  # L2 regularization, có thể thay đổi thành 'l1' nếu bạn muốn L1 regularization
steps = [
    ('minmaxnormalize', MinMaxScaler()),
    ('Logistic', LogisticRegression(solver='newton-cg', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)

# Huấn luyện mô hình
model.fit(X_train, y_train)


# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Newton-cg)')
plt.xlabel('False Positive Rate(Newton-cg)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Newton-cg)')
plt.xlabel('False Positive Rate(Newton-cg)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Newton-cg)')
plt.xlabel('False Positive Rate(Newton-cg)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Newton-cg)')
plt.xlabel('False Positive Rate(Newton-cg)')
plt.legend(loc=4)
plt.show()
# Out:
# TẬP TRAIN
# c:\Users\phi16\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AUC test 0.6614043381535039
# TẬP TEST
# AUC test 0.6790594498669033

# %% [markdown]
# # tập test voi newton-cg

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6710963455149501
# AUC: 0.6720496894409939

# %% [markdown]
# # tập train newton-cg

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6633333333333333
# AUC: 0.6616240266963292

# %% [markdown]
# # newton-cholesky

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
# Chọn solver và tạo mô hình hồi quy logistic
  # L2 regularization, có thể thay đổi thành 'l1' nếu bạn muốn L1 regularization
steps = [
    ('minmaxnormalize', MinMaxScaler()),
    ('Logistic', LogisticRegression(solver='newton-cholesky', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)

# Huấn luyện mô hình
model.fit(X_train, y_train)


# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Newton-Cholesky)')
plt.xlabel('False Positive Rate(Newton-Cholesky)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Newton-Cholesky)')
plt.xlabel('False Positive Rate(Newton-Cholesky)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Newton-Cholesky)')
plt.xlabel('False Positive Rate(Newton-Cholesky)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Newton-Cholesky)')
plt.xlabel('False Positive Rate(Newton-Cholesky)')
plt.legend(loc=4)
plt.show()
# Out:
# TẬP TRAIN
# c:\Users\phi16\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AUC test 0.6614043381535039
# TẬP TEST
# AUC test 0.6790594498669033

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6710963455149501
# AUC: 0.6720496894409939

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6633333333333333
# AUC: 0.6616240266963292

# %% [markdown]
# # Sag

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
# Chọn solver và tạo mô hình hồi quy logistic
  # L2 regularization, có thể thay đổi thành 'l1' nếu bạn muốn L1 regularization
steps = [
    ('minmaxnormalize', MinMaxScaler()),
    ('Logistic', LogisticRegression(solver='sag', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)

# Huấn luyện mô hình
model.fit(X_train, y_train)
# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Sag)')
plt.xlabel('False Positive Rate(Sag)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Sag)')
plt.xlabel('False Positive Rate(Sag)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Sag)')
plt.xlabel('False Positive Rate(Sag)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Sag)')
plt.xlabel('False Positive Rate(Sag)')
plt.legend(loc=4)
plt.show()
# Out:
# TẬP TRAIN
# c:\Users\phi16\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AUC test 0.6614098998887653
# TẬP TEST
# AUC test 0.6790594498669033

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6877076411960132
# AUC: 0.7015527950310559

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6633333333333333
# AUC: 0.6565072302558399

# %% [markdown]
# # Saga

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
# Chọn solver và tạo mô hình hồi quy logistic
  # L2 regularization, có thể thay đổi thành 'l1' nếu bạn muốn L1 regularization
steps = [
    ('minmaxnormalize', MinMaxScaler()),
    ('Logistic', LogisticRegression(solver='saga', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)

# Huấn luyện mô hình
model.fit(X_train, y_train)

# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Saga)')
plt.xlabel('False Positive Rate(Saga)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Saga)')
plt.xlabel('False Positive Rate(Saga)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate (Saga)')
plt.xlabel('False Positive Rate (Saga)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate (Saga)')
plt.xlabel('False Positive Rate (Saga)')
plt.legend(loc=4)
plt.show()
# Out:
# TẬP TRAIN
# c:\Users\phi16\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AUC test 0.6614043381535039
# TẬP TEST
# AUC test 0.6790150842945873

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6777408637873754
# AUC: 0.6908385093167702

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.6725
# AUC: 0.6663793103448277
