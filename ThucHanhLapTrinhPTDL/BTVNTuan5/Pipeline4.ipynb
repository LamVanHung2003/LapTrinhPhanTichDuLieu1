# %% [markdown]
# # Input -> log(1+x^2)-> Logistic -> Output

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
# đọc file 
df= pd.read_excel('P1-SuperStoreUS-2015.xlsx',index_col=0)
df
# Out:
#        Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# Row ID
# 20847            High      0.01        2.84           0.93            3
# 20228   Not Specified      0.02      500.98          26.00            5
# 21776        Critical      0.06        9.48           7.29           11
# 24844          Medium      0.09       78.69          19.99           14
# 24846          Medium      0.08        3.28           2.31           14
# ...               ...       ...         ...            ...          ...
# 19842            High      0.01       10.90           7.46         3397
# 19843            High      0.10        7.99           5.03         3397
# 26208   Not Specified      0.08       11.97           5.81         3399
# 24911          Medium      0.10        9.38           4.93         3400
# 25914            High      0.10      105.98          13.99         3403
#
#             Customer Name       Ship Mode Customer Segment Product Category  \
# Row ID
# 20847       Bonnie Potter     Express Air        Corporate  Office Supplies
# 20228      Ronnie Proctor  Delivery Truck      Home Office        Furniture
# 21776       Marcus Dunlap     Regular Air      Home Office        Furniture
# 24844   Gwendolyn F Tyson     Regular Air   Small Business        Furniture
# 24846   Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies
# ...                   ...             ...              ...              ...
# 19842         Andrea Shaw     Regular Air   Small Business  Office Supplies
# 19843         Andrea Shaw     Regular Air   Small Business       Technology
# 26208         Marvin Reid     Regular Air   Small Business  Office Supplies
# 24911       Florence Gold     Express Air   Small Business        Furniture
# 25914       Tammy Buckley     Express Air         Consumer        Furniture
#
#                 Product Sub-Category  ...   Region State or Province  \
# Row ID                                ...
# 20847            Pens & Art Supplies  ...     West        Washington
# 20228             Chairs & Chairmats  ...     West        California
# 21776             Office Furnishings  ...     East        New Jersey
# 24844             Office Furnishings  ...  Central         Minnesota
# 24846            Pens & Art Supplies  ...  Central         Minnesota
# ...                              ...  ...      ...               ...
# 19842         Storage & Organization  ...  Central          Illinois
# 19843   Telephones and Communication  ...  Central          Illinois
# 26208            Pens & Art Supplies  ...  Central          Illinois
# 24911             Office Furnishings  ...     East     West Virginia
# 25914             Office Furnishings  ...     West           Wyoming
#
#                City Postal Code Order Date  Ship Date     Profit  \
# Row ID
# 20847     Anacortes       98221 2015-01-07 2015-01-08     4.5600
# 20228   San Gabriel       91776 2015-06-13 2015-06-15  4390.3665
# 21776       Roselle        7203 2015-02-15 2015-02-17   -53.8096
# 24844    Prior Lake       55372 2015-05-12 2015-05-14   803.4705
# 24846    Prior Lake       55372 2015-05-12 2015-05-13   -24.0300
# ...             ...         ...        ...        ...        ...
# 19842      Danville       61832 2015-03-11 2015-03-12  -116.7600
# 19843      Danville       61832 2015-03-11 2015-03-12  -160.9520
# 26208   Des Plaines       60016 2015-03-29 2015-03-31   -41.8700
# 24911      Fairmont       26554 2015-04-04 2015-04-04   -24.7104
# 25914      Cheyenne       82001 2015-02-08 2015-02-11   349.4850
#
#         Quantity ordered new    Sales Order ID
# Row ID
# 20847                      4    13.01    88522
# 20228                     12  6362.85    90193
# 21776                     22   211.15    90192
# 24844                     16  1164.45    86838
# 24846                      7    22.23    86838
# ...                      ...      ...      ...
# 19842                     18   207.31    87536
# 19843                     22   143.12    87536
# 26208                      5    59.98    87534
# 24911                     15   135.78    87537
# 25914                      5   506.50    87530
#
# [1952 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1952 entries, 20847 to 25914
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Order Priority        1952 non-null   object
#  1   Discount              1952 non-null   float64
#  2   Unit Price            1952 non-null   float64
#  3   Shipping Cost         1952 non-null   float64
#  4   Customer ID           1952 non-null   int64
#  5   Customer Name         1952 non-null   object
#  6   Ship Mode             1952 non-null   object
#  7   Customer Segment      1952 non-null   object
#  8   Product Category      1952 non-null   object
#  9   Product Sub-Category  1952 non-null   object
#  10  Product Container     1952 non-null   object
#  11  Product Name          1952 non-null   object
#  12  Product Base Margin   1936 non-null   float64
#  13  Country               1952 non-null   object
#  14  Region                1952 non-null   object
#  15  State or Province     1952 non-null   object
#  16  City                  1952 non-null   object
#  17  Postal Code           1952 non-null   int64
#  18  Order Date            1952 non-null   datetime64[ns]
#  19  Ship Date             1952 non-null   datetime64[ns]
#  20  Profit                1952 non-null   float64
#  21  Quantity ordered new  1952 non-null   int64
#  22  Sales                 1952 non-null   float64
#  23  Order ID              1952 non-null   int64
# dtypes: datetime64[ns](2), float64(6), int64(4), object(12)
# memory usage: 381.2+ KB

# %%
df=df.iloc[0:999]

# %% [markdown]
# # đổi cột

# %%
df.rename(columns={'Unit Price' : 'unitprice','Shipping Cost': 'shipcost', 
                         'Ship Mode':'shipmode','Customer Segment':'customerseg',
                         'Product Category':'PCate','Product Container':'PCon',
                         'Quantity ordered new':'Quantity'},inplace=True)
df
# Out:
# C:\Users\hungl\AppData\Local\Temp\ipykernel_25892\2089671222.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Unit Price' : 'unitprice','Shipping Cost': 'shipcost',
#        Order Priority  Discount  unitprice  shipcost  Customer ID  \
# Row ID
# 20847            High      0.01       2.84      0.93            3
# 20228   Not Specified      0.02     500.98     26.00            5
# 21776        Critical      0.06       9.48      7.29           11
# 24844          Medium      0.09      78.69     19.99           14
# 24846          Medium      0.08       3.28      2.31           14
# ...               ...       ...        ...       ...          ...
# 24894          Medium      0.07      60.98     49.00         1771
# 19826             Low      0.09      12.95      4.98         1775
# 20278   Not Specified      0.08       5.78      5.67         1776
# 20391             Low      0.07       5.43      0.95         1777
# 21163             Low      0.02      10.06      2.06         1777
#
#               Customer Name        shipmode     customerseg            PCate  \
# Row ID
# 20847         Bonnie Potter     Express Air       Corporate  Office Supplies
# 20228        Ronnie Proctor  Delivery Truck     Home Office        Furniture
# 21776         Marcus Dunlap     Regular Air     Home Office        Furniture
# 24844     Gwendolyn F Tyson     Regular Air  Small Business        Furniture
# 24846     Gwendolyn F Tyson     Regular Air  Small Business  Office Supplies
# ...                     ...             ...             ...              ...
# 24894           Jeff Spivey     Regular Air     Home Office  Office Supplies
# 19826          Marlene Kirk     Regular Air        Consumer  Office Supplies
# 20278   Charlotte Patterson     Regular Air        Consumer  Office Supplies
# 20391      Miriam Greenberg     Regular Air        Consumer  Office Supplies
# 21163      Miriam Greenberg     Regular Air        Consumer  Office Supplies
#
#                   Product Sub-Category  ...   Region State or Province  \
# Row ID                                  ...
# 20847              Pens & Art Supplies  ...     West        Washington
# 20228               Chairs & Chairmats  ...     West        California
# 21776               Office Furnishings  ...     East        New Jersey
# 24844               Office Furnishings  ...  Central         Minnesota
# 24846              Pens & Art Supplies  ...  Central         Minnesota
# ...                                ...  ...      ...               ...
# 24894                       Appliances  ...  Central          Illinois
# 19826   Binders and Binder Accessories  ...  Central           Indiana
# 20278                            Paper  ...  Central           Indiana
# 20391                            Paper  ...  Central           Indiana
# 21163                            Paper  ...  Central           Indiana
#
#                City Postal Code Order Date  Ship Date      Profit  Quantity  \
# Row ID
# 20847     Anacortes       98221 2015-01-07 2015-01-08     4.56000         4
# 20228   San Gabriel       91776 2015-06-13 2015-06-15  4390.36650        12
# 21776       Roselle        7203 2015-02-15 2015-02-17   -53.80960        22
# 24844    Prior Lake       55372 2015-05-12 2015-05-14   803.47050        16
# 24846    Prior Lake       55372 2015-05-12 2015-05-13   -24.03000         7
# ...             ...         ...        ...        ...         ...       ...
# 24894      Freeport       61032 2015-03-06 2015-03-07  -807.89000         7
# 19826    South Bend       46614 2015-06-14 2015-06-21   123.89175        21
# 20278   Terre Haute       47802 2015-02-04 2015-02-05   -53.89800        19
# 20391    Valparaiso       46383 2015-04-22 2015-04-26    26.50290         7
# 21163    Valparaiso       46383 2015-01-03 2015-01-08    90.62460        13
#
#           Sales Order ID
# Row ID
# 20847     13.01    88522
# 20228   6362.85    90193
# 21776    211.15    90192
# 24844   1164.45    86838
# 24846     22.23    86838
# ...         ...      ...
# 24894    410.17    89106
# 19826    269.54    89944
# 20278    106.57    89941
# 20391     38.41    89939
# 21163    131.34    89940
#
# [999 rows x 24 columns]

# %% [markdown]
# # Tạo cột IsProfit biết rằng nếu Profit lớn hơn 0 thì là YES , ngược lại là NO

# %%
df['IsProfit'] = df['Profit'].apply(lambda x: 'YES' if x > 0 else 'NO')
# Out:
# C:\Users\hungl\AppData\Local\Temp\ipykernel_25892\1644961232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IsProfit'] = df['Profit'].apply(lambda x: 'YES' if x > 0 else 'NO')

# %%
df
# Out:
#        Order Priority  Discount  unitprice  shipcost  Customer ID  \
# Row ID
# 20847            High      0.01       2.84      0.93            3
# 20228   Not Specified      0.02     500.98     26.00            5
# 21776        Critical      0.06       9.48      7.29           11
# 24844          Medium      0.09      78.69     19.99           14
# 24846          Medium      0.08       3.28      2.31           14
# ...               ...       ...        ...       ...          ...
# 24894          Medium      0.07      60.98     49.00         1771
# 19826             Low      0.09      12.95      4.98         1775
# 20278   Not Specified      0.08       5.78      5.67         1776
# 20391             Low      0.07       5.43      0.95         1777
# 21163             Low      0.02      10.06      2.06         1777
#
#               Customer Name        shipmode     customerseg            PCate  \
# Row ID
# 20847         Bonnie Potter     Express Air       Corporate  Office Supplies
# 20228        Ronnie Proctor  Delivery Truck     Home Office        Furniture
# 21776         Marcus Dunlap     Regular Air     Home Office        Furniture
# 24844     Gwendolyn F Tyson     Regular Air  Small Business        Furniture
# 24846     Gwendolyn F Tyson     Regular Air  Small Business  Office Supplies
# ...                     ...             ...             ...              ...
# 24894           Jeff Spivey     Regular Air     Home Office  Office Supplies
# 19826          Marlene Kirk     Regular Air        Consumer  Office Supplies
# 20278   Charlotte Patterson     Regular Air        Consumer  Office Supplies
# 20391      Miriam Greenberg     Regular Air        Consumer  Office Supplies
# 21163      Miriam Greenberg     Regular Air        Consumer  Office Supplies
#
#                   Product Sub-Category  ... State or Province         City  \
# Row ID                                  ...
# 20847              Pens & Art Supplies  ...        Washington    Anacortes
# 20228               Chairs & Chairmats  ...        California  San Gabriel
# 21776               Office Furnishings  ...        New Jersey      Roselle
# 24844               Office Furnishings  ...         Minnesota   Prior Lake
# 24846              Pens & Art Supplies  ...         Minnesota   Prior Lake
# ...                                ...  ...               ...          ...
# 24894                       Appliances  ...          Illinois     Freeport
# 19826   Binders and Binder Accessories  ...           Indiana   South Bend
# 20278                            Paper  ...           Indiana  Terre Haute
# 20391                            Paper  ...           Indiana   Valparaiso
# 21163                            Paper  ...           Indiana   Valparaiso
#
#         Postal Code Order Date  Ship Date      Profit Quantity    Sales  \
# Row ID
# 20847         98221 2015-01-07 2015-01-08     4.56000        4    13.01
# 20228         91776 2015-06-13 2015-06-15  4390.36650       12  6362.85
# 21776          7203 2015-02-15 2015-02-17   -53.80960       22   211.15
# 24844         55372 2015-05-12 2015-05-14   803.47050       16  1164.45
# 24846         55372 2015-05-12 2015-05-13   -24.03000        7    22.23
# ...             ...        ...        ...         ...      ...      ...
# 24894         61032 2015-03-06 2015-03-07  -807.89000        7   410.17
# 19826         46614 2015-06-14 2015-06-21   123.89175       21   269.54
# 20278         47802 2015-02-04 2015-02-05   -53.89800       19   106.57
# 20391         46383 2015-04-22 2015-04-26    26.50290        7    38.41
# 21163         46383 2015-01-03 2015-01-08    90.62460       13   131.34
#
#        Order ID IsProfit
# Row ID
# 20847     88522      YES
# 20228     90193      YES
# 21776     90192       NO
# 24844     86838      YES
# 24846     86838       NO
# ...         ...      ...
# 24894     89106       NO
# 19826     89944      YES
# 20278     89941       NO
# 20391     89939      YES
# 21163     89940      YES
#
# [999 rows x 25 columns]

# %%
df = df[['Discount', 'unitprice', 'shipcost', 'shipmode', 'customerseg', 'PCate', 
         'PCon', 'Region', 'Quantity', 'Sales', 'IsProfit']]
df
# Out:
#         Discount  unitprice  shipcost        shipmode     customerseg  \
# Row ID
# 20847       0.01       2.84      0.93     Express Air       Corporate
# 20228       0.02     500.98     26.00  Delivery Truck     Home Office
# 21776       0.06       9.48      7.29     Regular Air     Home Office
# 24844       0.09      78.69     19.99     Regular Air  Small Business
# 24846       0.08       3.28      2.31     Regular Air  Small Business
# ...          ...        ...       ...             ...             ...
# 24894       0.07      60.98     49.00     Regular Air     Home Office
# 19826       0.09      12.95      4.98     Regular Air        Consumer
# 20278       0.08       5.78      5.67     Regular Air        Consumer
# 20391       0.07       5.43      0.95     Regular Air        Consumer
# 21163       0.02      10.06      2.06     Regular Air        Consumer
#
#                   PCate        PCon   Region  Quantity    Sales IsProfit
# Row ID
# 20847   Office Supplies    Wrap Bag     West         4    13.01      YES
# 20228         Furniture  Jumbo Drum     West        12  6362.85      YES
# 21776         Furniture  Small Pack     East        22   211.15       NO
# 24844         Furniture   Small Box  Central        16  1164.45      YES
# 24846   Office Supplies    Wrap Bag  Central         7    22.23       NO
# ...                 ...         ...      ...       ...      ...      ...
# 24894   Office Supplies   Large Box  Central         7   410.17       NO
# 19826   Office Supplies   Small Box  Central        21   269.54      YES
# 20278   Office Supplies   Small Box  Central        19   106.57       NO
# 20391   Office Supplies    Wrap Bag  Central         7    38.41      YES
# 21163   Office Supplies    Wrap Bag  Central        13   131.34      YES
#
# [999 rows x 11 columns]

# %% [markdown]
# # 4.Mã hóa categorical data dùng One-Hot-Endcoding

# %%
dinhhuong = pd.get_dummies(df['shipmode']).astype(int)
df.drop('shipmode',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
# C:\Users\hungl\AppData\Local\Temp\ipykernel_25892\490238402.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('shipmode',axis=1,inplace=True)
#         Discount  unitprice  shipcost     customerseg            PCate  \
# Row ID
# 20847       0.01       2.84      0.93       Corporate  Office Supplies
# 20228       0.02     500.98     26.00     Home Office        Furniture
# 21776       0.06       9.48      7.29     Home Office        Furniture
# 24844       0.09      78.69     19.99  Small Business        Furniture
# 24846       0.08       3.28      2.31  Small Business  Office Supplies
#
#               PCon   Region  Quantity    Sales IsProfit  Delivery Truck  \
# Row ID
# 20847     Wrap Bag     West         4    13.01      YES               0
# 20228   Jumbo Drum     West        12  6362.85      YES               1
# 21776   Small Pack     East        22   211.15       NO               0
# 24844    Small Box  Central        16  1164.45      YES               0
# 24846     Wrap Bag  Central         7    22.23       NO               0
#
#         Express Air  Regular Air
# Row ID
# 20847             1            0
# 20228             0            0
# 21776             0            1
# 24844             0            1
# 24846             0            1

# %%
dinhhuong = pd.get_dummies(df['customerseg']).astype(int)
df.drop('customerseg',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost            PCate        PCon   Region  \
# Row ID
# 20847       0.01       2.84      0.93  Office Supplies    Wrap Bag     West
# 20228       0.02     500.98     26.00        Furniture  Jumbo Drum     West
# 21776       0.06       9.48      7.29        Furniture  Small Pack     East
# 24844       0.09      78.69     19.99        Furniture   Small Box  Central
# 24846       0.08       3.28      2.31  Office Supplies    Wrap Bag  Central
#
#         Quantity    Sales IsProfit  Delivery Truck  Express Air  Regular Air  \
# Row ID
# 20847          4    13.01      YES               0            1            0
# 20228         12  6362.85      YES               1            0            0
# 21776         22   211.15       NO               0            0            1
# 24844         16  1164.45      YES               0            0            1
# 24846          7    22.23       NO               0            0            1
#
#         Consumer  Corporate  Home Office  Small Business
# Row ID
# 20847          0          1            0               0
# 20228          0          0            1               0
# 21776          0          0            1               0
# 24844          0          0            0               1
# 24846          0          0            0               1

# %%
dinhhuong = pd.get_dummies(df['PCate']).astype(int)
df.drop('PCate',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost        PCon   Region  Quantity    Sales  \
# Row ID
# 20847       0.01       2.84      0.93    Wrap Bag     West         4    13.01
# 20228       0.02     500.98     26.00  Jumbo Drum     West        12  6362.85
# 21776       0.06       9.48      7.29  Small Pack     East        22   211.15
# 24844       0.09      78.69     19.99   Small Box  Central        16  1164.45
# 24846       0.08       3.28      2.31    Wrap Bag  Central         7    22.23
#
#        IsProfit  Delivery Truck  Express Air  Regular Air  Consumer  \
# Row ID
# 20847       YES               0            1            0         0
# 20228       YES               1            0            0         0
# 21776        NO               0            0            1         0
# 24844       YES               0            0            1         0
# 24846        NO               0            0            1         0
#
#         Corporate  Home Office  Small Business  Furniture  Office Supplies  \
# Row ID
# 20847           1            0               0          0                1
# 20228           0            1               0          1                0
# 21776           0            1               0          1                0
# 24844           0            0               1          1                0
# 24846           0            0               1          0                1
#
#         Technology
# Row ID
# 20847            0
# 20228            0
# 21776            0
# 24844            0
# 24846            0

# %%
dinhhuong = pd.get_dummies(df['PCon']).astype(int)
df.drop('PCon',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost   Region  Quantity    Sales IsProfit  \
# Row ID
# 20847       0.01       2.84      0.93     West         4    13.01      YES
# 20228       0.02     500.98     26.00     West        12  6362.85      YES
# 21776       0.06       9.48      7.29     East        22   211.15       NO
# 24844       0.09      78.69     19.99  Central        16  1164.45      YES
# 24846       0.08       3.28      2.31  Central         7    22.23       NO
#
#         Delivery Truck  Express Air  Regular Air  ...  Furniture  \
# Row ID                                            ...
# 20847                0            1            0  ...          0
# 20228                1            0            0  ...          1
# 21776                0            0            1  ...          1
# 24844                0            0            1  ...          1
# 24846                0            0            1  ...          0
#
#         Office Supplies  Technology  Jumbo Box  Jumbo Drum  Large Box  \
# Row ID
# 20847                 1           0          0           0          0
# 20228                 0           0          0           1          0
# 21776                 0           0          0           0          0
# 24844                 0           0          0           0          0
# 24846                 1           0          0           0          0
#
#         Medium Box  Small Box  Small Pack  Wrap Bag
# Row ID
# 20847            0          0           0         1
# 20228            0          0           0         0
# 21776            0          0           1         0
# 24844            0          1           0         0
# 24846            0          0           0         1
#
# [5 rows x 24 columns]

# %%
dinhhuong = pd.get_dummies(df['Region']).astype(int)
df.drop('Region',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost  Quantity    Sales IsProfit  \
# Row ID
# 20847       0.01       2.84      0.93         4    13.01      YES
# 20228       0.02     500.98     26.00        12  6362.85      YES
# 21776       0.06       9.48      7.29        22   211.15       NO
# 24844       0.09      78.69     19.99        16  1164.45      YES
# 24846       0.08       3.28      2.31         7    22.23       NO
#
#         Delivery Truck  Express Air  Regular Air  Consumer  ...  Jumbo Drum  \
# Row ID                                                      ...
# 20847                0            1            0         0  ...           0
# 20228                1            0            0         0  ...           1
# 21776                0            0            1         0  ...           0
# 24844                0            0            1         0  ...           0
# 24846                0            0            1         0  ...           0
#
#         Large Box  Medium Box  Small Box  Small Pack  Wrap Bag  Central  East  \
# Row ID
# 20847           0           0          0           0         1        0     0
# 20228           0           0          0           0         0        0     0
# 21776           0           0          0           1         0        0     1
# 24844           0           0          1           0         0        1     0
# 24846           0           0          0           0         1        1     0
#
#         South  West
# Row ID
# 20847       0     1
# 20228       0     1
# 21776       0     0
# 24844       0     0
# 24846       0     0
#
# [5 rows x 27 columns]

# %%
dinhhuong = pd.get_dummies(df['IsProfit'],drop_first=True)
dinhhuong=dinhhuong.astype(int)
df.drop('IsProfit',axis=1,inplace=True)
df= pd.concat([df,dinhhuong],axis=1)
df.head(5)
# Out:
#         Discount  unitprice  shipcost  Quantity    Sales  Delivery Truck  \
# Row ID
# 20847       0.01       2.84      0.93         4    13.01               0
# 20228       0.02     500.98     26.00        12  6362.85               1
# 21776       0.06       9.48      7.29        22   211.15               0
# 24844       0.09      78.69     19.99        16  1164.45               0
# 24846       0.08       3.28      2.31         7    22.23               0
#
#         Express Air  Regular Air  Consumer  Corporate  ...  Large Box  \
# Row ID                                                 ...
# 20847             1            0         0          1  ...          0
# 20228             0            0         0          0  ...          0
# 21776             0            1         0          0  ...          0
# 24844             0            1         0          0  ...          0
# 24846             0            1         0          0  ...          0
#
#         Medium Box  Small Box  Small Pack  Wrap Bag  Central  East  South  \
# Row ID
# 20847            0          0           0         1        0     0      0
# 20228            0          0           0         0        0     0      0
# 21776            0          0           1         0        0     1      0
# 24844            0          1           0         0        1     0      0
# 24846            0          0           0         1        1     0      0
#
#         West  YES
# Row ID
# 20847      1    1
# 20228      1    1
# 21776      0    0
# 24844      0    1
# 24846      0    0
#
# [5 rows x 27 columns]

# %%
df.rename(columns={'YES':'IsProfit'}, inplace=True)
df.head(5)
# Out:
#         Discount  unitprice  shipcost  Quantity    Sales  Delivery Truck  \
# Row ID
# 20847       0.01       2.84      0.93         4    13.01               0
# 20228       0.02     500.98     26.00        12  6362.85               1
# 21776       0.06       9.48      7.29        22   211.15               0
# 24844       0.09      78.69     19.99        16  1164.45               0
# 24846       0.08       3.28      2.31         7    22.23               0
#
#         Express Air  Regular Air  Consumer  Corporate  ...  Large Box  \
# Row ID                                                 ...
# 20847             1            0         0          1  ...          0
# 20228             0            0         0          0  ...          0
# 21776             0            1         0          0  ...          0
# 24844             0            1         0          0  ...          0
# 24846             0            1         0          0  ...          0
#
#         Medium Box  Small Box  Small Pack  Wrap Bag  Central  East  South  \
# Row ID
# 20847            0          0           0         1        0     0      0
# 20228            0          0           0         0        0     0      0
# 21776            0          0           1         0        0     1      0
# 24844            0          1           0         0        1     0      0
# 24846            0          0           0         1        1     0      0
#
#         West  IsProfit
# Row ID
# 20847      1         1
# 20228      1         1
# 21776      0         0
# 24844      0         1
# 24846      0         0
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 20847 to 21163
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Discount         999 non-null    float64
#  1   unitprice        999 non-null    float64
#  2   shipcost         999 non-null    float64
#  3   Quantity         999 non-null    int64
#  4   Sales            999 non-null    float64
#  5   Delivery Truck   999 non-null    int32
#  6   Express Air      999 non-null    int32
#  7   Regular Air      999 non-null    int32
#  8   Consumer         999 non-null    int32
#  9   Corporate        999 non-null    int32
#  10  Home Office      999 non-null    int32
#  11  Small Business   999 non-null    int32
#  12  Furniture        999 non-null    int32
#  13  Office Supplies  999 non-null    int32
#  14  Technology       999 non-null    int32
#  15  Jumbo Box        999 non-null    int32
#  16  Jumbo Drum       999 non-null    int32
#  17  Large Box        999 non-null    int32
#  18  Medium Box       999 non-null    int32
#  19  Small Box        999 non-null    int32
#  20  Small Pack       999 non-null    int32
#  21  Wrap Bag         999 non-null    int32
#  22  Central          999 non-null    int32
#  23  East             999 non-null    int32
#  24  South            999 non-null    int32
#  25  West             999 non-null    int32
#  26  IsProfit         999 non-null    int32
# dtypes: float64(4), int32(22), int64(1)
# memory usage: 132.7 KB

# %% [markdown]
# # Xây dựng mô hình dự báo IsProfit dựa trên Discount, unitprice, shipcost, shipmode, customerseg, PCate, PCon, Region, Quantity, Sales với Cross validation là train 80%, test 20% và random_state = 16

# %%
X = df.drop('IsProfit',axis=1).values
Y = df[['IsProfit']].values

# %%
# Chia tách ra trainning (huấn luyện) và testing (kiểm thử) 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=16)

# %% [markdown]
# # log(1+2^x) --> Logictis

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

# hàm biến đổi log(1+X^2)
def log_1_x_2(X):
    return np.log(1+X**2)
# functiontransformer
log_1_x_2_transformer = FunctionTransformer(log_1_x_2)
# Sử dụng transformer mới
steps = [('log1plusx2',log_1_x_2_transformer), ('Logistic', LogisticRegression())]

model = Pipeline(steps)
model.fit(X_train, y_train.flatten())
# Out:
# c:\Users\hungl\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('log1plusx2',
#                  FunctionTransformer(func=<function log_1_x_2 at 0x000001B633943560>)),
#                 ('Logistic', LogisticRegression())])

# %% [markdown]
# # liblinear

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

# hàm biến đổi log(1+X^2)
def log_1_x_2(X):
    return np.log(1+X**2)
# functiontransformer
log_1_x_2_transformer = FunctionTransformer(log_1_x_2)
# Sử dụng transformer mới
steps = [
    ('log1plusx2',log_1_x_2_transformer),
    ('Logistic', LogisticRegression(solver='liblinear', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)

# Huấn luyện mô hình
model.fit(X_train, y_train)
# Out:
# c:\Users\hungl\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(steps=[('log1plusx2',
#                  FunctionTransformer(func=<function log_1_x_2 at 0x000001B67547BC40>)),
#                 ('Logistic',
#                  LogisticRegression(max_iter=10000, solver='liblinear'))])

# %% [markdown]
# # Test liblinear

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.77
# AUC: 0.769907963185274

# %% [markdown]
# # Train liblinear

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.7822277847309136
# AUC: 0.7818797416765942

# %% [markdown]
# # ROC và AUE Plot

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# # TEST

# %% [markdown]
# # Đường cong càng ôm góc trên bên trái của biểu đồ thì mô hình càng phân loại dữ liệu thành các danh mục tốt hơn.

# %%
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(libinear)')
plt.xlabel('False Positive Rate(libinear)')
plt.show()

# %% [markdown]
# Để định lượng điều này, chúng ta có thể tính toán AUC – diện tích dưới đường cong – cho chúng ta biết phần nằm dưới đường cong là bao nhiêu.
#
# AUC càng gần 1 thì mô hình càng tốt. Một mô hình có AUC bằng 0,5 không tốt hơn mô hình phân loại ngẫu nhiên.

# %%
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
auc
# Out:
# 0.829031612645058

# %% [markdown]
# # ROC

# %%
#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(libinear)')
plt.xlabel('False Positive Rate(libinear)')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # TRAIN

# %%
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(libinear)')
plt.xlabel('False Positive Rate(libinear)')
plt.show()

# %%
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
auc
# Out:
# 0.8419211235814158

# %%
#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(libinear)')
plt.xlabel('False Positive Rate(libinear)')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # lbfgs

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

# hàm biến đổi log(1+X^2)
def log_1_x_2(X):
    return np.log(1+X**2)
# functiontransformer
log_1_x_2_transformer = FunctionTransformer(log_1_x_2)
# Sử dụng transformer mới
steps = [
    ('log1plusx2',log_1_x_2_transformer),
    ('Logistic', LogisticRegression(solver='lbfgs', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)

# Huấn luyện mô hình
model.fit(X_train, y_train)
# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(lbfgs)')
plt.xlabel('False Positive Rate(lbfgs)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(lbfgs)')
plt.xlabel('False Positive Rate(lbfgs)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST(lbfgs)')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(lbfgs)')
plt.xlabel('False Positive Rate(lbfgs)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(lbfgs)')
plt.xlabel('False Positive Rate(lbfgs)')
plt.legend(loc=4)
plt.show()
# Out:
# TẬP TRAIN
# c:\Users\hungl\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AUC test 0.8417330240140448
# TẬP TEST(lbfgs)
# AUC test 0.8298319327731093

# %% [markdown]
# # tập test voi lbfgs

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.77
# AUC: 0.769907963185274

# %% [markdown]
# # tập train lbfgs

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.7784730913642053
# AUC: 0.7780895353940686

# %% [markdown]
# # AUE and ROC plot

# %% [markdown]
# # Newton-cg

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

# hàm biến đổi log(1+X^2)
def log_1_x_2(X):
    return np.log(1+X**2)
# functiontransformer
log_1_x_2_transformer = FunctionTransformer(log_1_x_2)
# Sử dụng transformer mới
steps = [
    ('log1plusx2',log_1_x_2_transformer),
    ('Logistic', LogisticRegression(solver='newton-cg', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)

# Huấn luyện mô hình
model.fit(X_train, y_train)
# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Newton-cg)')
plt.xlabel('False Positive Rate(Newton-cg)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Newton-cg)')
plt.xlabel('False Positive Rate(Newton-cg)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Newton-cg)')
plt.xlabel('False Positive Rate(Newton-cg)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Newton-cg)')
plt.xlabel('False Positive Rate(Newton-cg)')
plt.legend(loc=4)
plt.show()
# Out:
# TẬP TRAIN
# c:\Users\hungl\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AUC test 0.8417267540284659
# TẬP TEST
# AUC test 0.8298319327731093

# %% [markdown]
# # tập test voi newton-cg

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.77
# AUC: 0.769907963185274

# %% [markdown]
# # tập train newton-cg

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.7784730913642053
# AUC: 0.7780895353940686

# %% [markdown]
# # newton-cholesky

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

# hàm biến đổi log(1+X^2)
def log_1_x_2(X):
    return np.log(1+X**2)
# functiontransformer
log_1_x_2_transformer = FunctionTransformer(log_1_x_2)
# Sử dụng transformer mới
steps = [
    ('log1plusx2',log_1_x_2_transformer),
    ('Logistic', LogisticRegression(solver='newton-cholesky', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)
# Huấn luyện mô hình
model.fit(X_train, y_train)

# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Newton-Cholesky)')
plt.xlabel('False Positive Rate(Newton-Cholesky)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Newton-Cholesky)')
plt.xlabel('False Positive Rate(Newton-Cholesky)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Newton-Cholesky)')
plt.xlabel('False Positive Rate(Newton-Cholesky)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Newton-Cholesky)')
plt.xlabel('False Positive Rate(Newton-Cholesky)')
plt.legend(loc=4)
plt.show()
# Out:
# TẬP TRAIN
# c:\Users\hungl\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AUC test 0.8417267540284659
# TẬP TEST
# AUC test 0.8298319327731093

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.77
# AUC: 0.769907963185274

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.7784730913642053
# AUC: 0.7780895353940686

# %% [markdown]
# # Sag

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

# hàm biến đổi log(1+X^2)
def log_1_x_2(X):
    return np.log(1+X**2)
# functiontransformer
log_1_x_2_transformer = FunctionTransformer(log_1_x_2)
# Sử dụng transformer mới
steps = [
    ('log1plusx2',log_1_x_2_transformer),
    ('Logistic', LogisticRegression(solver='sag', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)
# Huấn luyện mô hình
model.fit(X_train, y_train)
# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Sag)')
plt.xlabel('False Positive Rate(Sag)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Sag)')
plt.xlabel('False Positive Rate(Sag)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Sag)')
plt.xlabel('False Positive Rate(Sag)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Sag)')
plt.xlabel('False Positive Rate(Sag)')
plt.legend(loc=4)
plt.show()
# Out:
# TẬP TRAIN
# c:\Users\hungl\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AUC test 0.8416828641294125
# TẬP TEST
# AUC test 0.8297318927571029

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.77
# AUC: 0.769907963185274

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.7772215269086358
# AUC: 0.7768041883503668

# %% [markdown]
# # Saga

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

# hàm biến đổi log(1+X^2)
def log_1_x_2(X):
    return np.log(1+X**2)
# functiontransformer
log_1_x_2_transformer = FunctionTransformer(log_1_x_2)
# Sử dụng transformer mới
steps = [
    ('log1plusx2',log_1_x_2_transformer),
    ('Logistic', LogisticRegression(solver='saga', max_iter=10000, penalty='l2'))
]
model = Pipeline(steps)
# Huấn luyện mô hình
model.fit(X_train, y_train)
# TRAIN
print ('TẬP TRAIN')
# AUE
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate(Saga)')
plt.xlabel('False Positive Rate(Saga)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_train)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_train,  y_pred_proba)
auc = metrics.roc_auc_score(y_train, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate(Saga)')
plt.xlabel('False Positive Rate(Saga)')
plt.legend(loc=4)
plt.show()

# TEST
print('TẬP TEST')
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate (Saga)')
plt.xlabel('False Positive Rate (Saga)')
plt.show() 

# tính AUC
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print('AUC test',auc)
# ROC
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate (Saga)')
plt.xlabel('False Positive Rate (Saga)')
plt.legend(loc=4)
plt.show()
# Out:
# TẬP TRAIN
# c:\Users\hungl\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AUC test 0.8416138942880431
# TẬP TEST
# AUC test 0.8294317727090837

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_test)

# Tính Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.77
# AUC: 0.769907963185274

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

y_pred = model.predict(X_train)

# Tính Accuracy
accuracy = accuracy_score(y_train, y_pred)
print(f'Accuracy: {accuracy}')

# Tính ROC Curve và AUC
fpr, tpr, thresholds = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc}')
# Out:
# Accuracy: 0.7759699624530664
# AUC: 0.775518841306665
